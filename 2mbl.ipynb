# %% [markdown]
# # Scraping DCG.media

# %% [markdown]
# %pip install bs4 pandas numpy ydata-profiling plotly tqdm ipywidgets

# %%
### SCRAPING
import requests as rq
from bs4 import BeautifulSoup

### DATABASES
import pandas as pd
import numpy as np
from ydata_profiling import ProfileReport

### VISUALISATION
#import plotly.express as px

### DIVERS
from tqdm.notebook import tqdm

### FORMAT
from datetime import datetime, timezone
import time
import json

# %% [markdown]
# ## Définition des variables

# %%
website = 'mon-business-en-ligne'
abbr = 'mbl'
tld = '.com'

# %%
page_number = 1
top_url = f'https://www.{website+tld}'
top_search_url = f'{top_url}/page/{page_number}/?s'

# %% [markdown]
# ## Définition des fonctions

# %% [markdown]
# ### Obtenir le nombre de pages de résultats de recherche

# %%
def get_max_page_results(top_search_url):
    r = rq.get(top_search_url)
    soup = BeautifulSoup(r.content)
    page_final = soup.find('a', class_ = 'last').text
    return int(page_final)
get_max_page_results(top_search_url)
# Out:
# 9

# %% [markdown]
# ### Obtenir la liste des pages de résultats de recherche

# %%
def get_all_results_pages(page_final):
    urls = []
    for i in range(page_final):
        i = f'{top_url}/page/{i+1}/?s'
        urls.append(i)
    return urls
get_all_results_pages(get_max_page_results(top_search_url))
# Out:
# ['https://www.mon-business-en-ligne.com/page/1/?s',
#  'https://www.mon-business-en-ligne.com/page/2/?s',
#  'https://www.mon-business-en-ligne.com/page/3/?s',
#  'https://www.mon-business-en-ligne.com/page/4/?s',
#  'https://www.mon-business-en-ligne.com/page/5/?s',
#  'https://www.mon-business-en-ligne.com/page/6/?s',
#  'https://www.mon-business-en-ligne.com/page/7/?s',
#  'https://www.mon-business-en-ligne.com/page/8/?s',
#  'https://www.mon-business-en-ligne.com/page/9/?s']

# %% [markdown]
# ### Obtenir tous les liens des articles sur une page de recherche

# %%
def get_articles_on_page(search_results):
    urls_articles = []
    s = rq.Session()
    for p in tqdm(search_results):
        r = s.get(p)
        soup = BeautifulSoup(r.content)
        articles = soup.find_all('h2', class_ = 'entry-title')
        for article in articles:
            url = article.find('a', href=True)['href']
            urls_articles.append(url)
    return urls_articles

# %%
get_articles_on_page(get_all_results_pages(get_max_page_results(top_search_url)))
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# ['https://www.mon-business-en-ligne.com/espace-client-berger-levrault-connexion-rapide-et-gestion-simplifiee/',
#  'https://www.mon-business-en-ligne.com/poids-palette-europe-impact-sur-les-frais-de-transport-et-la-manutention/',
#  'https://www.mon-business-en-ligne.com/jurik-creation-dun-webmagazine-innovant-et-engageant/',
#  'https://www.mon-business-en-ligne.com/influence-des-dates-de-paie-des-professeurs-sur-leur-moral/',
#  'https://www.mon-business-en-ligne.com/quel-est-son-statut/',
#  'https://www.mon-business-en-ligne.com/puis-je-voyager-avec-un-recepisse-de-demande-de-titre-de-sejour/',
#  'https://www.mon-business-en-ligne.com/10-services-indispensables-pour-les-entreprises/',
#  'https://www.mon-business-en-ligne.com/les-meilleurs-grossistes-de-fleurs-de-cbd-en-2023/',
#  'https://www.mon-business-en-ligne.com/ouvrir-un-camion-pizza-conseils-pratiques-pour-trouver-le-bon-emplacement/',
#  'https://www.mon-business-en-ligne.com/comprendre-le-fonctionnement-du-droit-du-travail-en-france-tout-ce-que-vous-devez-savoir/',
#  'https://www.mon-business-en-ligne.com/tampons-pour-vetements-personnalisation-textile/',
#  'https://www.mon-business-en-ligne.com/nombre-de-jours-ouvrables-en-2024-comment-bien-planifier-son-annee/',
#  'https://www.mon-business-en-ligne.com/mi-temps-therapeutique-et-fonction-publique-quels-sont-les-veritables-avantages-et-inconvenients/',
#  'https://www.mon-business-en-ligne.com/prime-de-fidelisation-93-comment-en-beneficier-en-seine-saint-denis/',
#  'https://www.mon-business-en-ligne.com/pourquoi-choisir-des-cartes-cadeaux-pour-recompenser-vos-salaries/',
#  'https://www.mon-business-en-ligne.com/swedishop-astuces-pour-trouver-les-meilleures-offres-sur-le-site/',
#  'https://www.mon-business-en-ligne.com/comment-optimiser-sa-recherche-demploi-dans-la-region-bordelaise/',
#  'https://www.mon-business-en-ligne.com/comment-choisir-la-meilleure-entreprise-de-nettoyage-pour-votre-bureau-a-bordeaux/',
#  'https://www.mon-business-en-ligne.com/comment-positionner-un-nouveau-produit/',
#  'https://www.mon-business-en-ligne.com/quels-sont-les-primes-imposables/',
#  'https://www.mon-business-en-ligne.com/comment-faire-une-etude-de-cas-memoire/',
#  'https://www.mon-business-en-ligne.com/comment-enlever-des-taches-blanches-sur-une-table-en-merisier/',
#  'https://www.mon-business-en-ligne.com/tpe-et-pme-quelles-differences-entre-ces-entreprises/',
#  'https://www.mon-business-en-ligne.com/les-nouvelle-methodes-de-management-les-plus-efficaces/',
#  'https://www.mon-business-en-ligne.com/travailler-a-paris-les-avantages-et-les-inconvenients/',
#  'https://www.mon-business-en-ligne.com/5-alternatives-gratuites-a-zoom-pour-vos-reunions-en-ligne/',
#  'https://www.mon-business-en-ligne.com/creer-une-eurl-vs-sarl-difference-specificites/',
#  'https://www.mon-business-en-ligne.com/une-solution-denvoi-de-sms-en-masse-qui-convient-a-votre-budget-2/',
#  'https://www.mon-business-en-ligne.com/les-differences-entre-une-affiche-et-un-flyer/',
#  'https://www.mon-business-en-ligne.com/comment-devenir-testeur-de-jeux-video-en-tant-que-micro-entrepreneur/',
#  'https://www.mon-business-en-ligne.com/contrat-consensuel-definition-fonctionnement-et-exemples-pratiques/',
#  'https://www.mon-business-en-ligne.com/emploi-a-domicile-en-mise-sous-pli-verite-sur-sa-fiabilite-et-risques-darnaque/',
#  'https://www.mon-business-en-ligne.com/choisir-son-statut-pour-livreur-uber-eats-auto-entrepreneur-ou-salarie/',
#  'https://www.mon-business-en-ligne.com/appartenance-de-linkedin-a-un-gafam-analyse-detaillee/',
#  'https://www.mon-business-en-ligne.com/linfluence-des-avantages-du-statut-cadre-sur-la-motivation-au-travail/',
#  'https://www.mon-business-en-ligne.com/comment-optimiser-votre-recherche-demploi-a-pole-emploi-dax-astuces-et-conseils/',
#  'https://www.mon-business-en-ligne.com/comprendre-le-role-du-document-kbis-dans-le-fonctionnement-dune-association/',
#  'https://www.mon-business-en-ligne.com/grille-salariale-de-la-convention-66-comment-optimiser-sa-remuneration/',
#  'https://www.mon-business-en-ligne.com/evolution-de-la-valeur-du-point-convention-66-en-2024-quels-impacts-sur-les-grilles-salariales/',
#  'https://www.mon-business-en-ligne.com/le-preparateur-de-commande-ce-quil-faut-savoir/',
#  'https://www.mon-business-en-ligne.com/caisse-depargne-bretagne-pays-de-loire-comment-ouvrir-un-compte-bancaire-pro/',
#  'https://www.mon-business-en-ligne.com/credit-mutuel-ile-de-france-comment-ouvrir-un-compte-bancaire-pro/',
#  'https://www.mon-business-en-ligne.com/convention-bim-et-processus-de-modelisation-des-donnees/',
#  'https://www.mon-business-en-ligne.com/7-idees-de-team-building-uniques-a-paris-pour-dynamiser-votre-equipe/',
#  'https://www.mon-business-en-ligne.com/quel-est-le-salaire-dun-educateur-canin-comportementaliste/',
#  'https://www.mon-business-en-ligne.com/lenquete-sociale-procedure-deroulement-definition/',
#  'https://www.mon-business-en-ligne.com/les-services-supplementaires-a-considerer-lors-du-choix-dune-societe-de-demenagement/',
#  'https://www.mon-business-en-ligne.com/comment-la-formation-obligatoire-en-entreprise-favorise-t-elle-la-croissance-professionnelle/',
#  'https://www.mon-business-en-ligne.com/lancer-son-entreprise-les-etapes-essentielles-pour-demarrer-votre-projet-entrepreneurial/',
#  'https://www.mon-business-en-ligne.com/histoire-du-logo-mcdonalds-evolution-creation-et-impact-sur-la-marque/',
#  'https://www.mon-business-en-ligne.com/bureau-pour-deux-personnes-creer-un-espace-ergonomique-et-convivial/',
#  'https://www.mon-business-en-ligne.com/les-avantages-douvrir-votre-propre-pizzeria-en-franchise-pizza-hut/',
#  'https://www.mon-business-en-ligne.com/les-pieges-a-eviter-lors-de-lelaboration-dun-exemple-dappreciation-de-stagiaire/',
#  'https://www.mon-business-en-ligne.com/les-opportunites-insoupconnees-du-travail-demballage-a-domicile/',
#  'https://www.mon-business-en-ligne.com/pourquoi-le-logo-pagani-symbolise-le-prestige-dans-lunivers-horloger/',
#  'https://www.mon-business-en-ligne.com/optimiser-votre-recherche-demploi-a-hyeres-avec-pole-emploi-astuces-et-conseils/',
#  'https://www.mon-business-en-ligne.com/les-etapes-cles-pour-reussir-la-creation-de-votre-sci-conseils-dexperts/',
#  'https://www.mon-business-en-ligne.com/pourquoi-le-tote-bag-personnalise-est-un-cadeau-dentreprise-ideal/',
#  'https://www.mon-business-en-ligne.com/comprendre-la-structure-juridique-une-definition-detaillee/',
#  'https://www.mon-business-en-ligne.com/comment-calculer-le-nombre-daction-dune-entreprise/',
#  'https://www.mon-business-en-ligne.com/comment-choisir-un-statut-pour-son-entreprise/',
#  'https://www.mon-business-en-ligne.com/comment-construire-lidentite-dune-marque/',
#  'https://www.mon-business-en-ligne.com/comment-faire-pour-mieux-vendre/',
#  'https://www.mon-business-en-ligne.com/comment-rediger-les-statuts-dune-societe/',
#  'https://www.mon-business-en-ligne.com/octime-salarie-connexion-se-connecter-a-son-compte/',
#  'https://www.mon-business-en-ligne.com/comment-faire-pour-creer-un-lien-internet/',
#  'https://www.mon-business-en-ligne.com/comment-calculer-le-nombre-daction-dune-entreprise/',
#  'https://www.mon-business-en-ligne.com/quel-sont-les-commerce-qui-marche-le-mieux/',
#  'https://www.mon-business-en-ligne.com/comment-savoir-si-mon-patron-veut-me-virer/',
#  'https://www.mon-business-en-ligne.com/quel-est-le-salaire-minimum-dun-comptable/',
#  'https://www.mon-business-en-ligne.com/quelle-est-le-salaire-dun-comptable/',
#  'https://www.mon-business-en-ligne.com/comment-construire-un-diagramme-de-pert/',
#  'https://www.mon-business-en-ligne.com/combien-coute-un-kbis/',
#  'https://www.mon-business-en-ligne.com/credit-agricole-nord-midi-pyrenees-comment-ouvrir-un-compte-bancaire-pro/',
#  'https://www.mon-business-en-ligne.com/1645-brut-en-net-calculer-son-salaire-en-net/',
#  'https://www.mon-business-en-ligne.com/quels-sont-les-4-types-de-competences/',
#  'https://www.mon-business-en-ligne.com/comment-ouvrir-une-boutique-de-puff-liquideo-en-tant-que-grossiste/',
#  'https://www.mon-business-en-ligne.com/comment-attirer-et-fideliser-vos-clients-dans-le-domaine-du-nettoyage/',
#  'https://www.mon-business-en-ligne.com/smodin-vs-hix-ai-quest-ce-qui-fait-de-hix-ai-une-alternative-superieure-a-smodin/',
#  'https://www.mon-business-en-ligne.com/reussir-en-tant-que-femme-de-menage-auto-entrepreneur-astuces-et-conseils-pratiques/',
#  'https://www.mon-business-en-ligne.com/les-avantages-du-cgos-pour-les-agents-hospitaliers/',
#  'https://www.mon-business-en-ligne.com/levolution-du-logo-apple-a-travers-les-decennies/',
#  'https://www.mon-business-en-ligne.com/pourquoi-et-comment-utiliser-le-papier-demballage-pour-la-vente-a-emporter/',
#  'https://www.mon-business-en-ligne.com/nombre-de-jours-travailles-en-2023-optimisation-et-repartition-mensuelle/',
#  'https://www.mon-business-en-ligne.com/les-subtilites-de-la-signature-pour-ordre-dans-les-transactions-commerciales/',
#  'https://www.mon-business-en-ligne.com/zoom-sur-des-modeles-inspirants-dentreprises-rse/',
#  'https://www.mon-business-en-ligne.com/comment-faire-pour-creer-un-lien-internet/',
#  'https://www.mon-business-en-ligne.com/mediavenir-media-digital-dinformation-politique-economique/',
#  'https://www.mon-business-en-ligne.com/comment-se-connecter-a-comptalia/',
#  'https://www.mon-business-en-ligne.com/hr4you-auchan-un-nouveau-paradigme-des-ressources-humaines/',
#  'https://www.mon-business-en-ligne.com/proteger-son-ordinateur-identifier-deux-categories-de-logiciels-malveillants/',
#  'https://www.mon-business-en-ligne.com/methodologie-cgrh-strategies-et-etapes-cles-pour-une-gestion-rh-efficace/',
#  'https://www.mon-business-en-ligne.com/les-facteurs-a-considerer-lors-de-lachat-dun-parasol-de-terrasse-pour-votre-restaurant/',
#  'https://www.mon-business-en-ligne.com/zimbra-bonneuil-plateforme-de-messagerie-pour-les-residents-et-les-entreprises-locales/',
#  'https://www.mon-business-en-ligne.com/arkevia-portail-et-la-securisation-de-vos-documents-en-ligne/',
#  'https://www.mon-business-en-ligne.com/les-avantages-insoupconnes-du-cnas-sud-est-pour-les-agents-territoriaux/',
#  'https://www.mon-business-en-ligne.com/les-innovations-de-birdy-auchan-pour-une-gestion-optimale-du-stock/',
#  'https://www.mon-business-en-ligne.com/arkevia-revolutionner-la-gestion-documentaire/',
#  'https://www.mon-business-en-ligne.com/les-e-bulletins-arkevia-revolution-dans-la-gestion-des-salaires/',
#  'https://www.mon-business-en-ligne.com/les-secrets-du-magasin-concorde-une-experience-unique-a-champigny-sur-marne/',
#  'https://www.mon-business-en-ligne.com/le-salaire-net-dun-eboueur-en-2024-lessentiel-a-connaitre/',
#  'https://www.mon-business-en-ligne.com/octime-salarie-connexion-se-connecter-a-son-compte/',
#  'https://www.mon-business-en-ligne.com/les-risques-encourus-en-cas-de-violation-des-lois-sur-le-droit-dauteur-et-la-propriete-intellectuelle/',
#  'https://www.mon-business-en-ligne.com/comment-optimiser-votre-tremplin-numerique-pour-un-meilleur-referencement-seo/',
#  'https://www.mon-business-en-ligne.com/limportance-de-lavocat-en-droit-social-dans-la-gestion-des-conflits-du-travail/',
#  'https://www.mon-business-en-ligne.com/resiliation-resilier-son-contrat-electricite-chez-greenyellow/',
#  'https://www.mon-business-en-ligne.com/les-meilleures-strategies-pour-mener-a-bien-sa-transformation-digitale-en-entreprise/',
#  'https://www.mon-business-en-ligne.com/decouvrez-les-principaux-avantages-du-portage-salarial/',
#  'https://www.mon-business-en-ligne.com/optimiser-la-gestion-de-vos-projets-avec-un-logiciel-de-suivi-adapte/',
#  'https://www.mon-business-en-ligne.com/comment-devenir-commissaire-de-police-au-maroc/',
#  'https://www.mon-business-en-ligne.com/les-avantages-insoupconnes-du-portail-malin-la-poste-pour-les-professionnels/',
#  'https://www.mon-business-en-ligne.com/comprendre-la-definition-du-portage-salarial-et-ses-avantages-pour-les-independants/',
#  'https://www.mon-business-en-ligne.com/quelle-marge-pour-etre-rentable/',
#  'https://www.mon-business-en-ligne.com/comment-prouver-vos-competences-sans-experience-professionnelle/',
#  'https://www.mon-business-en-ligne.com/les-erreurs-a-eviter-lors-de-la-simulation-de-portage-salarial-avec-excel/',
#  'https://www.mon-business-en-ligne.com/exploration-des-dispositifs-al-in-daction-logement-pour-les-entreprises/',
#  'https://www.mon-business-en-ligne.com/qualifier-une-base-de-donnees-de-prospects-a-quoi-ca-sert/',
#  'https://www.mon-business-en-ligne.com/qui-finance-la-formation-des-membres-du-cse/',
#  'https://www.mon-business-en-ligne.com/les-avantages-des-fenetres-en-pvc/',
#  'https://www.mon-business-en-ligne.com/calcul-du-stock-de-securite-methodes-efficaces-et-precises/',
#  'https://www.mon-business-en-ligne.com/temoignages-inspirants-de-nomades-numeriques-a-travers-le-monde/',
#  'https://www.mon-business-en-ligne.com/comment-modifier-les-statuts-de-sa-sci-en-ligne/',
#  'https://www.mon-business-en-ligne.com/quest-ce-quun-assessment-center/',
#  'https://www.mon-business-en-ligne.com/comment-creer-une-entreprise-prospere-et-durable-en-2021-2/',
#  'https://www.mon-business-en-ligne.com/ouvrir-une-franchise-sushi-shop-decouvrez-les-nombreux-avantages/',
#  'https://www.mon-business-en-ligne.com/role-et-competences-cles-de-lassistant-supply-chain/',
#  'https://www.mon-business-en-ligne.com/revenu-passif-ces-avantages-a-connaitre/',
#  'https://www.mon-business-en-ligne.com/comment-choisir-un-statut-pour-son-entreprise/',
#  'https://www.mon-business-en-ligne.com/comment-construire-lidentite-dune-marque/',
#  'https://www.mon-business-en-ligne.com/comment-faire-pour-mieux-vendre/',
#  'https://www.mon-business-en-ligne.com/comment-rediger-les-statuts-dune-societe/',
#  'https://www.mon-business-en-ligne.com/octime-salarie-connexion-se-connecter-a-son-compte/',
#  'https://www.mon-business-en-ligne.com/comment-faire-pour-creer-un-lien-internet/',
#  'https://www.mon-business-en-ligne.com/comment-calculer-le-nombre-daction-dune-entreprise/',
#  'https://www.mon-business-en-ligne.com/agence-seo-tremplin-numerique-expertise-en-projets-web-sur-mesure/',
#  'https://www.mon-business-en-ligne.com/quel-avocat-choisir-pour-un-redressement-judiciaire-guide-de-selection/',
#  'https://www.mon-business-en-ligne.com/le-business-model-canvas-outil-de-gestion-et-de-developpement/',
#  'https://www.mon-business-en-ligne.com/comment-envoyer-mes-fiche-de-paie-pole-emploi/',
#  'https://www.mon-business-en-ligne.com/avantages-et-inconvenients-du-cesu-pour-salaries-analyse-complete/',
#  'https://www.mon-business-en-ligne.com/secteur-prive-comprendre-sa-definition-et-ses-frontieres-economiques/',
#  'https://www.mon-business-en-ligne.com/comprendre-le-poi-plan-doperation-interne-et-son-importance/',
#  'https://www.mon-business-en-ligne.com/les-avantages-dune-intranet-pour-les-mfr-comment-se-connecter-facilement/',
#  'https://www.mon-business-en-ligne.com/acheter-une-cigarette-electronique-de-qualite-chez-un-grossiste-pour-particulier/',
#  'https://www.mon-business-en-ligne.com/comment-choisir-son-fournisseur-en-materiel-doptique-criteres-et-conseils/',
#  'https://www.mon-business-en-ligne.com/les-pdg-de-lindustrie-automobile-quels-sont-leurs-salaires/',
#  'https://www.mon-business-en-ligne.com/les-tresors-caches-de-5-euros-services-etonnants-pour-les-entrepreneurs/',
#  'https://www.mon-business-en-ligne.com/la-gamme-bio-des-e-liquides-pro-vdlv/',
#  'https://www.mon-business-en-ligne.com/decouvrez-les-multiples-approches-de-gestion-du-personnel-pour-booster-votre-efficacite-organisationnelle/',
#  'https://www.mon-business-en-ligne.com/les-outils-excel-avances-pour-ameliorer-votre-simulation-de-portage-salarial/',
#  'https://www.mon-business-en-ligne.com/comment-assurer-lactivite-de-son-entreprise-en-cas-de-crise-grace-a-des-outils-specialises/',
#  'https://www.mon-business-en-ligne.com/comment-fideliser-vos-travailleurs-temporaires-et-assurer-une-bonne-entente-avec-les-salaries/',
#  'https://www.mon-business-en-ligne.com/quels-sont-les-services-accessibles-aupres-dune-agence-developpement-web-nice/',
#  'https://www.mon-business-en-ligne.com/les-etiquettes-alimentaires-informer-le-consommateur/',
#  'https://www.mon-business-en-ligne.com/suivez-une-formation-specialisee-en-management-transversal/',
#  'https://www.mon-business-en-ligne.com/pourquoi-le-serveur-nas-est-il-un-avantage-pour-votre-entreprise/',
#  'https://www.mon-business-en-ligne.com/quels-sont-les-avis-des-parents-sur-les-couches-pampers/',
#  'https://www.mon-business-en-ligne.com/la-lld-une-solution-cle-en-main-pour-une-gestion-simplifiee-de-son-parc-automobile/',
#  'https://www.mon-business-en-ligne.com/norme-wc-pmr-2021-les-normes-pour-handicapes-modifiees-depuis-2020/',
#  'https://www.mon-business-en-ligne.com/maximiser-la-visibilite-et-la-notoriete-en-ligne-grace-a-lutilisation-efficace-des-reseaux-sociaux/',
#  'https://www.mon-business-en-ligne.com/formation-en-anglais-professionnel-un-veritable-atout-pour-chercher-du-travail/',
#  'https://www.mon-business-en-ligne.com/decrypter-lalgorithme-linkedin-pour-une-meilleure-performance/',
#  'https://www.mon-business-en-ligne.com/comment-effectuer-une-demande-de-kbis-sans-erreurs/',
#  'https://www.mon-business-en-ligne.com/a-vous-lire-la-science-de-la-politesse-dans-la-correspondance-electronique/',
#  'https://www.mon-business-en-ligne.com/les-services-de-comptabilite-externalises-un-atout-pour-les-pme/',
#  'https://www.mon-business-en-ligne.com/comment-transformer-ses-heures-de-dif-en-cpf/',
#  'https://www.mon-business-en-ligne.com/quels-sont-les-indicateurs-du-bilan-social/',
#  'https://www.mon-business-en-ligne.com/quels-sont-les-meilleurs-leviers-marketing-en-ligne/',
#  'https://www.mon-business-en-ligne.com/protegez-votre-entreprise-avec-une-assurance-multirisque-professionnelle-adaptee/',
#  'https://www.mon-business-en-ligne.com/les-meilleures-pratiques-pour-une-gestion-de-projet-efficace-en-entreprise/',
#  'https://www.mon-business-en-ligne.com/revolutionner-son-e-commerce-limpact-cle-dun-partenariat-avec-un-fournisseur-francophone-en-chine/',
#  'https://www.mon-business-en-ligne.com/le-choix-des-meilleures-imprimantes-professionnelles-pour-plans-et-dessins-techniques/',
#  'https://www.mon-business-en-ligne.com/carrieres-prestigieuses-lunivers-des-metiers-dans-lhotellerie-de-luxe/',
#  'https://www.mon-business-en-ligne.com/avantages-des-sacs-et-bagages-publicitaires-dans-les-strategies-de-marketing/',
#  'https://www.mon-business-en-ligne.com/guide-ultime-pour-choisir-le-tampon-parfait-pour-votre-entreprise/',
#  'https://www.mon-business-en-ligne.com/comment-simplifier-votre-suivi-de-chantier-btp/',
#  'https://www.mon-business-en-ligne.com/securite-en-entrepot-comment-bien-equiper-ses-quais-de-chargement/',
#  'https://www.mon-business-en-ligne.com/assurance-professionnelle-bmacif-les-demarches-a-suivre-pour-etre-bien-protege/',
#  'https://www.mon-business-en-ligne.com/de-lidee-a-laction-parcours-dun-createur-dentreprise-reussi/',
#  'https://www.mon-business-en-ligne.com/les-obligations-du-rgpd-ce-que-chaque-entreprise-doit-savoir-pour-proteger-les-donnees/',
#  'https://www.mon-business-en-ligne.com/quest-ce-quun-plan-de-financement-previsionnel/',
#  'https://www.mon-business-en-ligne.com/qui-se-rapporte-a-largent/',
#  'https://www.mon-business-en-ligne.com/quels-sont-les-differents-types-de-societes-de-capitaux/',
#  'https://www.mon-business-en-ligne.com/comment-reussir-a-creer-une-communaute-en-ligne-pour-votre-entreprise/',
#  'https://www.mon-business-en-ligne.com/comprendre-et-realiser-une-demande-de-kbis-en-toute-simplicite/',
#  'https://www.mon-business-en-ligne.com/lessor-du-metier-de-devops-pourquoi-se-former/',
#  'https://www.mon-business-en-ligne.com/gestion-efficace-de-vos-emails-avec-aol-mail/',
#  'https://www.mon-business-en-ligne.com/les-implications-juridiques-de-la-realisation-dun-test-adn-en-france/',
#  'https://www.mon-business-en-ligne.com/obtenir-des-conseils-juridiques-comment-acceder-a-lexpertise-dun-avocat/',
#  'https://www.mon-business-en-ligne.com/decouvrir-et-choisir-les-opportunites-deducation-dans-la-capitale-francaise/',
#  'https://www.mon-business-en-ligne.com/ameliorer-lefficacite-au-travail-strategies-et-astuces-pratiques/',
#  'https://www.mon-business-en-ligne.com/huggies-et-pampers-deux-marques-deux-univers-un-choix-difficile-pour-les-parents/',
#  'https://www.mon-business-en-ligne.com/comment-bien-entretenir-votre-utilitaire-de-location-dentreprise/',
#  'https://www.mon-business-en-ligne.com/les-opportunites-de-financement-et-daccompagnement-juridique-pour-les-entrepreneurs-decouvrez-les-aides-et-subventions-pour-les-entreprises/',
#  'https://www.mon-business-en-ligne.com/pourquoi-confier-la-fabrication-sur-mesure-de-vos-quincailleries-pour-vos-chantiers/',
#  'https://www.mon-business-en-ligne.com/comment-choisir-un-statut-pour-son-entreprise/',
#  'https://www.mon-business-en-ligne.com/comment-construire-lidentite-dune-marque/',
#  'https://www.mon-business-en-ligne.com/comment-faire-pour-mieux-vendre/',
#  'https://www.mon-business-en-ligne.com/comment-rediger-les-statuts-dune-societe/',
#  'https://www.mon-business-en-ligne.com/octime-salarie-connexion-se-connecter-a-son-compte/',
#  'https://www.mon-business-en-ligne.com/comment-faire-pour-creer-un-lien-internet/',
#  'https://www.mon-business-en-ligne.com/comment-calculer-le-nombre-daction-dune-entreprise/',
#  'https://www.mon-business-en-ligne.com/chauffage-entreprise-meilleurs-systemes-et-criteres-de-selection-2023/',
#  'https://www.mon-business-en-ligne.com/pourquoi-les-entrepreneurs-sont-ils-necessaires-au-fonctionnement-de-leconomie/',
#  'https://www.mon-business-en-ligne.com/astuces-pour-reussir-sa-communication-avec-un-stylo-4-couleurs-personnalise/',
#  'https://www.mon-business-en-ligne.com/les-desavantages-caches-du-portage-salarial-decryptage/',
#  'https://www.mon-business-en-ligne.com/flux-logistique-en-entreprise-definition-et-importance-strategique/',
#  'https://www.mon-business-en-ligne.com/comment-realiser-une-etude-de-faisabilite-dun-projet/',
#  'https://www.mon-business-en-ligne.com/comment-faire-un-bilan-de-competences-gratuit/',
#  'https://www.mon-business-en-ligne.com/emploi-municipal-demarches-et-astuces-pour-integrer-une-mairie/',
#  'https://www.mon-business-en-ligne.com/parcours-du-combattant-ou-aventure-passionnante-les-etapes-cles-de-la-creation-dentreprise-decortiquees/',
#  'https://www.mon-business-en-ligne.com/annulation-bon-de-commande-signe-demarches-et-conseils-pratiques/',
#  'https://www.mon-business-en-ligne.com/mutation-professionnelle-forcee-vos-droits-face-a-lemployeur/',
#  'https://www.mon-business-en-ligne.com/comment-transformer-ses-prospects-en-clients-grace-aux-goodies/',
#  'https://www.mon-business-en-ligne.com/controler-et-ameliorer-la-qualite-des-livraisons-e-commerce/',
#  'https://www.mon-business-en-ligne.com/comment-devenir-franchiseur/',
#  'https://www.mon-business-en-ligne.com/comprendre-les-etapes-cles-pour-realiser-son-reve-professionnel-dans-le-secteur-de-la-petite-enfance/',
#  'https://www.mon-business-en-ligne.com/resolution-des-litiges-en-transport-de-marchandises-conseils-et-strategies/',
#  'https://www.mon-business-en-ligne.com/ameliorer-lexperience-devenements-dentreprise-grace-a-une-signaletique-appropriee/',
#  'https://www.mon-business-en-ligne.com/strategie-de-copywriting-comprendre-la-definition-pour-reussir/',
#  'https://www.mon-business-en-ligne.com/quelles-sont-les-caracteristiques-a-privilegier-pour-des-chaussures-de-securite-confortables/',
#  'https://www.mon-business-en-ligne.com/quest-ce-quil-faut-savoir-pour-developper-les-talents-a-paris-a-travers-dun-bilan-de-competences/',
#  'https://www.mon-business-en-ligne.com/les-constructeurs-de-camions-et-remorques-magasins-une-solution-cle-en-main-pour-votre-commerce-mobile/',
#  'https://www.mon-business-en-ligne.com/fermeture-entreprise-rapide-demarches-et-consequences-legales/',
#  'https://www.mon-business-en-ligne.com/contrats-de-travail-en-france-types-differences-et-choix-strategiques/',
#  'https://www.mon-business-en-ligne.com/accueil-telephonique-comment-renforcer-limage-de-marque-de-votre-entreprise/',
#  'https://www.mon-business-en-ligne.com/gestion-des-conges-et-absences-les-atouts-dun-logiciel-rh/',
#  'https://www.mon-business-en-ligne.com/limportance-et-les-enjeux-de-la-cybersecurite-pour-la-protection-des-donnees-des-paiements-et-de-la-propriete-intellectuelle/',
#  'https://www.mon-business-en-ligne.com/les-metiers-de-linterim-pourquoi-rencontrent-ils-autant-de-succes-les-entreprises/',
#  'https://www.mon-business-en-ligne.com/revenus-issus-du-dropshipping-realites-et-mythes/',
#  'https://www.mon-business-en-ligne.com/gestion-des-factures-impayees-pour-micro-entrepreneurs-astuces-et-solutions/',
#  'https://www.mon-business-en-ligne.com/la-data-intelligence-la-cle-pour-les-entreprises-qui-souhaitent-innover-et-devenir-plus-performantes/',
#  'https://www.mon-business-en-ligne.com/types-de-stocks-en-entreprise-optimisation-et-gestion-efficace/',
#  'https://www.mon-business-en-ligne.com/rupture-cdd-par-le-salarie-conditions-et-demarches-legales/',
#  'https://www.mon-business-en-ligne.com/les-avantages-douvrir-une-franchise-dans-le-secteur-chr-et-cuisine/',
#  'https://www.mon-business-en-ligne.com/les-serveurs-vocaux-le-nouvel-outil-de-communication-des-entreprises/',
#  'https://www.mon-business-en-ligne.com/eft-vs-ach-vs-cheque-electronique-optimisez-les-paiements-de-votre-entreprise/',
#  'https://www.mon-business-en-ligne.com/obstacles-courants-en-prospection-b2b-comment-les-surmonter/',
#  'https://www.mon-business-en-ligne.com/faites-appel-a-un-bureau-detude-electrique-et-electronique-pour-le-succes-de-votre-projet/',
#  'https://www.mon-business-en-ligne.com/aide-a-domicile-en-micro-entreprise-conseils-et-etapes-pour-reussir-votre-lancement/',
#  'https://www.mon-business-en-ligne.com/parfaire-la-pose-de-votre-papier-peint-une-marche-a-suivre-detaillee/',
#  'https://www.mon-business-en-ligne.com/acheter-des-palettes-en-bois-pour-votre-business-pourquoi-et-comment-faire-appel-a-un-specialiste/',
#  'https://www.mon-business-en-ligne.com/choisissez-une-plateforme-cse-adaptee-aux-besoins-de-vos-salaries/',
#  'https://www.mon-business-en-ligne.com/pourquoi-choisir-une-agence-powerpoint-pour-des-presentations-reussies-et-innovantes/',
#  'https://www.mon-business-en-ligne.com/quelles-sont-les-fonctionnalites-meconnues-de-linkedin/',
#  'https://www.mon-business-en-ligne.com/organisation-et-choix-de-la-soiree-dentreprise-linteret-de-faire-appel-a-une-agence-devenementiel/',
#  'https://www.mon-business-en-ligne.com/tva-reel-simplifie-le-regime-reel-simplifie-explique/',
#  'https://www.mon-business-en-ligne.com/devenir-son-propre-patron-en-toute-serenite-grace-au-statut-dauto-entrepreneur/',
#  'https://www.mon-business-en-ligne.com/comment-se-deroule-une-domiciliation-en-ligne/',
#  'https://www.mon-business-en-ligne.com/comment-fonctionne-une-alarme-de-porte-principes-de-base-et-technologie-derriere-la-securite-domiciliaire/',
#  'https://www.mon-business-en-ligne.com/reglementation-cosmetique-en-europe-les-points-cles-a-retenir/',
#  'https://www.mon-business-en-ligne.com/votre-distributeur-microsoft-de-confiance-high-tech/',
#  'https://www.mon-business-en-ligne.com/les-erreurs-a-eviter-lors-de-la-creation-dune-boutique-de-cbd/',
#  'https://www.mon-business-en-ligne.com/quelle-methode-est-utilisee-pour-verifier-lintegrite-des-donnees-techniques-de-verification-des-donnees-et-de-la-securite-de-linformation/',
#  'https://www.mon-business-en-ligne.com/location-dune-mini-pelle-pour-des-travaux-ponctuels-sur-quoi-etre-regardant/',
#  'https://www.mon-business-en-ligne.com/quel-est-le-but-dun-restaurant/',
#  'https://www.mon-business-en-ligne.com/comment-supprimer-une-association-loi-1901/',
#  'https://www.mon-business-en-ligne.com/les-avantages-du-diplome-advf-pour-vos-clients/',
#  'https://www.mon-business-en-ligne.com/maximiser-lefficacite-du-marketing-grace-a-la-personnalisation-une-strategie-incontournable/',
#  'https://www.mon-business-en-ligne.com/comment-creer-un-site-e-commerce/',
#  'https://www.mon-business-en-ligne.com/comment-faire-la-promotion-dune-association/',
#  'https://www.mon-business-en-ligne.com/pourquoi-letat-aide-les-entreprises/',
#  'https://www.mon-business-en-ligne.com/comment-choisir-un-statut-pour-son-entreprise/',
#  'https://www.mon-business-en-ligne.com/comment-construire-lidentite-dune-marque/',
#  'https://www.mon-business-en-ligne.com/comment-faire-pour-mieux-vendre/',
#  'https://www.mon-business-en-ligne.com/comment-rediger-les-statuts-dune-societe/',
#  'https://www.mon-business-en-ligne.com/octime-salarie-connexion-se-connecter-a-son-compte/',
#  'https://www.mon-business-en-ligne.com/comment-faire-pour-creer-un-lien-internet/',
#  'https://www.mon-business-en-ligne.com/comment-calculer-le-nombre-daction-dune-entreprise/',
#  'https://www.mon-business-en-ligne.com/comment-choisir-son-assurance-professionnelle/',
#  'https://www.mon-business-en-ligne.com/quelle-est-la-base-de-la-communication-en-entreprise/',
#  'https://www.mon-business-en-ligne.com/comment-definir-une-strategie-dacquisition-client/',
#  'https://www.mon-business-en-ligne.com/gerer-les-conflits-en-milieu-professionnel-astuces-pour-une-resolution-efficace/',
#  'https://www.mon-business-en-ligne.com/les-strategies-gagnantes-pour-une-collaboration-a-distance-efficace/',
#  'https://www.mon-business-en-ligne.com/la-strategie-imparable-pour-booster-la-visibilite-de-votre-entreprise-grace-aux-reseaux-sociaux/',
#  'https://www.mon-business-en-ligne.com/les-meilleures-strategies-pour-favoriser-linnovation-en-entreprise/',
#  'https://www.mon-business-en-ligne.com/les-recentes-evolutions-du-droit-des-entreprises-et-leur-influence-sur-les-activites-commerciales/',
#  'https://www.mon-business-en-ligne.com/les-dernieres-tendances-en-matiere-de-gestion-dentreprise-a-connaitre/',
#  'https://www.mon-business-en-ligne.com/les-cles-pour-une-communication-marketing-reussie-et-une-image-de-marque-forte/',
#  'https://www.mon-business-en-ligne.com/10-astuces-pour-reussir-son-entretien-dembauche-dans-le-secteur-tech/',
#  'https://www.mon-business-en-ligne.com/les-divers-contrats-indispensables-pour-lorganisation-en-entreprise/',
#  'https://www.mon-business-en-ligne.com/comprendre-les-distinctions-entre-le-contrat-de-travail-a-duree-determinee-et-le-contrat-a-duree-indeterminee/',
#  'https://www.mon-business-en-ligne.com/limportance-cruciale-de-la-communication-interne-dans-la-cohesion-dune-entreprise/',
#  'https://www.mon-business-en-ligne.com/les-meilleures-strategies-pour-renforcer-lengagement-des-entreprises-envers-la-responsabilite-sociale/',
#  'https://www.mon-business-en-ligne.com/la-carte-t-pour-travailler-dans-limmobilier/',
#  'https://www.mon-business-en-ligne.com/les-atouts-du-marketing-dinfluence-pour-booster-la-visibilite-de-son-entreprise/',
#  'https://www.mon-business-en-ligne.com/le-depot-de-marque-la-cle-pour-securiser-votre-propriete-intellectuelle-en-entreprise/',
#  'https://www.mon-business-en-ligne.com/quel-logiciel-utiliser-quand-on-est-comptable/',
#  'https://www.mon-business-en-ligne.com/les-etapes-essentielles-pour-lancer-sa-propre-entreprise/',
#  'https://www.mon-business-en-ligne.com/comment-gerer-la-conformite-fiscale-et-reglementaire-de-votre-entreprise/',
#  'https://www.mon-business-en-ligne.com/les-dernieres-evolutions-du-coworking-et-des-espaces-de-travail-partages-a-connaitre-absolument/',
#  'https://www.mon-business-en-ligne.com/slack-logiciel-de-productivite-entreprise-collaboratif/',
#  'https://www.mon-business-en-ligne.com/comment-gagner-en-efficacite-et-en-productivite-en-entreprise/',
#  'https://www.mon-business-en-ligne.com/les-elements-cles-dune-charte-graphique-pour-un-site-internet-professionnel/',
#  'https://www.mon-business-en-ligne.com/les-regles-essentielles-pour-une-gestion-efficace-des-salaries-en-entreprise/',
#  'https://www.mon-business-en-ligne.com/logistique-dentreprise-6-raisons-de-bien-preparer-les-commandes-dans-les-entrepots/',
#  'https://www.mon-business-en-ligne.com/optimisez-la-gestion-de-votre-flotte-grace-a-un-logiciel-de-geolocalisation/',
#  'https://www.mon-business-en-ligne.com/les-secrets-pour-un-accueil-physique-haut-de-gamme-reussi-en-ile-de-france/',
#  'https://www.mon-business-en-ligne.com/les-cles-du-succes-pour-le-marketing-digital-des-pme/',
#  'https://www.mon-business-en-ligne.com/optimisez-vos-ventes-avec-linfluence-marketing-les-cles-du-succes-pour-votre-entreprise/',
#  'https://www.mon-business-en-ligne.com/lachat-dun-bar-demande-laccompagnement-dune-agence-immobiliere-specialisee/',
#  'https://www.mon-business-en-ligne.com/comment-le-rfid-peut-aider-votre-entreprise/',
#  'https://www.mon-business-en-ligne.com/tout-savoir-sur-la-protection-des-donnees-personnelles-en-entreprise/',
#  'https://www.mon-business-en-ligne.com/fournisseur-de-gaz-pour-professionnels-3-criteres-pour-bien-choisir/',
#  'https://www.mon-business-en-ligne.com/quel-est-le-role-des-chaussures-de-securite-dans-la-prevention-des-accidents-professionnels/',
#  'https://www.mon-business-en-ligne.com/les-nouvelles-tendances-du-marketing-digital-en-entreprise-ce-qui-fonctionne-aujourdhui/',
#  'https://www.mon-business-en-ligne.com/comment-creer-un-lien-pour-un-questionnaire/',
#  'https://www.mon-business-en-ligne.com/decouvrez-les-avantages-de-rejoindre-une-franchise-donuts-en-france/',
#  'https://www.mon-business-en-ligne.com/proteger-efficacement-les-donnees-personnelles-en-milieu-professionnel-guide-et-meilleures-pratiques/',
#  'https://www.mon-business-en-ligne.com/les-defis-incontournables-de-la-transition-numerique-des-entreprises/',
#  'https://www.mon-business-en-ligne.com/limpact-de-la-personnalisation-dans-le-marketing-et-les-meilleures-strategies-a-adopter-pour-lappliquer-dans-votre-entreprise/',
#  'https://www.mon-business-en-ligne.com/limpact-de-la-culture-dentreprise-sur-la-performance-des-entreprises/',
#  'https://www.mon-business-en-ligne.com/optimisez-votre-presence-en-ligne-pour-attirer-de-nouveaux-clients-avec-ces-conseils-incontournables/',
#  'https://www.mon-business-en-ligne.com/decouvrez-la-technologie-pampers-pour-vos-bebes/',
#  'https://www.mon-business-en-ligne.com/les-avantages-de-choisir-une-solution-logistique-e-commerce-pour-votre-entreprise/',
#  'https://www.mon-business-en-ligne.com/les-points-forts-et-faiblesses-du-management-participatif/',
#  'https://www.mon-business-en-ligne.com/du-salariat-a-lentrepreneuriat-comment-reussir-sa-transition-avec-le-cumul-cdi-et-freelance/',
#  'https://www.mon-business-en-ligne.com/les-astuces-pour-maintenir-une-rentabilite-durable-dans-votre-bar-restaurant/',
#  'https://www.mon-business-en-ligne.com/comment-optimiser-le-referencement-de-votre-agence-immobiliere-en-ligne/',
#  'https://www.mon-business-en-ligne.com/les-specificites-des-statuts-juridiques-dune-entreprise-et-leur-impact-sur-votre-activite/',
#  'https://www.mon-business-en-ligne.com/comment-se-preparer-efficacement-grace-aux-formations-obligatoires-pour-lancer-son-entreprise/',
#  'https://www.mon-business-en-ligne.com/assurance-professionnelle-quand-est-il-recommande-de-souscrire/',
#  'https://www.mon-business-en-ligne.com/les-avantages-davoir-un-pont-roulant-dans-votre-entreprise/',
#  'https://www.mon-business-en-ligne.com/les-differents-types-de-sites-internet-professionnels-adaptes-a-angers/',
#  'https://www.mon-business-en-ligne.com/profitez-de-lexpertise-des-grands-groupes-pour-acheter-du-materiel-neuf-pour-btp/',
#  'https://www.mon-business-en-ligne.com/les-meilleures-strategies-pour-mener-a-bien-sa-transformation-digitale-en-entreprise-2/',
#  'https://www.mon-business-en-ligne.com/les-strategies-incontournables-pour-une-campagne-publicitaire-reussie/',
#  'https://www.mon-business-en-ligne.com/les-5-forces-de-porter-et-leur-impact-sur-votre-entreprise/',
#  'https://www.mon-business-en-ligne.com/quelle-est-limportance-de-deposer-un-nom-de-marque/',
#  'https://www.mon-business-en-ligne.com/comment-choisir-un-statut-pour-son-entreprise/',
#  'https://www.mon-business-en-ligne.com/comment-construire-lidentite-dune-marque/',
#  'https://www.mon-business-en-ligne.com/comment-faire-pour-mieux-vendre/',
#  'https://www.mon-business-en-ligne.com/comment-rediger-les-statuts-dune-societe/',
#  'https://www.mon-business-en-ligne.com/octime-salarie-connexion-se-connecter-a-son-compte/',
#  'https://www.mon-business-en-ligne.com/comment-faire-pour-creer-un-lien-internet/',
#  'https://www.mon-business-en-ligne.com/comment-calculer-le-nombre-daction-dune-entreprise/',
#  'https://www.mon-business-en-ligne.com/les-enjeux-des-relations-entre-une-entreprise-et-ses-partenaires-clients-fournisseurs-et-associes/',
#  'https://www.mon-business-en-ligne.com/creez-une-identite-visuelle-percutante-avec-une-enseigne-lumineuse-personnalisee/',
#  'https://www.mon-business-en-ligne.com/trouver-un-emploi-a-bayonne-conseils-et-astuces-pour-reussir-sa-recherche/',
#  'https://www.mon-business-en-ligne.com/comment-creer-et-maintenir-une-image-de-marque-forte-grace-a-une-bonne-communication-externe/',
#  'https://www.mon-business-en-ligne.com/les-regles-incontournables-pour-assurer-la-securite-au-travail/',
#  'https://www.mon-business-en-ligne.com/les-aspects-negatifs-du-portage-salarial-a-prendre-en-compte/',
#  'https://www.mon-business-en-ligne.com/comment-simuler-votre-revenu-en-portage-salarial-a-lille-pour-prendre-des-decisions-eclairees/',
#  'https://www.mon-business-en-ligne.com/comment-se-differencier-de-la-concurrence-avec-sa-marque-de-sac-a-main/',
#  'https://www.mon-business-en-ligne.com/les-differentes-sources-de-financement-pour-votre-projet-douverture-de-boulangerie/',
#  'https://www.mon-business-en-ligne.com/pourquoi-recourir-a-une-agence-de-content-marketing/',
#  'https://www.mon-business-en-ligne.com/comment-la-pandemie-covid-19-a-affecte-les-entreprises/',
#  'https://www.mon-business-en-ligne.com/formalites-juridiques-pour-creer-et-fermer-une-entreprise-conseils-et-pieges-a-eviter/',
#  'https://www.mon-business-en-ligne.com/les-pieges-a-eviter-lors-de-la-souscription-dune-assurance-professionnelle-3/',
#  'https://www.mon-business-en-ligne.com/les-pieges-a-eviter-lors-de-la-souscription-dune-assurance-professionnelle-2/',
#  'https://www.mon-business-en-ligne.com/les-pieges-a-eviter-lors-de-la-souscription-dune-assurance-professionnelle/',
#  'https://www.mon-business-en-ligne.com/les-cles-de-la-diversite-et-de-linclusion-dans-le-milieu-professionnel-3/',
#  'https://www.mon-business-en-ligne.com/les-cles-de-la-diversite-et-de-linclusion-dans-le-milieu-professionnel/',
#  'https://www.mon-business-en-ligne.com/optimiser-son-site-web-pour-un-meilleur-referencement-et-un-trafic-qualifie-accru-les-meilleures-pratiques-a-adopter/',
#  'https://www.mon-business-en-ligne.com/3-astuces-pour-valoriser-votre-marque-lors-de-lexpedition-de-vos-produits/',
#  'https://www.mon-business-en-ligne.com/les-coulisses-de-la-fabrication-des-couches-pampers/',
#  'https://www.mon-business-en-ligne.com/agenda-en-ligne-un-outil-facile-et-pratique/',
#  'https://www.mon-business-en-ligne.com/boostez-votre-visibilite-sur-les-reseaux-sociaux-grace-a-ces-astuces-infaillibles/',
#  'https://www.mon-business-en-ligne.com/comment-publier-des-annonces-legales-pour-mon-entreprise/',
#  'https://www.mon-business-en-ligne.com/tout-savoir-sur-le-calcul-de-son-salaire-brut-en-net/',
#  'https://www.mon-business-en-ligne.com/decouvrez-les-dernieres-strategies-marketing-pour-augmenter-vos-ventes/',
#  'https://www.mon-business-en-ligne.com/les-competences-indispensables-pour-reussir-dans-la-creation-et-lorganisation-devenements/',
#  'https://www.mon-business-en-ligne.com/comment-rompre-un-contrat-davenir/',
#  'https://www.mon-business-en-ligne.com/les-meilleures-methodes-de-marketing-digital-pour-booster-votre-entreprise/',
#  'https://www.mon-business-en-ligne.com/comment-negocier-avec-un-traiteur-pour-obtenir-le-meilleur-tarif-pour-votre-soiree/',
#  'https://www.mon-business-en-ligne.com/les-materiaux-utilises-dans-la-fabrication-des-couches-pampers-une-garantie-de-qualite/',
#  'https://www.mon-business-en-ligne.com/les-strategies-innovantes-de-marketing-digital-pour-dynamiser-votre-entreprise/',
#  'https://www.mon-business-en-ligne.com/pourquoi-la-mediation-en-entreprise/',
#  'https://www.mon-business-en-ligne.com/boostez-vos-resultats-marketing-avec-lintegration-typeform/',
#  'https://www.mon-business-en-ligne.com/developper-le-sens-entrepreunarial-de-vos-adolescents/',
#  'https://www.mon-business-en-ligne.com/quelles-sont-les-etapes-pour-creer-sa-propre-agence-web/',
#  'https://www.mon-business-en-ligne.com/la-responsabilite-civile-des-dirigeants-dentreprise-decryptage-et-consequences-impactantes/',
#  'https://www.mon-business-en-ligne.com/les-cles-pour-faire-le-bon-choix-dassurance-entreprise/',
#  'https://www.mon-business-en-ligne.com/les-benefices-de-la-diversite-et-de-linclusion-en-entreprise/',
#  'https://www.mon-business-en-ligne.com/les-obligations-legales-et-fiscales-essentielles-pour-les-entrepreneurs-a-connaitre/',
#  'https://www.mon-business-en-ligne.com/les-criteres-a-prendre-en-compte-pour-selectionner-un-grossiste-voopoo/',
#  'https://www.mon-business-en-ligne.com/les-dispositifs-les-plus-populaires-dans-lassortiment-des-grossistes-de-cigarettes-electroniques-professionnels/',
#  'https://www.mon-business-en-ligne.com/les-cles-pour-decrocher-un-emploi-rapidement-dans-un-marche-competitif/',
#  'https://www.mon-business-en-ligne.com/a-quoi-sert-une-etiquette-de-rouleau-thermique/',
#  'https://www.mon-business-en-ligne.com/les-bases-essentielles-pour-assurer-la-protection-de-vos-donnees-personnelles/',
#  'https://www.mon-business-en-ligne.com/comment-gerer-une-entreprise-industrielle/',
#  'https://www.mon-business-en-ligne.com/pme-pourquoi-faire-appel-a-un-expert-informatique/',
#  'https://www.mon-business-en-ligne.com/les-meilleures-pratiques-pour-maximiser-lefficacite-de-votre-logiciel-de-phoning/',
#  'https://www.mon-business-en-ligne.com/les-differents-types-dassurance-pro-quelles-sont-les-specificites-de-chacune/',
#  'https://www.mon-business-en-ligne.com/les-materiaux-recommandes-pour-les-mugs-personnalises/',
#  'https://www.mon-business-en-ligne.com/les-fondamentaux-juridiques-du-marketing-et-de-la-publicite-ce-quil-faut-savoir/',
#  'https://www.mon-business-en-ligne.com/des-experts-guident-les-entreprises-pour-repondre-aux-normes-iso-9001-14001-45001/',
#  'https://www.mon-business-en-ligne.com/lelevage-porcin-et-limportance-du-materiel-agricole-professionnel/',
#  'https://www.mon-business-en-ligne.com/les-formes-de-contrats-commerciaux-et-leurs-specificites-juridiques-un-guide-complet-pour-les-entrepreneurs/',
#  'https://www.mon-business-en-ligne.com/les-cles-dune-strategie-marketing-performante-pour-votre-entreprise/',
#  'https://www.mon-business-en-ligne.com/comment-choisir-entre-une-sas-et-une-sasu/',
#  'https://www.mon-business-en-ligne.com/les-differents-types-dentreprises-et-leur-raison-sociale/',
#  'https://www.mon-business-en-ligne.com/les-cles-pour-augmenter-le-trafic-cible-sur-votre-site-ecommerce/',
#  'https://www.mon-business-en-ligne.com/comment-etablir-un-plan-financier-solide-pour-louverture-de-votre-salon-de-coiffure/',
#  'https://www.mon-business-en-ligne.com/les-innovations-technologiques-qui-transforment-les-entreprises/',
#  'https://www.mon-business-en-ligne.com/optimiser-ses-resultats-les-cles-pour-mesurer-lefficacite-de-ses-actions-marketing/',
#  'https://www.mon-business-en-ligne.com/comment-choisir-un-statut-pour-son-entreprise/',
#  'https://www.mon-business-en-ligne.com/comment-construire-lidentite-dune-marque/',
#  'https://www.mon-business-en-ligne.com/comment-faire-pour-mieux-vendre/',
#  'https://www.mon-business-en-ligne.com/comment-rediger-les-statuts-dune-societe/',
#  'https://www.mon-business-en-ligne.com/octime-salarie-connexion-se-connecter-a-son-compte/',
#  'https://www.mon-business-en-ligne.com/comment-faire-pour-creer-un-lien-internet/',
#  'https://www.mon-business-en-ligne.com/comment-calculer-le-nombre-daction-dune-entreprise/',
#  'https://www.mon-business-en-ligne.com/la-cle-du-succes-cultiver-une-culture-dentreprise-forte-et-motivante/',
#  'https://www.mon-business-en-ligne.com/opportunites-de-financement-dentreprise-en-2023-les-solutions-de-court-terme/',
#  'https://www.mon-business-en-ligne.com/choisir-les-canaux-de-communication-les-plus-efficaces-pour-cibler-votre-audience-en-b2b/',
#  'https://www.mon-business-en-ligne.com/comment-gerer-efficacement-votre-comptabilite-en-abc-portage-salarial/',
#  'https://www.mon-business-en-ligne.com/les-pieges-juridiques-a-eviter-absolument-en-tant-quentrepreneur/',
#  'https://www.mon-business-en-ligne.com/que-couvre-une-assurance-local-professionnel-concretement/',
#  'https://www.mon-business-en-ligne.com/les-etapes-cles-pour-construire-une-identite-de-marque-puissante-pour-votre-entreprise/',
#  'https://www.mon-business-en-ligne.com/decryptage-des-dernieres-evolutions-du-marketing-digital-en-entreprise/',
#  'https://www.mon-business-en-ligne.com/call-center-les-avantages-davoir-un-logiciel-dedie/',
#  'https://www.mon-business-en-ligne.com/les-defis-de-la-transition-ecologique-pour-les-entreprises/',
#  'https://www.mon-business-en-ligne.com/les-meilleures-adresses-de-grossistes-pour-acheter-une-cigarette-electronique-pas-cher/',
#  'https://www.mon-business-en-ligne.com/le-developpement-durable-un-atout-majeur-pour-les-entreprises/',
#  'https://www.mon-business-en-ligne.com/les-questions-frequemment-posees-lors-dun-entretien-pour-un-poste-de-vendeur-en-cigarette-electronique/',
#  'https://www.mon-business-en-ligne.com/les-astuces-pour-optimiser-lespace-sous-son-evier-achete-chez-leroy-merlin/',
#  'https://www.mon-business-en-ligne.com/les-cles-de-la-reussite-des-startups-les-plus-innovantes-actuellement/',
#  'https://www.mon-business-en-ligne.com/travail-a-distance-obligations-de-lemployeur-et-du-salarie-pour-assurer-la-securite/',
#  'https://www.mon-business-en-ligne.com/les-principaux-devoirs-juridiques-en-matiere-de-gestion-des-ressources-humaines/',
#  'https://www.mon-business-en-ligne.com/comment-minimiser-les-couts-tout-en-maximisant-la-couverture-dassurance-pour-votre-entreprise/',
#  'https://www.mon-business-en-ligne.com/les-meilleures-strategies-pour-stimuler-la-croissance-et-le-developpement-des-startups/',
#  'https://www.mon-business-en-ligne.com/5-raisons-de-faire-appel-a-un-cabinet-dexpertise-comptable/',
#  'https://www.mon-business-en-ligne.com/le-portage-salarial-une-solution-pour-les-retraites-actifs/',
#  'https://www.mon-business-en-ligne.com/les-erreurs-a-eviter-lors-du-choix-de-votre-fournisseur-demballage-a-lyon/',
#  'https://www.mon-business-en-ligne.com/les-secrets-dune-prospection-commerciale-efficace-reveles/',
#  'https://www.mon-business-en-ligne.com/les-meilleures-pratiques-pour-gerer-les-contrats-en-entreprise/',
#  'https://www.mon-business-en-ligne.com/heineken-la-biere-virtuelle-a-la-pointe-de-la-technologie/',
#  'https://www.mon-business-en-ligne.com/3-strategies-de-marketing-digital-pour-demarrer-votre-business-2/',
#  'https://www.mon-business-en-ligne.com/comment-enregistrer-un-bon-dachat/',
#  'https://www.mon-business-en-ligne.com/comment-creer-un-plan-de-communication-efficace/',
#  'https://www.mon-business-en-ligne.com/les-strategies-gagnantes-du-marketing-de-contenu-pour-fideliser-et-captiver-votre-audience/',
#  'https://www.mon-business-en-ligne.com/les-obligations-juridiques-dun-chef-dentreprise-ce-que-vous-devez-savoir/',
#  'https://www.mon-business-en-ligne.com/optimisez-votre-reussite-professionnelle-grace-au-developpement-personnel/',
#  'https://www.mon-business-en-ligne.com/decouvrez-les-dernieres-tendances-en-rse-pour-les-entreprises/',
#  'https://www.mon-business-en-ligne.com/boostez-votre-entreprise-avec-une-culture-dentreprise-positive-et-motivante/',
#  'https://www.mon-business-en-ligne.com/comment-reconnaitre-une-bonne-auto-ecole/',
#  'https://www.mon-business-en-ligne.com/les-astuces-pour-rendre-un-compte-rendu-plus-attractif/',
#  'https://www.mon-business-en-ligne.com/les-dernieres-evolutions-du-teletravail-decouvrez-les-tendances-a-ne-pas-manquer/',
#  'https://www.mon-business-en-ligne.com/quels-sont-les-avantages-dune-solution-cloud/',
#  'https://www.mon-business-en-ligne.com/optimisez-la-communication-interne-au-sein-de-votre-entreprise-grace-a-ces-astuces/',
#  'https://www.mon-business-en-ligne.com/les-cles-pour-une-campagne-publicitaire-percutante-et-rentable/',
#  'https://www.mon-business-en-ligne.com/les-bonnes-raisons-doffrir-des-goodies-publicitaires/',
#  'https://www.mon-business-en-ligne.com/optimisez-votre-strategie-marketing-en-entreprise-avec-les-tendances-actuelles/',
#  'https://www.mon-business-en-ligne.com/promouvoir-la-diversite-en-entreprise-un-atout-majeur-pour-la-performance-et-linnovation/',
#  'https://www.mon-business-en-ligne.com/comment-mettre-en-valeur-ses-competences-professionnelles-sur-son-cv/',
#  'https://www.mon-business-en-ligne.com/les-specificites-des-vetements-de-travail-pour-les-metiers-de-lindustrie/',
#  'https://www.mon-business-en-ligne.com/decouvrez-les-approches-innovantes-pour-la-formation-et-le-developpement-des-competences-en-entreprise/',
#  'https://www.mon-business-en-ligne.com/comprendre-les-types-de-societes-et-leurs-modes-de-creation-pour-mieux-entreprendre/',
#  'https://www.mon-business-en-ligne.com/le-metaverse-un-concept-revolutionnaire-pour-notre-interaction-en-ligne/',
#  'https://www.mon-business-en-ligne.com/les-cles-dune-strategie-de-communication-reussie/',
#  'https://www.mon-business-en-ligne.com/innovation-et-disruption-les-entreprises-revolutionnaires-qui-transforment-leur-secteur/',
#  'https://www.mon-business-en-ligne.com/redynamiser-votre-entreprise-grace-a-des-techniques-de-marketing-innovantes/',
#  'https://www.mon-business-en-ligne.com/les-forces-et-faiblesses-du-marketing-traditionnel-et-digital-pour-les-entreprises/',
#  'https://www.mon-business-en-ligne.com/levolution-du-prix-de-lor-et-linflation-lors-du-covid-19/',
#  'https://www.mon-business-en-ligne.com/comment-mettre-en-place-la-facturation-electronique-dans-votre-entreprise/',
#  'https://www.mon-business-en-ligne.com/la-montee-en-puissance-des-entreprises-responsables-impact-environnemental-et-transformation-du-paysage-economique/',
#  'https://www.mon-business-en-ligne.com/pourquoi-le-videoprojecteur-est-un-outil-indispensable-pour-les-enseignants/',
#  'https://www.mon-business-en-ligne.com/les-obligations-legales-essentielles-pour-les-entreprises-connaitre-ses-responsabilites/',
#  'https://www.mon-business-en-ligne.com/les-alternatives-peu-couteuses-aux-panneaux-publicitaires-classiques/',
#  'https://www.mon-business-en-ligne.com/les-strategies-efficaces-pour-une-gestion-dentreprise-performante/',
#  'https://www.mon-business-en-ligne.com/3-strategies-de-marketing-digital-pour-demarrer-votre-business/',
#  'https://www.mon-business-en-ligne.com/boostez-votre-taux-de-conversion-de-prospects-a-clients-grace-a-des-strategies-marketing-eprouvees/',
#  'https://www.mon-business-en-ligne.com/comment-choisir-un-statut-pour-son-entreprise/',
#  'https://www.mon-business-en-ligne.com/comment-construire-lidentite-dune-marque/',
#  'https://www.mon-business-en-ligne.com/comment-faire-pour-mieux-vendre/',
#  'https://www.mon-business-en-ligne.com/comment-rediger-les-statuts-dune-societe/',
#  'https://www.mon-business-en-ligne.com/octime-salarie-connexion-se-connecter-a-son-compte/',
#  'https://www.mon-business-en-ligne.com/comment-faire-pour-creer-un-lien-internet/',
#  'https://www.mon-business-en-ligne.com/comment-calculer-le-nombre-daction-dune-entreprise/',
#  'https://www.mon-business-en-ligne.com/des-boites-en-carton-pour-stocker-et-livrer-des-produits/',
#  'https://www.mon-business-en-ligne.com/les-benefices-et-limites-de-lautomatisation-en-marketing/',
#  'https://www.mon-business-en-ligne.com/comment-eviter-les-elements-nuisibles-pour-le-bon-referencement-de-votre-site-web/',
#  'https://www.mon-business-en-ligne.com/creation-de-contenus-attractifs-pour-generer-des-leads-qualifies-guide-ultime/',
#  'https://www.mon-business-en-ligne.com/quelles-sont-les-actions-marketing-les-plus-efficaces/',
#  'https://www.mon-business-en-ligne.com/gestion-commerciale-en-entreprise-maitriser-les-formalites-douanieres/',
#  'https://www.mon-business-en-ligne.com/imprimer-des-documents-en-toute-securite-les-garanties-a-privilegier/',
#  'https://www.mon-business-en-ligne.com/le-guide-des-cartes-bancaires-decouvrez-celle-qui-vous-convient-le-mieux/',
#  'https://www.mon-business-en-ligne.com/comment-le-kaizen-peut-ameliorer-votre-entreprise/',
#  'https://www.mon-business-en-ligne.com/quelles-sont-les-assurances-obligatoires-pour-les-entreprises/',
#  'https://www.mon-business-en-ligne.com/techniques-de-marketing-relationnel-efficaces-pour-fideliser-vos-clients/',
#  'https://www.mon-business-en-ligne.com/comment-choisir-son-logiciel-de-lead-nurturing-a-marseille/',
#  'https://www.mon-business-en-ligne.com/cest-quoi-le-statut-juridique-dune-entreprise/',
#  'https://www.mon-business-en-ligne.com/une-solution-denvoi-de-sms-en-masse-qui-convient-a-votre-budget/',
#  'https://www.mon-business-en-ligne.com/les-differents-types-de-cones-de-signalisation/',
#  'https://www.mon-business-en-ligne.com/expedition-des-marchandises-quel-type-de-palette-choisir/',
#  'https://www.mon-business-en-ligne.com/la-responsabilite-legale-des-dirigeants-dentreprise-ce-que-vous-devez-savoir/',
#  'https://www.mon-business-en-ligne.com/comptabilite-et-fiscalite-dentreprise-les-obligations-legales-a-respecter/',
#  'https://www.mon-business-en-ligne.com/comprendre-lincidence-de-votre-strategie-de-marketing-sur-les-ventes-de-votre-entreprise/',
#  'https://www.mon-business-en-ligne.com/pourquoi-acheter-un-mobilier-de-bureau-personnalisable/',
#  'https://www.mon-business-en-ligne.com/comprendre-la-difference-essentielle-entre-les-competences-et-les-experiences-professionnelles/',
#  'https://www.mon-business-en-ligne.com/les-enjeux-juridiques-a-connaitre-avant-de-creer-sa-propre-entreprise-ce-quil-faut-savoir-pour-se-lancer-sereinement/',
#  'https://www.mon-business-en-ligne.com/comment-une-agence-digitale-peut-elle-vous-aider-a-reussir-votre-strategie-sea/',
#  'https://www.mon-business-en-ligne.com/les-competences-les-plus-importantes-pour-une-evolution-de-carriere-reussie/',
#  'https://www.mon-business-en-ligne.com/la-biere-heineken-en-gros-comment-economiser-sur-vos-achats/',
#  'https://www.mon-business-en-ligne.com/les-regles-a-connaitre-sur-les-contrats-de-travail-temporaires-en-entreprise/',
#  'https://www.mon-business-en-ligne.com/comment-choisir-le-bon-avocat-en-droit-administratif-pour-votre-entreprise/',
#  'https://www.mon-business-en-ligne.com/pourquoi-faire-des-cartes-de-visites-avec-un-qr-code/',
#  'https://www.mon-business-en-ligne.com/le-delai-de-carence-a-pole-emploi-explications-rapides-et-utiles/',
#  'https://www.mon-business-en-ligne.com/comprendre-les-differentes-taxes-imposees-aux-entreprises-en-france/',
#  'https://www.mon-business-en-ligne.com/lisolation-pour-les-professionnels-en-quoi-ca-consiste/',
#  'https://www.mon-business-en-ligne.com/comment-linnovation-peut-ameliorer-les-performances-dune-entreprise/',
#  'https://www.mon-business-en-ligne.com/5-conseils-pour-ameliorer-votre-strategie-marketing-dentreprise/',
#  'https://www.mon-business-en-ligne.com/linnovation-une-cle-de-la-reussite-des-entreprises/',
#  'https://www.mon-business-en-ligne.com/droit-du-travail-en-entreprise-tout-ce-que-vous-devez-savoir-sur-les-relations-employeurs-employes-les-contrats-de-travail-et-les-licenciements/',
#  'https://www.mon-business-en-ligne.com/comment-faire-une-demande-de-lesta-usa/',
#  'https://www.mon-business-en-ligne.com/vtc-la-profession-du-futur/',
#  'https://www.mon-business-en-ligne.com/les-dernieres-technologies-qui-revolutionnent-les-entreprises/',
#  'https://www.mon-business-en-ligne.com/comment-creer-une-entreprise-prospere-et-durable-en-2021/',
#  'https://www.mon-business-en-ligne.com/quel-est-linteret-des-entreprises-de-posseder-des-panneaux-interdiction/',
#  'https://www.mon-business-en-ligne.com/enedis-la-nouvelle-entite-chargee-de-la-distribution-delectricite-en-france/',
#  'https://www.mon-business-en-ligne.com/comment-creer-une-entreprise-et-les-etapes-a-suivre/',
#  'https://www.mon-business-en-ligne.com/la-pandemie-mondiale-affecte-t-elle-le-monde-des-affaires/',
#  'https://www.mon-business-en-ligne.com/comment-developper-une-strategie-de-marketing-et-de-vente-pour-votre-entreprise/',
#  'https://www.mon-business-en-ligne.com/coronavirus-pas-de-quarantaine-pour-les-voyageurs-de-lespace-schengen/',
#  'https://www.mon-business-en-ligne.com/comment-creer-une-strategie-de-contenu-efficace-pour-les-entreprises/',
#  'https://www.mon-business-en-ligne.com/comment-choisir-le-bon-sac-papier-pour-son-commerce/',
#  'https://www.mon-business-en-ligne.com/comment-le-sms-marketing-peut-revolutionner-votre-entreprise/',
#  'https://www.mon-business-en-ligne.com/comment-reussir-son-arbre-de-noel-dentreprise/',
#  'https://www.mon-business-en-ligne.com/les-avantages-du-ab-testing-pour-augmenter-vos-conversions/',
#  'https://www.mon-business-en-ligne.com/comment-creer-une-organisation-efficace-pour-votre-travail/',
#  'https://www.mon-business-en-ligne.com/comment-se-connecter-a-facebook-et-respecter-les-termes-de-service-de-mailchimp/',
#  'https://www.mon-business-en-ligne.com/immatriculer-une-entreprise-les-etapes-incontournables/',
#  'https://www.mon-business-en-ligne.com/responsabilites-dune-meilleure-societe-dhebergement-web/',
#  'https://www.mon-business-en-ligne.com/comment-ouvrir-une-franchise-la-main-tendue/',
#  'https://www.mon-business-en-ligne.com/assurance-responsabilite-civile-pro-etes-vous-concerne-par-la-rc-pro/',
#  'https://www.mon-business-en-ligne.com/interview-video-en-quoi-peut-elle-propulser-en-avant-votre-entreprise/',
#  'https://www.mon-business-en-ligne.com/entreprise-place-et-importance-dun-service-client/',
#  'https://www.mon-business-en-ligne.com/quest-ce-que-lassurance-professionnelle/',
#  'https://www.mon-business-en-ligne.com/lutilisation-du-traceur-de-chantier-fluorescent/',
#  'https://www.mon-business-en-ligne.com/comment-choisir-un-statut-pour-son-entreprise/',
#  'https://www.mon-business-en-ligne.com/comment-construire-lidentite-dune-marque/',
#  'https://www.mon-business-en-ligne.com/comment-faire-pour-mieux-vendre/',
#  'https://www.mon-business-en-ligne.com/comment-rediger-les-statuts-dune-societe/',
#  'https://www.mon-business-en-ligne.com/octime-salarie-connexion-se-connecter-a-son-compte/',
#  'https://www.mon-business-en-ligne.com/comment-faire-pour-creer-un-lien-internet/',
#  'https://www.mon-business-en-ligne.com/comment-calculer-le-nombre-daction-dune-entreprise/',
#  'https://www.mon-business-en-ligne.com/la-gestion-dentreprise-un-enjeu-majeur-pour-les-pme/',
#  'https://www.mon-business-en-ligne.com/pas-de-strategie-de-visibilite-sans-redaction-web/',
#  'https://www.mon-business-en-ligne.com/pourquoi-investir-dans-une-jeune-entreprise/',
#  'https://www.mon-business-en-ligne.com/pourquoi-tout-entrepreneur-devrait-avoir-un-business-plan-pour-son-site-internet/',
#  'https://www.mon-business-en-ligne.com/tva-sur-encaissement-les-bases-comptable/',
#  'https://www.mon-business-en-ligne.com/des-journees-en-entreprise-pour-depister-les-cancers/',
#  'https://www.mon-business-en-ligne.com/quelle-assurance-choisir-pour-un-travailleur-independant/',
#  'https://www.mon-business-en-ligne.com/les-objets-publicitaires-les-plus-utilises/',
#  'https://www.mon-business-en-ligne.com/comment-augmenter-les-ventes-grace-a-une-conception-web-efficace/',
#  'https://www.mon-business-en-ligne.com/comment-publier-une-annonce-legale-eurl/',
#  'https://www.mon-business-en-ligne.com/quel-logiciel-utiliser-pour-mieux-gerer-les-temps-de-travail-des-salaries/',
#  'https://www.mon-business-en-ligne.com/pourquoi-utiliser-un-logiciel-de-gestion-des-atmp-et-ijss/',
#  'https://www.mon-business-en-ligne.com/quel-cfe-pour-les-auto-entrepreneurs/',
#  'https://www.mon-business-en-ligne.com/boostez-votre-developpement-commercial/',
#  'https://www.mon-business-en-ligne.com/les-defis-auxquels-un-ambulancier-est-confronte/',
#  'https://www.mon-business-en-ligne.com/comment-calculer-votre-salaire-en-portage-salarial/',
#  'https://www.mon-business-en-ligne.com/les-cles-pour-reussir-votre-campagne-de-sms-groupes/',
#  'https://www.mon-business-en-ligne.com/comment-changer-statuts-sas/',
#  'https://www.mon-business-en-ligne.com/comment-creer-un-etablissement-de-credit/',
#  'https://www.mon-business-en-ligne.com/pourquoi-la-virtualisation-dans-les-entreprises/',
#  'https://www.mon-business-en-ligne.com/limportance-de-bien-realiser-votre-compte-de-resultat-previsionnel/',
#  'https://www.mon-business-en-ligne.com/sitemap/',
#  'https://www.mon-business-en-ligne.com/entrepreneurs-apprivoisez-le-syndrome-de-limposteur/',
#  'https://www.mon-business-en-ligne.com/comment-creer-et-gerer-des-accords-de-non-divulgation-pour-les-entreprises/',
#  'https://www.mon-business-en-ligne.com/comment-bien-choisir-son-agence-de-communication/',
#  'https://www.mon-business-en-ligne.com/reussir-son-business-sur-la-toile-vendre-sur-plusieurs-canaux/',
#  'https://www.mon-business-en-ligne.com/pourquoi-contacter-un-avocat-en-droit-des-affaires/',
#  'https://www.mon-business-en-ligne.com/qui-a-le-droit-a-la-prime-de-noel-2019/',
#  'https://www.mon-business-en-ligne.com/entreprise-comment-choisir-votre-avocat-en-droit-des-affaires/',
#  'https://www.mon-business-en-ligne.com/quest-ce-qui-fait-un-bon-service-de-reclamation-aujourdhui/',
#  'https://www.mon-business-en-ligne.com/les-differents-services-apres-vente-telephonique/',
#  'https://www.mon-business-en-ligne.com/les-enjeux-du-big-data-pour-votre-entreprise/',
#  'https://www.mon-business-en-ligne.com/quels-sont-les-avantages-dadherer-a-un-regime-dassurance-maladie-complementaire/',
#  'https://www.mon-business-en-ligne.com/pourquoi-ameliorer-la-communication-interne/',
#  'https://www.mon-business-en-ligne.com/le-cbd-est-il-une-molecule-legale/',
#  'https://www.mon-business-en-ligne.com/quels-sont-les-investisseurs-en-bourse/',
#  'https://www.mon-business-en-ligne.com/',
#  'https://www.mon-business-en-ligne.com/contact/',
#  'https://www.mon-business-en-ligne.com/mentions-legales/',
#  'https://www.mon-business-en-ligne.com/qui-finance-la-formation-dun-contrat-de-professionnalisation/',
#  'https://www.mon-business-en-ligne.com/qui-est-concerne-par-le-cse/',
#  'https://www.mon-business-en-ligne.com/quel-produit-naturel-pour-nettoyer-les-toilettes/',
#  'https://www.mon-business-en-ligne.com/pourquoi-faire-certifier-ses-comptes/',
#  'https://www.mon-business-en-ligne.com/ou-trouver-attestation-heures-dif/',
#  'https://www.mon-business-en-ligne.com/comment-rediger-les-statuts-dune-societe/',
#  'https://www.mon-business-en-ligne.com/comment-faire-pour-mieux-vendre/',
#  'https://www.mon-business-en-ligne.com/comment-construire-lidentite-dune-marque/',
#  'https://www.mon-business-en-ligne.com/comment-choisir-un-statut-pour-son-entreprise/',
#  'https://www.mon-business-en-ligne.com/comment-choisir-un-statut-pour-son-entreprise/',
#  'https://www.mon-business-en-ligne.com/comment-construire-lidentite-dune-marque/',
#  'https://www.mon-business-en-ligne.com/comment-faire-pour-mieux-vendre/',
#  'https://www.mon-business-en-ligne.com/comment-rediger-les-statuts-dune-societe/',
#  'https://www.mon-business-en-ligne.com/octime-salarie-connexion-se-connecter-a-son-compte/',
#  'https://www.mon-business-en-ligne.com/comment-faire-pour-creer-un-lien-internet/',
#  'https://www.mon-business-en-ligne.com/comment-calculer-le-nombre-daction-dune-entreprise/']

# %% [markdown]
# ### Récupérer les infos qu'on souhaite sur chaque article

# %%
def get_article_info(r, url_article):
    # Liste de variables
    noms_variables = [
        'url',  # URL scrapée
        'canonical_url', 'slug', 'meta_title', 'meta_desc',  # Infos issues de la balise meta
        'date_published', 'date_modified',  # Infos dates
        'author',  # Parfois en meta
        'title', 'category', 'views', 'reading_time',  # Metadonnées contenues ailleurs que dans la balise meta
        'content', 'raw_content'  # Contenu de la page
    ]
    
    # Initialisation du dictionnaire
    data = {nom: np.nan for nom in noms_variables}
    
    data['url'] = url_article
    
    soup = BeautifulSoup(r.content, 'lxml')
    
    try:
        data['canonical_url'] = soup.find('link', {'rel': 'canonical'})['href']
    except:
        pass
    
    try:
        data['slug'] = data['canonical_url'].split('/')[-2] if data['canonical_url'] else np.nan
    except:
        pass

    try:
        data['meta_title'] = soup.find('meta', {'property': 'og:title'})['content']
    except:
        pass

    try:
        data['meta_desc'] = soup.find('meta', {'property': 'og:description'})['content']
    except:
        pass

    try:
        data['date_published'] = pd.to_datetime(soup.find('meta', {'property': 'article:published_time'})['content'][:-6], utc=True)
    except:
        pass

    try:
        data['date_modified'] = pd.to_datetime(soup.find('meta', {'property': 'article:modified_time'})['content'][:-6], utc=True)
    except:
        pass

    try:
        data['author'] = soup.find("meta", {'name': 'author'})['content']
    except:
        try:
            data['author'] = soup.find(class_="author").text.split('Publié par ')[-1]
        except:
            pass

    try:
        data['title'] = soup.find('h1').text
    except:
        pass

    try:
        data['category'] = [x.text for x in soup.find_all(class_="tdb-entry-category")]
    except:
        pass

    try:
        data['views'] = int(soup.find('span', class_=lambda x: x and x.startswith('td-nr-views-')).text)
    except:
        pass

    try:
        data['reading_time'] = int(soup.find('meta', {'name': 'twitter:data2'})['content'].split(' ')[0]) if soup.find('meta', {'name': 'twitter:data2'}) and 'minutes' in soup.find('meta', {'name': 'twitter:data2'})['content'] else np.nan
    except:
        pass

    try:
        data['content'] = BeautifulSoup(str(soup.find("div", class_="td-post-content")), 'lxml').get_text()
    except:
        pass

    try:
        data['raw_content'] = str(soup.find("div", class_="td-post-content"))
    except:
        pass

    # Ajout de features
    data['length'] = len(str(data['content']).split())
    
    if pd.notnull(data['date_published']):
        data['days_since_published'] = int((pd.Timestamp.now(tz='UTC') - data['date_published']).days)
    else:
        data['days_since_published'] = np.nan
    
    # Création de la série
    series = pd.Series(data)
    series.name = url_article
    
    # Ajout de features supplémentaires
    if pd.notnull(data.get('views')) and pd.notnull(data.get('days_since_published')):
        series['views_daily'] = series['views'] / series['days_since_published']
        series['views_monthly'] = series['views_daily'] * 30
    else:
        series['views_daily'] = np.nan
        series['views_monthly'] = np.nan
    
    series['website'] = top_url
    
    return series

# %% [markdown]
# ## Fonction finale

# %%
article_list = get_articles_on_page(get_all_results_pages(get_max_page_results(top_search_url)))
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]

# %% [markdown]
# ### Fonction finale

# %%
# Import des packages
from concurrent.futures import ThreadPoolExecutor, as_completed
import time

# Initialisation du compteur
start_time = time.time()

# Fonction principale qui sauvegarde le DataFrame dans un fichier CSV et le retourne
def scrape_all_articles(urls, batch_size=250, max_workers=20):
    # Initialisation d'une session réutilisable
    session = rq.Session()

    # Création d'une fonction qui traite chaque URL
    def process_url(url):
            try:
                r = session.get(url)
                return get_article_info(r, url)
            except Exception as e:
                print(f"Erreur pour {url}: {str(e)}")
                return pd.Series(name=url)

    # Utilise ThreadPoolExecutor pour paralléliser le traitement
    results = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Parcourt la liste d'URLs par lots de taille 'batch_size'
        for i in range(0, len(urls), batch_size):
            # Extrait un lot d'URLs
            batch = urls[i:i+batch_size]
            # Crée et soumet des tâches pour chaque URL du lot
            futures = [executor.submit(process_url, url) for url in batch]
            
            # Traite les résultats au fur et à mesure qu'ils sont terminés
            for future in tqdm(as_completed(futures), total=len(batch), desc=f"Batch {i//batch_size + 1} / {len(urls)//batch_size+1}"):
                # Récupère le résultat de la tâche
                result = future.result()
                # Si le résultat n'est pas None (pas d'erreur), l'ajoute aux résultats
                if result is not None:
                    results.append(result)
    
    # Création du DataFrame final
    df_final = pd.DataFrame(results)
    
    # Ajout de colonnes calculées
    df_final['website'] = top_url
    df_final['scraping_date'] = pd.Timestamp.now(tz='UTC')

    df_final.columns = ['article_url', 'article_canonical_url', 'article_slug',
       'article_meta_title', 'article_meta_desc', 'article_date_published',
       'article_date_modified', 'article_author', 'article_title',
       'article_category', 'article_views', 'article_reading_time',
       'article_content', 'article_raw_content', 'article_length',
       'days_since_published', 'article_views_daily', 'article_views_monthly',
       'website', 'scraping_date']

    # Sauvegarde en CSV
    df_final.to_csv(f'scraping_{abbr}.csv', sep='|', index=True)
    print(f"Scraping terminé. Total d'articles : {len(df_final)}")
    return df_final

df = scrape_all_articles(article_list)

end_time = time.time()
print(end_time - start_time)
# Out:
# Batch 1 / 3:   0%|          | 0/250 [00:00<?, ?it/s]
# Erreur pour https://www.mon-business-en-ligne.com/espace-client-berger-levrault-connexion-rapide-et-gestion-simplifiee/: division by zero
# Batch 2 / 3:   0%|          | 0/250 [00:00<?, ?it/s]
# Batch 3 / 3:   0%|          | 0/91 [00:00<?, ?it/s]
# Scraping terminé. Total d'articles : 591
# 112.94180059432983

# %%
# Création d'un rapport de profil avec pandas_profiling
profile = ProfileReport(df, title=f"{abbr.title()} Scraping Report", explorative=True)

# Génération du rapport au format HTML
profile.to_file(f"scraping_report_{abbr}.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# c:\Users\aurel\AppData\Local\Programs\Python\Python312\Lib\site-packages\ydata_profiling\model\correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'cannot reindex on an axis with duplicate labels')
#   warnings.warn(
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
