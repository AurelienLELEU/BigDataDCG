# %% [markdown]
# # Scraping DCG.media

# %% [markdown]
# %pip install bs4 pandas numpy ydata-profiling plotly tqdm ipywidgets

# %%
### SCRAPING
import requests as rq
from bs4 import BeautifulSoup

### DATABASES
import pandas as pd
import numpy as np
from ydata_profiling import ProfileReport

### VISUALISATION
#import plotly.express as px

### DIVERS
from tqdm.notebook import tqdm

### FORMAT
from datetime import datetime, timezone
import time
import json

# %% [markdown]
# ## Définition des variables

# %%
website = 'autoentrepreneur-pratique'
abbr = 'aep'
tld = '.fr'

# %%
page_number = 1
top_url = f'https://www.{website+tld}'
top_search_url = f'{top_url}/page/{page_number}/?s'

# %% [markdown]
# ## Définition des fonctions

# %% [markdown]
# ### Obtenir le nombre de pages de résultats de recherche

# %%
def get_max_page_results(top_search_url):
    r = rq.get(top_search_url)
    soup = BeautifulSoup(r.content)
    pagenumbers = soup.find_all('a', class_ = 'page-numbers')
    page_final = pagenumbers[-2].text
    return int(page_final)
get_max_page_results(top_search_url)
# Out:
# 9

# %% [markdown]
# ### Obtenir la liste des pages de résultats de recherche

# %%
def get_all_results_pages(page_final):
    urls = []
    for i in range(page_final):
        i = f'{top_url}/page/{i+1}/?s'
        urls.append(i)
    return urls
get_all_results_pages(get_max_page_results(top_search_url))
# Out:
# ['https://www.autoentrepreneur-pratique.fr/page/1/?s',
#  'https://www.autoentrepreneur-pratique.fr/page/2/?s',
#  'https://www.autoentrepreneur-pratique.fr/page/3/?s',
#  'https://www.autoentrepreneur-pratique.fr/page/4/?s',
#  'https://www.autoentrepreneur-pratique.fr/page/5/?s',
#  'https://www.autoentrepreneur-pratique.fr/page/6/?s',
#  'https://www.autoentrepreneur-pratique.fr/page/7/?s',
#  'https://www.autoentrepreneur-pratique.fr/page/8/?s',
#  'https://www.autoentrepreneur-pratique.fr/page/9/?s']

# %% [markdown]
# ### Obtenir tous les liens des articles sur une page de recherche

# %%
def get_articles_on_page(search_results):
    urls_articles = []
    s = rq.Session()
    for p in tqdm(search_results):
        r = s.get(p)
        soup = BeautifulSoup(r.content)
        articles = soup.find_all('h2', class_ = 'title')
        for article in articles:
            url = article.find('a', href=True)['href']
            urls_articles.append(url)
    return urls_articles

# %%
get_articles_on_page(get_all_results_pages(get_max_page_results(top_search_url)))
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# ['https://www.autoentrepreneur-pratique.fr/le-role-strategique-dun-logisticien-definition-et-decryptage/',
#  'https://www.autoentrepreneur-pratique.fr/limportance-cruciale-de-la-taille-euro-palette-en-logistique/',
#  'https://www.autoentrepreneur-pratique.fr/comment-anticiper-les-dates-de-paie-a-leducation-nationale-pour-mieux-gerer-son-budget/',
#  'https://www.autoentrepreneur-pratique.fr/les-avantages-dexternaliser-son-entreprise-avec-une-solution-de-comite-dentreprise/',
#  'https://www.autoentrepreneur-pratique.fr/pourquoi-contacter-une-agence-specialisee-dans-la-conception-de-carte-pop-up/',
#  'https://www.autoentrepreneur-pratique.fr/comprendre-la-grille-des-salaires-convention-66-implications-pour-les-moniteurs-deducation/',
#  'https://www.autoentrepreneur-pratique.fr/pourquoi-la-date-de-salaire-enseignant-change-t-elle-selon-les-regions/',
#  'https://www.autoentrepreneur-pratique.fr/entreprises-a-rennes-innovation-et-tradition-en-harmonie/',
#  'https://www.autoentrepreneur-pratique.fr/comment-rediger-un-mail-professionnel-des-exemples-pour-chaque-situation/',
#  'https://www.autoentrepreneur-pratique.fr/comprendre-le-systeme-dechelon-pour-les-praticiens-hospitaliers-enjeux-et-perspectives/',
#  'https://www.autoentrepreneur-pratique.fr/comprendre-et-beneficier-du-statut-rqth-tout-ce-que-vous-devez-savoir/',
#  'https://www.autoentrepreneur-pratique.fr/travailler-chez-soi-en-emballage-comment-maximiser-ses-gains-en-toute-autonomie/',
#  'https://www.autoentrepreneur-pratique.fr/nombre-de-jours-ouvrables-en-2024-quels-effets-sur-la-productivite-des-entreprises/',
#  'https://www.autoentrepreneur-pratique.fr/lappreciation-du-stagiaire-un-levier-pour-la-reussite-professionnelle/',
#  'https://www.autoentrepreneur-pratique.fr/les-erreurs-courantes-associees-a-la-signature-po/',
#  'https://www.autoentrepreneur-pratique.fr/cnas-mon-compte-billetterie-guide-exhaustif-pour-maximiser-vos-reductions/',
#  'https://www.autoentrepreneur-pratique.fr/strategies-de-mailing-efficaces-boostez-votre-communication-en-ligne/',
#  'https://www.autoentrepreneur-pratique.fr/attestation-devolutive-comprendre-son-role-et-sa-procedure/',
#  'https://www.autoentrepreneur-pratique.fr/bitpanda-la-plateforme-dechange-de-crypto-monnaies-a-adopter/',
#  'https://www.autoentrepreneur-pratique.fr/comment-concilier-vie-professionnelle-et-horaires-decales-en-2x8/',
#  'https://www.autoentrepreneur-pratique.fr/horaire-2x8-organisation-et-vie-quotidienne-en-horaires-decales/',
#  'https://www.autoentrepreneur-pratique.fr/alicia-etheredge-brown-une-productrice-de-television-qui-monte/',
#  'https://www.autoentrepreneur-pratique.fr/comment-reussir-sa-candidature-pour-un-contrat-en-alternance-les-etapes-cles/',
#  'https://www.autoentrepreneur-pratique.fr/comprendre-le-statut-du-vrp-avantages-responsabilites-et-perspectives/',
#  'https://www.autoentrepreneur-pratique.fr/comprendre-le-mecanisme-du-dividende-en-sarl-enjeux-et-implications/',
#  'https://www.autoentrepreneur-pratique.fr/survivre-a-une-radiation-dauto-entrepreneur-conseils-et-astuces-pour-rebondir/',
#  'https://www.autoentrepreneur-pratique.fr/meilleur-avocat-a-nimes-conseils-pour-choisir-le-bon-professionnel-juridique/',
#  'https://www.autoentrepreneur-pratique.fr/creer-un-compte-g-trouve-conseils-indispensables-pour-entrepreneurs-avises/',
#  'https://www.autoentrepreneur-pratique.fr/myextrabat-plateforme-de-gestion-pour-les-professionnels-du-batiment/',
#  'https://www.autoentrepreneur-pratique.fr/comment-trouver-un-vitrier-en-hauts-de-france/',
#  'https://www.autoentrepreneur-pratique.fr/aol-mail-comment-il-redefinit-la-communication-en-2024/',
#  'https://www.autoentrepreneur-pratique.fr/obtenir-une-attestation-simplifiee-en-tant-que-particulier-employeur-les-secrets-dune-demarche-reussie/',
#  'https://www.autoentrepreneur-pratique.fr/optez-pour-une-location-dune-fontaine-a-eau-pour-votre-evenement/',
#  'https://www.autoentrepreneur-pratique.fr/une-simplification-des-envois-de-colis-avec-my-flying-box/',
#  'https://www.autoentrepreneur-pratique.fr/gerez-avec-simplicite-vos-envois-de-colis-et-dimpression-detiquettes-avec-my-flying-box/',
#  'https://www.autoentrepreneur-pratique.fr/les-outils-seo-indispensables-pour-analyser-et-ameliorer-votre-site/',
#  'https://www.autoentrepreneur-pratique.fr/brikstok-ex-flozor-decouvrez-la-nouvelle-adresse-brikstok-com-et-ses-avantages-2/',
#  'https://www.autoentrepreneur-pratique.fr/brikstok-ex-flozor-decouvrez-la-nouvelle-adresse-brikstok-com-et-ses-avantages/',
#  'https://www.autoentrepreneur-pratique.fr/agence-seo-optimize-360-meilleure-que-les-autres/',
#  'https://www.autoentrepreneur-pratique.fr/article-l1332-2-du-code-du-travail-explication-de-larticle-de-loi/',
#  'https://www.autoentrepreneur-pratique.fr/comment-obtenir-une-carte-professionnelle-dassurance/',
#  'https://www.autoentrepreneur-pratique.fr/comment-obtenir-une-carte-professionnelle-assurance/',
#  'https://www.autoentrepreneur-pratique.fr/concurrent-direct-et-indirect-exemple-explications/',
#  'https://www.autoentrepreneur-pratique.fr/sasu-tout-savoir-pour-creer-et-ou-fermer-son-entreprise/',
#  'https://www.autoentrepreneur-pratique.fr/optimiser-sa-logistique-avec-b2pweb-guide-pratique/',
#  'https://www.autoentrepreneur-pratique.fr/le-role-dun-cabinet-de-recrutement-web-dans-la-gestion-des-talents-a-long-terme/',
#  'https://www.autoentrepreneur-pratique.fr/les-evolutions-possibles-du-salaire-net-des-eboueurs-en-france/',
#  'https://www.autoentrepreneur-pratique.fr/les-differentes-sources-de-revenu-des-influenceurs-du-web-les-opportunites-de-monetisation/',
#  'https://www.autoentrepreneur-pratique.fr/comment-une-application-specialisee-peut-transformer-la-gestion-des-auto-ecoles/',
#  'https://www.autoentrepreneur-pratique.fr/les-competences-indispensables-de-lavocat-en-droit-social-pour-resoudre-les-litiges-du-travail/',
#  'https://www.autoentrepreneur-pratique.fr/le-role-strategique-dun-logisticien-definition-et-decryptage/',
#  'https://www.autoentrepreneur-pratique.fr/limportance-cruciale-de-la-taille-euro-palette-en-logistique/',
#  'https://www.autoentrepreneur-pratique.fr/comment-anticiper-les-dates-de-paie-a-leducation-nationale-pour-mieux-gerer-son-budget/',
#  'https://www.autoentrepreneur-pratique.fr/les-avantages-dexternaliser-son-entreprise-avec-une-solution-de-comite-dentreprise/',
#  'https://www.autoentrepreneur-pratique.fr/le-role-strategique-dun-logisticien-definition-et-decryptage/',
#  'https://www.autoentrepreneur-pratique.fr/limportance-cruciale-de-la-taille-euro-palette-en-logistique/',
#  'https://www.autoentrepreneur-pratique.fr/comment-anticiper-les-dates-de-paie-a-leducation-nationale-pour-mieux-gerer-son-budget/',
#  'https://www.autoentrepreneur-pratique.fr/les-avantages-dexternaliser-son-entreprise-avec-une-solution-de-comite-dentreprise/',
#  'https://www.autoentrepreneur-pratique.fr/pourquoi-contacter-une-agence-specialisee-dans-la-conception-de-carte-pop-up/',
#  'https://www.autoentrepreneur-pratique.fr/conseils-pour-choisir-et-entretenir-son-mobilier-pliant/',
#  'https://www.autoentrepreneur-pratique.fr/les-subtilites-du-mi-temps-therapeutique-dans-la-fonction-publique-entre-benefices-et-contraintes/',
#  'https://www.autoentrepreneur-pratique.fr/les-attraits-du-magasin-concorde-a-champigny-sur-marne-pour-les-amateurs-de-bonnes-affaires/',
#  'https://www.autoentrepreneur-pratique.fr/gestion-documents-administratifs-optimisez-avec-actradis-pour-entreprises/',
#  'https://www.autoentrepreneur-pratique.fr/comparez-vos-transporteurs-pour-trouver-la-meilleure-solution-denvoi-de-colis-au-meilleur-prix/',
#  'https://www.autoentrepreneur-pratique.fr/ou-sont-acceptes-les-cheques-vacances/',
#  'https://www.autoentrepreneur-pratique.fr/colis-a-envoyer-en-express-comment-sy-prendre/',
#  'https://www.autoentrepreneur-pratique.fr/quel-est-le-salaire-moyen-dun-comptable/',
#  'https://www.autoentrepreneur-pratique.fr/les-benefices-insoupconnes-denc92pour-les-etablissements-des-hauts-de-seine/',
#  'https://www.autoentrepreneur-pratique.fr/pourquoi-les-avantages-du-statut-cadre-font-toute-la-difference/',
#  'https://www.autoentrepreneur-pratique.fr/les-outils-indispensables-pour-reussir-en-tant-que-nomade-numerique/',
#  'https://www.autoentrepreneur-pratique.fr/quel-est-limpact-du-salaire-sur-la-carriere-dun-chauffeur-poids-lourd/',
#  'https://www.autoentrepreneur-pratique.fr/comment-publier-des-annonces-legales-en-ligne/',
#  'https://www.autoentrepreneur-pratique.fr/formation-adulte-en-hotellerie-accedez-a-une-nouvelle-carriere/',
#  'https://www.autoentrepreneur-pratique.fr/pourquoi-le-logo-des-marques-influence-nos-choix-de-consommation/',
#  'https://www.autoentrepreneur-pratique.fr/limportance-des-equipements-dph-pour-une-gestion-efficace-de-lhygiene-en-entreprise/',
#  'https://www.autoentrepreneur-pratique.fr/decryptage-des-opportunites-de-croissance-sur-5euros-com/',
#  'https://www.autoentrepreneur-pratique.fr/la-veille-territoriale-une-vision-multidimensionnelle-de-votre-marche-et-territoire/',
#  'https://www.autoentrepreneur-pratique.fr/lavenement-de-protac-dans-lindustrie-de-la-fabrication-additive/',
#  'https://www.autoentrepreneur-pratique.fr/trouver-le-bon-avocat-comment-connaitre-sa-specialisation/',
#  'https://www.autoentrepreneur-pratique.fr/quels-sont-les-points-forts-du-cms-magento/',
#  'https://www.autoentrepreneur-pratique.fr/comment-optimiser-votre-geolocalisation-de-transport-routier-pour-une-gestion-efficace/',
#  'https://www.autoentrepreneur-pratique.fr/comment-obtenir-un-kbis-pour-profession-liberale-conseils-et-etapes-cles/',
#  'https://www.autoentrepreneur-pratique.fr/comprendre-la-structure-des-charges-dans-une-entreprise-individuelle-aspects-cles-et-optimisation/',
#  'https://www.autoentrepreneur-pratique.fr/limpact-des-solutions-de-messagerie-a-versailles-sur-la-communication-professionnelle/',
#  'https://www.autoentrepreneur-pratique.fr/comment-les-gafa-utilisent-linkedin-pour-dominer-le-marche/',
#  'https://www.autoentrepreneur-pratique.fr/gagner-en-productivite-grace-a-medysis-strategies-avancees/',
#  'https://www.autoentrepreneur-pratique.fr/les-etapes-pour-se-desinscrire-de-pole-emploi-efficacement/',
#  'https://www.autoentrepreneur-pratique.fr/sigmatech-un-processus-de-recrutement-dans-le-secteur-du-web-equilibre-et-ameliore-quotidiennement/',
#  'https://www.autoentrepreneur-pratique.fr/comment-analyser-la-tresorerie-dune-entreprise-efficacement/',
#  'https://www.autoentrepreneur-pratique.fr/comment-fonctionne-le-processus-de-nomination-pour-la-medaille-de-lordre-national-du-merite/',
#  'https://www.autoentrepreneur-pratique.fr/limportance-de-verifier-la-validite-des-numeros-mobiles-pour-les-entreprises/',
#  'https://www.autoentrepreneur-pratique.fr/la-contribution-de-france-video-caps-a-la-qualite-des-videos-en-ligne/',
#  'https://www.autoentrepreneur-pratique.fr/quels-atouts-dopter-pour-la-campagne-de-sms-publicitaire/',
#  'https://www.autoentrepreneur-pratique.fr/strategie-marketing-point-de-vente-boostez-vos-resultats-avec-widely/',
#  'https://www.autoentrepreneur-pratique.fr/comment-choisir-une-agence-de-creation-de-site-web/',
#  'https://www.autoentrepreneur-pratique.fr/ouvrir-un-etablissement-secondaire/',
#  'https://www.autoentrepreneur-pratique.fr/quel-est-le-meilleur-site-pour-creer-un-site-internet/',
#  'https://www.autoentrepreneur-pratique.fr/quelle-puissance-poele-a-granule-pour-100m2/',
#  'https://www.autoentrepreneur-pratique.fr/comment-payer-en-illicado-sur-leroy-merlin/',
#  'https://www.autoentrepreneur-pratique.fr/decouvrez-les-secrets-de-so-go-lille-pour-une-gestion-de-mails-optimale/',
#  'https://www.autoentrepreneur-pratique.fr/avocat-en-droit-de-la-publicite-defense-et-protection-des-marques/',
#  'https://www.autoentrepreneur-pratique.fr/normes-non-feu-erp-que-faut-il-savoir/',
#  'https://www.autoentrepreneur-pratique.fr/parcours-detaille-les-phases-cruciales-pour-la-creation-dune-entreprise-reussie/',
#  'https://www.autoentrepreneur-pratique.fr/plaque-funeraire-moderne-une-piece-esthetique-mais-tout-aussi-durable/',
#  'https://www.autoentrepreneur-pratique.fr/plaque-funeraire-toutes-les-matieres-et-methodes-de-fabrication/',
#  'https://www.autoentrepreneur-pratique.fr/les-principaux-atouts-de-la-carte-veritas-mastercard-flexibilite-securite-et-accessibilite-mondiale/',
#  'https://www.autoentrepreneur-pratique.fr/quels-sont-les-avantages-davoir-un-compte-pro/',
#  'https://www.autoentrepreneur-pratique.fr/retroplanning-comprendre-sa-definition-et-son-application-efficace/',
#  'https://www.autoentrepreneur-pratique.fr/a-la-decouverte-dune-alternative-plus-moderne-du-sms-le-rcs/',
#  'https://www.autoentrepreneur-pratique.fr/le-role-strategique-dun-logisticien-definition-et-decryptage/',
#  'https://www.autoentrepreneur-pratique.fr/limportance-cruciale-de-la-taille-euro-palette-en-logistique/',
#  'https://www.autoentrepreneur-pratique.fr/comment-anticiper-les-dates-de-paie-a-leducation-nationale-pour-mieux-gerer-son-budget/',
#  'https://www.autoentrepreneur-pratique.fr/les-avantages-dexternaliser-son-entreprise-avec-une-solution-de-comite-dentreprise/',
#  'https://www.autoentrepreneur-pratique.fr/le-role-strategique-dun-logisticien-definition-et-decryptage/',
#  'https://www.autoentrepreneur-pratique.fr/limportance-cruciale-de-la-taille-euro-palette-en-logistique/',
#  'https://www.autoentrepreneur-pratique.fr/comment-anticiper-les-dates-de-paie-a-leducation-nationale-pour-mieux-gerer-son-budget/',
#  'https://www.autoentrepreneur-pratique.fr/les-avantages-dexternaliser-son-entreprise-avec-une-solution-de-comite-dentreprise/',
#  'https://www.autoentrepreneur-pratique.fr/pourquoi-contacter-une-agence-specialisee-dans-la-conception-de-carte-pop-up/',
#  'https://www.autoentrepreneur-pratique.fr/comment-choisir-la-bonne-formation-a-distance/',
#  'https://www.autoentrepreneur-pratique.fr/combien-coute-la-creation-dune-sci/',
#  'https://www.autoentrepreneur-pratique.fr/quelles-sont-les-primes-exonerees-de-charges/',
#  'https://www.autoentrepreneur-pratique.fr/revolution-de-la-logistique-les-incontournables-atouts-dun-logiciel-de-gestion-des-flux-de-camions/',
#  'https://www.autoentrepreneur-pratique.fr/llce-anglais-et-quelles-autres-langues-choisir/',
#  'https://www.autoentrepreneur-pratique.fr/trouver-une-formation-en-france-via-une-plateforme-specialisee/',
#  'https://www.autoentrepreneur-pratique.fr/choisir-lalternance-pour-mieux-batir-sa-carriere-professionnelle/',
#  'https://www.autoentrepreneur-pratique.fr/choisir-son-avocat-conseils-pratiques-pour-une-selection-avisee/',
#  'https://www.autoentrepreneur-pratique.fr/optimisation-de-la-chaine-logistique-maitriser-le-flux-pousse/',
#  'https://www.autoentrepreneur-pratique.fr/developpement-digital-pour-entreprises-strategies-pour-une-presence-en-ligne-efficace/',
#  'https://www.autoentrepreneur-pratique.fr/les-etapes-cruciales-pour-reussir-le-changement-dadresse-dune-sci/',
#  'https://www.autoentrepreneur-pratique.fr/le-big-data-revolutionner-le-marketing-dans-lere-numerique/',
#  'https://www.autoentrepreneur-pratique.fr/contrat-de-prestation-freelance-astuces-et-conseils-pour-sassurer-securite-et-clarte/',
#  'https://www.autoentrepreneur-pratique.fr/indicateurs-sociaux-mesurez-limpact-de-votre-strategie-sur-les-reseaux/',
#  'https://www.autoentrepreneur-pratique.fr/mam-explique-services-essentiels-avantages-et-definition-complete/',
#  'https://www.autoentrepreneur-pratique.fr/potentiel-commercial-optimiser-votre-zone-de-chalandise/',
#  'https://www.autoentrepreneur-pratique.fr/maximiser-son-succes-en-tant-quauto-entrepreneur-conseils-pratiques-et-ressources-incontournables/',
#  'https://www.autoentrepreneur-pratique.fr/conseils-pour-un-modele-cv-performant-et-percutant/',
#  'https://www.autoentrepreneur-pratique.fr/travailler-en-freelance-3-facons-efficaces-pour-trouver-des-clients/',
#  'https://www.autoentrepreneur-pratique.fr/lancement-de-votre-entreprise-par-la-strategie-digitale-avec-une-agence-web-a-strasbourg/',
#  'https://www.autoentrepreneur-pratique.fr/guide-ultime-du-logiciel-de-caisse-auto-entrepreneur/',
#  'https://www.autoentrepreneur-pratique.fr/4-types-doutils-a-utiliser-par-les-entrepreneurs-individuels/',
#  'https://www.autoentrepreneur-pratique.fr/progressium-pourquoi-solliciter-ces-experts-du-franchisage/',
#  'https://www.autoentrepreneur-pratique.fr/comment-rompre-un-contrat-dinterim/',
#  'https://www.autoentrepreneur-pratique.fr/quel-salaire-net-pour-un-apprenti/',
#  'https://www.autoentrepreneur-pratique.fr/comment-devenir-fiscaliste-international/',
#  'https://www.autoentrepreneur-pratique.fr/comment-calculer-le-prix-de-vente-dune-entreprise/',
#  'https://www.autoentrepreneur-pratique.fr/comprendre-les-echanges-b2b-b2c-c2c-b2g-strategies-et-differences/',
#  'https://www.autoentrepreneur-pratique.fr/management-situationnel-strategies-pour-exceller-en-leadership/',
#  'https://www.autoentrepreneur-pratique.fr/licenciement-pour-abandon-de-poste-demarches-et-conseils-legaux/',
#  'https://www.autoentrepreneur-pratique.fr/metiers-de-nuit-a-haute-remuneration-decouvrez-les-plus-lucratifs/',
#  'https://www.autoentrepreneur-pratique.fr/quels-sont-les-avantages-des-enveloppes-plastiques-ecologiques/',
#  'https://www.autoentrepreneur-pratique.fr/cours-de-preparation-toeic-les-astuces-pour-la-preparation-du-test-toeic/',
#  'https://www.autoentrepreneur-pratique.fr/linteret-de-solliciter-une-agence-de-referencement-payant-sea-pour-une-campagne-google-ads/',
#  'https://www.autoentrepreneur-pratique.fr/definition-et-importance-du-brief-en-creation-de-contenu-optimisez-vos-projets/',
#  'https://www.autoentrepreneur-pratique.fr/gestion-commerciale-pourquoi-sage-100-est-la-meilleure-option/',
#  'https://www.autoentrepreneur-pratique.fr/a-qui-sadresse-la-location-de-bureau-partage-a-la-journee-et-quels-sont-les-avantages/',
#  'https://www.autoentrepreneur-pratique.fr/eft-vs-ach-vs-cheque-electronique-optimisez-les-paiements-de-votre-entreprise/',
#  'https://www.autoentrepreneur-pratique.fr/reduire-le-time-to-market-strategies-efficaces-pour-accelerer-le-lancement/',
#  'https://www.autoentrepreneur-pratique.fr/types-de-stocks-en-entreprise-comprendre-et-optimiser-la-gestion/',
#  'https://www.autoentrepreneur-pratique.fr/pourquoi-est-il-crucial-dafficher-les-consignes-de-securite-dans-le-milieu-professionnel/',
#  'https://www.autoentrepreneur-pratique.fr/reduire-la-facture-delectricite-de-votre-boulangerie-astuces-a-adopter/',
#  'https://www.autoentrepreneur-pratique.fr/economisez-avec-style-les-racks-de-seconde-main/',
#  'https://www.autoentrepreneur-pratique.fr/annulation-bon-de-commande-signe-demarches-et-conseils-pratiques/',
#  'https://www.autoentrepreneur-pratique.fr/calcul-du-taux-de-retention-client-methodes-et-analyse-pour-optimiser-la-fidelisation/',
#  'https://www.autoentrepreneur-pratique.fr/decouvrir-lintelligence-artificielle-un-monde-de-possibilites-innovantes/',
#  'https://www.autoentrepreneur-pratique.fr/expert-en-depannage-de-chaudiere-a-bruxelles-frigotech-a-votre-service/',
#  'https://www.autoentrepreneur-pratique.fr/carsat-missions-services-et-contact-pour-vos-demarches-retraite/',
#  'https://www.autoentrepreneur-pratique.fr/primes-salariales-differences-entre-recompenses-individuelles-et-collectives/',
#  'https://www.autoentrepreneur-pratique.fr/kpi-essentiels-pour-la-supply-chain-optimisez-votre-gestion-logistique/',
#  'https://www.autoentrepreneur-pratique.fr/le-role-strategique-dun-logisticien-definition-et-decryptage/',
#  'https://www.autoentrepreneur-pratique.fr/limportance-cruciale-de-la-taille-euro-palette-en-logistique/',
#  'https://www.autoentrepreneur-pratique.fr/comment-anticiper-les-dates-de-paie-a-leducation-nationale-pour-mieux-gerer-son-budget/',
#  'https://www.autoentrepreneur-pratique.fr/les-avantages-dexternaliser-son-entreprise-avec-une-solution-de-comite-dentreprise/',
#  'https://www.autoentrepreneur-pratique.fr/le-role-strategique-dun-logisticien-definition-et-decryptage/',
#  'https://www.autoentrepreneur-pratique.fr/limportance-cruciale-de-la-taille-euro-palette-en-logistique/',
#  'https://www.autoentrepreneur-pratique.fr/comment-anticiper-les-dates-de-paie-a-leducation-nationale-pour-mieux-gerer-son-budget/',
#  'https://www.autoentrepreneur-pratique.fr/les-avantages-dexternaliser-son-entreprise-avec-une-solution-de-comite-dentreprise/',
#  'https://www.autoentrepreneur-pratique.fr/pourquoi-contacter-une-agence-specialisee-dans-la-conception-de-carte-pop-up/',
#  'https://www.autoentrepreneur-pratique.fr/une-literie-haut-de-gamme-ameliore-la-qualite-de-votre-sommeil/',
#  'https://www.autoentrepreneur-pratique.fr/lart-de-cuisiner-le-riz-avec-succes/',
#  'https://www.autoentrepreneur-pratique.fr/comment-choisir-la-plaque-dimmatriculation-ideale-pour-votre-vehicule/',
#  'https://www.autoentrepreneur-pratique.fr/quelle-est-la-meilleure-maniere-de-se-perfectionner-en-management/',
#  'https://www.autoentrepreneur-pratique.fr/lemballage-eco-responsable-un-levier-pour-differencier-votre-marque-sur-le-marche/',
#  'https://www.autoentrepreneur-pratique.fr/decouvrez-limportance-dun-service-de-menage-a-domicile-et-de-qualite-a-paris/',
#  'https://www.autoentrepreneur-pratique.fr/ik-et-fiscalite-les-bons-a-savoir-pour-economiser-sur-ses-impots-avec-le-simulateur-ik/',
#  'https://www.autoentrepreneur-pratique.fr/quel-est-le-role-dun-comptable/',
#  'https://www.autoentrepreneur-pratique.fr/une-agence-seo-grands-comptes-ses-missions-principales/',
#  'https://www.autoentrepreneur-pratique.fr/agence-marketing-video-quel-est-linteret-de-recourir-a-ce-type-dagence/',
#  'https://www.autoentrepreneur-pratique.fr/comment-developper-votre-motivation/',
#  'https://www.autoentrepreneur-pratique.fr/logiciel-zoom-du-telechargement-a-lutilisation-zoom-sur-ce-logiciel-de-visioconference/',
#  'https://www.autoentrepreneur-pratique.fr/resiliation-resilier-son-contrat-electricite-chez-elecocite/',
#  'https://www.autoentrepreneur-pratique.fr/comment-obtenir-une-copie-conforme-dun-diplome/',
#  'https://www.autoentrepreneur-pratique.fr/quel-outillage-utilise-t-on-pour-la-rectification-de-table-de-presse/',
#  'https://www.autoentrepreneur-pratique.fr/pourquoi-louer-des-decorations-evenementielles/',
#  'https://www.autoentrepreneur-pratique.fr/sejour-linguistique-la-cle-de-lapprentissage-et-de-lepanouissement-personnel/',
#  'https://www.autoentrepreneur-pratique.fr/quelles-sont-les-economies-realisees-par-les-entreprises/',
#  'https://www.autoentrepreneur-pratique.fr/comment-envoyer-une-capture-decran-a-partir-de-votre-ordinateur/',
#  'https://www.autoentrepreneur-pratique.fr/location-dun-bureau-prive-paris-un-choix-strategique-pour-les-entreprises/',
#  'https://www.autoentrepreneur-pratique.fr/formation-en-ressources-humaines-booster-votre-carriere-avec-une-formation-professionnelle/',
#  'https://www.autoentrepreneur-pratique.fr/boostez-la-performance-de-vos-collaborateurs-offrez-leur-une-seance-de-sylvotherapie/',
#  'https://www.autoentrepreneur-pratique.fr/creation-dune-start-up-les-principales-etapes-a-connaitre/',
#  'https://www.autoentrepreneur-pratique.fr/comprendre-les-differents-types-de-structures-organisationnelles/',
#  'https://www.autoentrepreneur-pratique.fr/notre-choix-des-5-emballages-alimentaires-eco-responsables/',
#  'https://www.autoentrepreneur-pratique.fr/eurl-ou-sarl-quelle-difference-entre-ces-statuts/',
#  'https://www.autoentrepreneur-pratique.fr/comment-enregistrer-les-statuts-dune-sci/',
#  'https://www.autoentrepreneur-pratique.fr/comment-beneficier-de-lacre-en-2020/',
#  'https://www.autoentrepreneur-pratique.fr/comment-ajouter-un-lien-internet-dans-un-document-texte-libre-office/',
#  'https://www.autoentrepreneur-pratique.fr/cest-quoi-un-produit-innovant/',
#  'https://www.autoentrepreneur-pratique.fr/quel-est-le-meilleur-logiciel-pour-auto-entrepreneur/',
#  'https://www.autoentrepreneur-pratique.fr/comment-savoir-si-son-bilan-comptable-est-bon/',
#  'https://www.autoentrepreneur-pratique.fr/quest-ce-quune-strategie-de-positionnement/',
#  'https://www.autoentrepreneur-pratique.fr/quest-ce-que-la-faisabilite-technique/',
#  'https://www.autoentrepreneur-pratique.fr/les-etapes-cles-pour-un-licenciement-en-france-tout-savoir-sur-les-procedures/',
#  'https://www.autoentrepreneur-pratique.fr/les-pieges-courants-a-eviter-lors-de-la-creation-dune-entreprise/',
#  'https://www.autoentrepreneur-pratique.fr/securite-incendie-dans-une-entreprise-connaitre-les-obligations-de-lemployeur/',
#  'https://www.autoentrepreneur-pratique.fr/pourquoi-externaliser-la-gestion-des-ressources-humaines/',
#  'https://www.autoentrepreneur-pratique.fr/quels-sont-les-outils-de-solution-sms-pour-communiquer-avec-vos-clients/',
#  'https://www.autoentrepreneur-pratique.fr/les-benefices-indeniables-de-lexternalisation-des-services/',
#  'https://www.autoentrepreneur-pratique.fr/diversite-et-inclusion-dans-le-milieu-professionnel-les-cles-du-succes/',
#  'https://www.autoentrepreneur-pratique.fr/societe-de-prospection-une-solution-efficace-pour-elargir-votre-clientele/',
#  'https://www.autoentrepreneur-pratique.fr/decouvrez-les-strategies-de-recrutement-innovantes-pour-attirer-les-profils-les-plus-qualifies/',
#  'https://www.autoentrepreneur-pratique.fr/les-cles-pour-optimiser-votre-email-marketing-et-booster-vos-resultats/',
#  'https://www.autoentrepreneur-pratique.fr/guide-complet-sur-le-recouvrement-de-factures-impayees-les-strategies-efficaces-et-les-meilleures-pratiques/',
#  'https://www.autoentrepreneur-pratique.fr/les-dernieres-tendances-du-teletravail-et-leur-influence-sur-les-entreprises/',
#  'https://www.autoentrepreneur-pratique.fr/les-pieges-a-eviter-en-marketing-pour-optimiser-votre-strategie/',
#  'https://www.autoentrepreneur-pratique.fr/porte-grillagee-assurez-la-securite-de-votre-espace-de-stockage/',
#  'https://www.autoentrepreneur-pratique.fr/quapporte-une-formation-en-medecine-holistique-a-votre-parcours/',
#  'https://www.autoentrepreneur-pratique.fr/les-enjeux-et-les-perspectives-de-la-digitalisation-des-entreprises/',
#  'https://www.autoentrepreneur-pratique.fr/le-role-strategique-dun-logisticien-definition-et-decryptage/',
#  'https://www.autoentrepreneur-pratique.fr/limportance-cruciale-de-la-taille-euro-palette-en-logistique/',
#  'https://www.autoentrepreneur-pratique.fr/comment-anticiper-les-dates-de-paie-a-leducation-nationale-pour-mieux-gerer-son-budget/',
#  'https://www.autoentrepreneur-pratique.fr/les-avantages-dexternaliser-son-entreprise-avec-une-solution-de-comite-dentreprise/',
#  'https://www.autoentrepreneur-pratique.fr/le-role-strategique-dun-logisticien-definition-et-decryptage/',
#  'https://www.autoentrepreneur-pratique.fr/limportance-cruciale-de-la-taille-euro-palette-en-logistique/',
#  'https://www.autoentrepreneur-pratique.fr/comment-anticiper-les-dates-de-paie-a-leducation-nationale-pour-mieux-gerer-son-budget/',
#  'https://www.autoentrepreneur-pratique.fr/les-avantages-dexternaliser-son-entreprise-avec-une-solution-de-comite-dentreprise/',
#  'https://www.autoentrepreneur-pratique.fr/pourquoi-contacter-une-agence-specialisee-dans-la-conception-de-carte-pop-up/',
#  'https://www.autoentrepreneur-pratique.fr/comment-choisir-le-bon-produit-nettoyant-hospitalier/',
#  'https://www.autoentrepreneur-pratique.fr/ameliorer-sa-presence-sur-les-reseaux-sociaux-guide-des-meilleures-pratiques-efficaces/',
#  'https://www.autoentrepreneur-pratique.fr/un-camion-sur-mesure-pour-votre-commerce-ambulant/',
#  'https://www.autoentrepreneur-pratique.fr/comment-le-salaire-dun-chirurgien-dentiste-est-il-calcule/',
#  'https://www.autoentrepreneur-pratique.fr/difference-en-auto-entreprise-et-portage-entrepreneurial/',
#  'https://www.autoentrepreneur-pratique.fr/assurance-professionnelle-les-differents-types/',
#  'https://www.autoentrepreneur-pratique.fr/quelles-sont-les-particularites-du-contrat-a-duree-determinee-dit-intermittent/',
#  'https://www.autoentrepreneur-pratique.fr/lusinage-de-precision-quest-ce-que-cest/',
#  'https://www.autoentrepreneur-pratique.fr/la-responsabilite-sociale-des-entreprises-des-actions-concretes-pour-sengager-positivement/',
#  'https://www.autoentrepreneur-pratique.fr/decouvrez-les-visites-virtuelles-a-360-degres/',
#  'https://www.autoentrepreneur-pratique.fr/lart-doffrir-du-vin-une-quete-sensorielle-et-culturelle/',
#  'https://www.autoentrepreneur-pratique.fr/quelle-mini-grue-choisir-pour-realiser-vos-projets/',
#  'https://www.autoentrepreneur-pratique.fr/comment-creer-une-carte-de-visite-originale/',
#  'https://www.autoentrepreneur-pratique.fr/covering-publicitaire-les-differentes-solutions-possibles/',
#  'https://www.autoentrepreneur-pratique.fr/la-bonne-tactique-pour-joindre-rapidement-un-service-client/',
#  'https://www.autoentrepreneur-pratique.fr/comment-une-agence-de-presentation-powerpoint-peut-vous-aider/',
#  'https://www.autoentrepreneur-pratique.fr/decouvrez-les-solutions-acoustiques-pour-lindustrie-et-le-tertiaire/',
#  'https://www.autoentrepreneur-pratique.fr/comment-piloter-son-entreprise-en-quelques-points-cles/',
#  'https://www.autoentrepreneur-pratique.fr/quest-ce-qui-caracterise-les-enveloppes-grand-format/',
#  'https://www.autoentrepreneur-pratique.fr/comment-se-lancer-en-freelance-et-bien-gerer-son-argent/',
#  'https://www.autoentrepreneur-pratique.fr/test-a-b-comment-interpreter-correctement-les-resultats/',
#  'https://www.autoentrepreneur-pratique.fr/quelle-est-la-remuneration-dun-livreur-uber-eats/',
#  'https://www.autoentrepreneur-pratique.fr/les-essentiels-pour-les-entrepreneurs-les-outils-numeriques-a-ne-pas-negliger/',
#  'https://www.autoentrepreneur-pratique.fr/les-cles-dune-gestion-efficace-des-ressources-humaines-en-entreprise/',
#  'https://www.autoentrepreneur-pratique.fr/quand-et-comment-changer-de-mutuelle/',
#  'https://www.autoentrepreneur-pratique.fr/extrait-kbis-quest-ce-que-cest-son-utilite-que-contient-il/',
#  'https://www.autoentrepreneur-pratique.fr/comment-favoriser-linnovation-dans-les-entreprises/',
#  'https://www.autoentrepreneur-pratique.fr/caisse-depargne-loire-centre-comment-ouvrir-un-compte-bancaire-pro/',
#  'https://www.autoentrepreneur-pratique.fr/les-etapes-essentielles-pour-limmatriculation-dune-entreprise-en-france/',
#  'https://www.autoentrepreneur-pratique.fr/le-marketing-responsable-une-reponse-aux-attentes-des-consommateurs-contemporains/',
#  'https://www.autoentrepreneur-pratique.fr/limpact-incontournable-du-marketing-de-contenu-sur-la-croissance-de-votre-entreprise/',
#  'https://www.autoentrepreneur-pratique.fr/la-cle-de-la-reussite-des-entreprises-dans-la-transformation-digitale/',
#  'https://www.autoentrepreneur-pratique.fr/les-consequences-du-changement-climatique-sur-les-entreprises-de-nouveaux-defis-a-relever/',
#  'https://www.autoentrepreneur-pratique.fr/la-veille-reglementaire-et-la-gestion-des-risques-des-elements-cles-pour-les-entreprises/',
#  'https://www.autoentrepreneur-pratique.fr/les-avantages-du-calorifugeage-pour-les-coproprietes/',
#  'https://www.autoentrepreneur-pratique.fr/comment-se-presente-lintegration-des-nacelles-elevatrices-en-milieu-interieur/',
#  'https://www.autoentrepreneur-pratique.fr/une-carte-de-visite-dorure-a-chaud-pour-faire-bonne-impression/',
#  'https://www.autoentrepreneur-pratique.fr/strategies-efficaces-pour-fideliser-sa-clientele-durablement/',
#  'https://www.autoentrepreneur-pratique.fr/optimisez-votre-presence-en-ligne-faites-appel-a-un-consultant-seo-a-angers/',
#  'https://www.autoentrepreneur-pratique.fr/quest-ce-que-le-home-staging/',
#  'https://www.autoentrepreneur-pratique.fr/limportance-de-lagence-react-native-dans-le-developpement-dapplication-mobile/',
#  'https://www.autoentrepreneur-pratique.fr/comment-trouver-rapidement-un-travail-apres-les-etudes/',
#  'https://www.autoentrepreneur-pratique.fr/intershipper-reduire-labandon-de-panier-en-e-commerce/',
#  'https://www.autoentrepreneur-pratique.fr/quels-sont-les-4-facteurs-individuels-des-tms/',
#  'https://www.autoentrepreneur-pratique.fr/comment-promouvoir-et-vendre-vos-produits-avec-google-shopping/',
#  'https://www.autoentrepreneur-pratique.fr/les-specificites-des-formes-juridiques-dentreprise-tout-ce-que-vous-devez-savoir/',
#  'https://www.autoentrepreneur-pratique.fr/tout-ce-quil-faut-savoir-sur-les-salles-blanches/',
#  'https://www.autoentrepreneur-pratique.fr/graveur-laser-sur-metal-les-applications-et-lutilisation-avec-efficacite/',
#  'https://www.autoentrepreneur-pratique.fr/freelance-vs-agence-seo-lequel-choisir/',
#  'https://www.autoentrepreneur-pratique.fr/comment-rompre-un-contrat-alternance/',
#  'https://www.autoentrepreneur-pratique.fr/le-role-strategique-dun-logisticien-definition-et-decryptage/',
#  'https://www.autoentrepreneur-pratique.fr/limportance-cruciale-de-la-taille-euro-palette-en-logistique/',
#  'https://www.autoentrepreneur-pratique.fr/comment-anticiper-les-dates-de-paie-a-leducation-nationale-pour-mieux-gerer-son-budget/',
#  'https://www.autoentrepreneur-pratique.fr/les-avantages-dexternaliser-son-entreprise-avec-une-solution-de-comite-dentreprise/',
#  'https://www.autoentrepreneur-pratique.fr/le-role-strategique-dun-logisticien-definition-et-decryptage/',
#  'https://www.autoentrepreneur-pratique.fr/limportance-cruciale-de-la-taille-euro-palette-en-logistique/',
#  'https://www.autoentrepreneur-pratique.fr/comment-anticiper-les-dates-de-paie-a-leducation-nationale-pour-mieux-gerer-son-budget/',
#  'https://www.autoentrepreneur-pratique.fr/les-avantages-dexternaliser-son-entreprise-avec-une-solution-de-comite-dentreprise/',
#  'https://www.autoentrepreneur-pratique.fr/pourquoi-contacter-une-agence-specialisee-dans-la-conception-de-carte-pop-up/',
#  'https://www.autoentrepreneur-pratique.fr/comment-devenir-auto-entrepreneur/',
#  'https://www.autoentrepreneur-pratique.fr/que-peut-offrir-une-agence-de-developpement-web/',
#  'https://www.autoentrepreneur-pratique.fr/les-tendances-entrepreneuriales-en-vogue-en-ce-moment/',
#  'https://www.autoentrepreneur-pratique.fr/comment-le-lettrage-neon-illumine-la-communication-dune-enseigne-commerciale/',
#  'https://www.autoentrepreneur-pratique.fr/quel-meilleur-cadeau-quun-objet-personnalise/',
#  'https://www.autoentrepreneur-pratique.fr/pourquoi-faire-appel-a-un-coach-professionnel-pour-developper-ses-competences-et-sa-carriere/',
#  'https://www.autoentrepreneur-pratique.fr/optez-pour-des-drapeaux-publicitaires-pour-vos-campagnes-marketing/',
#  'https://www.autoentrepreneur-pratique.fr/comment-conjuguer-les-avantages-du-salariat-et-de-lentreprenariat-grace-au-portage-salarial/',
#  'https://www.autoentrepreneur-pratique.fr/les-obligations-fiscales-des-entreprises-declarations-et-paiement-des-impots-decryptes/',
#  'https://www.autoentrepreneur-pratique.fr/les-tendances-emergentes-de-la-transformation-numerique-en-entreprise/',
#  'https://www.autoentrepreneur-pratique.fr/branding-un-levier-essentiel-pour-le-succes-dune-entreprise/',
#  'https://www.autoentrepreneur-pratique.fr/comment-gagner-la-confiance-de-ses-prospects/',
#  'https://www.autoentrepreneur-pratique.fr/decouvrez-les-specificites-des-contrats-de-travail-en-vigueur/',
#  'https://www.autoentrepreneur-pratique.fr/les-indispensables-de-la-gestion-efficace-des-reseaux-sociaux-les-outils-a-connaitre/',
#  'https://www.autoentrepreneur-pratique.fr/les-vaisselles-jetables-pour-demarquer-votre-restaurant/',
#  'https://www.autoentrepreneur-pratique.fr/le-guest-blogging-pour-booster-son-referencement-comment-faire/',
#  'https://www.autoentrepreneur-pratique.fr/les-fondamentaux-pour-batir-et-preserver-des-relations-clients-solides/',
#  'https://www.autoentrepreneur-pratique.fr/les-regles-essentielles-en-matiere-de-protection-des-donnees-personnelles-comprendre-et-respecter-la-legislation/',
#  'https://www.autoentrepreneur-pratique.fr/les-formations-pour-se-reconvertir-dans-les-metiers-du-bien-etre/',
#  'https://www.autoentrepreneur-pratique.fr/les-interviews-dentreprise-ce-que-cela-peut-apporter-a-votre-entreprise/',
#  'https://www.autoentrepreneur-pratique.fr/les-contenues-videos-un-atout-important-pour-le-developpement-dune-entreprise/',
#  'https://www.autoentrepreneur-pratique.fr/quels-sont-les-ateliers-proposes-par-my-flying-box/',
#  'https://www.autoentrepreneur-pratique.fr/bien-definir-votre-tjm-avec-un-simulateur-tjm-salaire-net/',
#  'https://www.autoentrepreneur-pratique.fr/les-emballages-en-carton-ce-quil-faut-savoir/',
#  'https://www.autoentrepreneur-pratique.fr/comprendre-les-differents-types-de-societes-en-france-pour-mieux-choisir-celle-qui-convient-a-votre-entreprise/',
#  'https://www.autoentrepreneur-pratique.fr/connaitre-la-reglementation-autour-des-panneaux-de-chantier/',
#  'https://www.autoentrepreneur-pratique.fr/creer-un-site-internet-les-obligations-legales-a-respecter/',
#  'https://www.autoentrepreneur-pratique.fr/un-comparatif-des-plateformes-de-publicite-en-ligne-avantages-et-inconvenients-a-connaitre/',
#  'https://www.autoentrepreneur-pratique.fr/service-de-verification-de-numeros-mobiles-le-hlr-lookup/',
#  'https://www.autoentrepreneur-pratique.fr/les-5-meilleures-qualites-professionnelles-a-cultiver-pour-un-succes-a-long-terme/',
#  'https://www.autoentrepreneur-pratique.fr/soumission-des-fiches-de-paie-a-pole-emploi/',
#  'https://www.autoentrepreneur-pratique.fr/ou-placer-une-guerite-de-securite/',
#  'https://www.autoentrepreneur-pratique.fr/google-meet-ex-hangouts-meet-comment-utiliser-google-meet/',
#  'https://www.autoentrepreneur-pratique.fr/comment-le-marketing-digital-peut-aider-les-petites-entreprises-a-croitre/',
#  'https://www.autoentrepreneur-pratique.fr/limportance-du-contenu-de-qualite-pour-une-strategie-de-marketing-reussie/',
#  'https://www.autoentrepreneur-pratique.fr/pourquoi-et-comment-ameliorer-la-satisfaction-client/',
#  'https://www.autoentrepreneur-pratique.fr/comment-rediger-un-compte-rendu-dactivite/',
#  'https://www.autoentrepreneur-pratique.fr/comment-assurer-la-maintenance-dun-site-wordpress/',
#  'https://www.autoentrepreneur-pratique.fr/quel-est-linteret-de-disposer-dune-application-de-geomarketing/',
#  'https://www.autoentrepreneur-pratique.fr/ifttt-logiciel-de-productivite-entreprise-collaboratif/',
#  'https://www.autoentrepreneur-pratique.fr/un-centre-dappel-optimise-tous-nos-conseils/',
#  'https://www.autoentrepreneur-pratique.fr/procedure-dinjonction-de-payer-tout-ce-quil-y-a-savoir/',
#  'https://www.autoentrepreneur-pratique.fr/quelle-est-la-difference-entre-le-marketing-digital-et-le-marketing-traditionnel/',
#  'https://www.autoentrepreneur-pratique.fr/quels-sont-les-avantages-de-cette-agence-seo/',
#  'https://www.autoentrepreneur-pratique.fr/comment-bien-choisir-son-calendrier-publicitaire/',
#  'https://www.autoentrepreneur-pratique.fr/comment-elargir-votre-public-en-traduisant-votre-site-web/',
#  'https://www.autoentrepreneur-pratique.fr/que-dire-sur-le-monde-des-affaires-aux-usa/',
#  'https://www.autoentrepreneur-pratique.fr/horaires-du-1064-le-service-client-bouygues/',
#  'https://www.autoentrepreneur-pratique.fr/quelles-sont-les-attitudes-a-avoir-pour-reussir-sa-formation-professionnelle/',
#  'https://www.autoentrepreneur-pratique.fr/pourquoi-utiliser-des-bulles-gonflables-geantes-pour-vos-evenements-professionnels/',
#  'https://www.autoentrepreneur-pratique.fr/le-role-strategique-dun-logisticien-definition-et-decryptage/',
#  'https://www.autoentrepreneur-pratique.fr/limportance-cruciale-de-la-taille-euro-palette-en-logistique/',
#  'https://www.autoentrepreneur-pratique.fr/comment-anticiper-les-dates-de-paie-a-leducation-nationale-pour-mieux-gerer-son-budget/',
#  'https://www.autoentrepreneur-pratique.fr/les-avantages-dexternaliser-son-entreprise-avec-une-solution-de-comite-dentreprise/',
#  'https://www.autoentrepreneur-pratique.fr/le-role-strategique-dun-logisticien-definition-et-decryptage/',
#  'https://www.autoentrepreneur-pratique.fr/limportance-cruciale-de-la-taille-euro-palette-en-logistique/',
#  'https://www.autoentrepreneur-pratique.fr/comment-anticiper-les-dates-de-paie-a-leducation-nationale-pour-mieux-gerer-son-budget/',
#  'https://www.autoentrepreneur-pratique.fr/les-avantages-dexternaliser-son-entreprise-avec-une-solution-de-comite-dentreprise/',
#  'https://www.autoentrepreneur-pratique.fr/pourquoi-contacter-une-agence-specialisee-dans-la-conception-de-carte-pop-up/',
#  'https://www.autoentrepreneur-pratique.fr/quest-ce-que-le-dpo/',
#  'https://www.autoentrepreneur-pratique.fr/sas-ou-sarl-quel-statut-est-fait-pour-moi/',
#  'https://www.autoentrepreneur-pratique.fr/six-questions-a-poser-a-votre-agence-de-traduction/',
#  'https://www.autoentrepreneur-pratique.fr/les-5-qualites-dun-bon-traducteur/',
#  'https://www.autoentrepreneur-pratique.fr/pourquoi-opter-pour-une-automatisation-du-service-client-de-votre-entreprise/',
#  'https://www.autoentrepreneur-pratique.fr/pourquoi-consulter-un-blog-sur-les-actualites-dentreprise-de-marketing-et-du-digital/',
#  'https://www.autoentrepreneur-pratique.fr/la-banque-postale-pour-entreprises-presentation-application-et-operations-de-gestion-de-compte/',
#  'https://www.autoentrepreneur-pratique.fr/tout-savoir-sur-le-statut-de-micro-entrepreneur/',
#  'https://www.autoentrepreneur-pratique.fr/pour-quelles-raisons-former-son-personne-a-la-relation-client/',
#  'https://www.autoentrepreneur-pratique.fr/utiliser-des-carnets-autocopiants-pour-bien-organiser-le-travail-en-entreprise/',
#  'https://www.autoentrepreneur-pratique.fr/comment-garantir-la-reussite-dun-projet-evenementiel/',
#  'https://www.autoentrepreneur-pratique.fr/comment-les-entreprises-peuvent-elles-comptabiliser-des-dividendes-un-guide-pratique/',
#  'https://www.autoentrepreneur-pratique.fr/rupture-conventionnelle-quelles-sont-les-etapes/',
#  'https://www.autoentrepreneur-pratique.fr/mise-en-place-dun-reseau-social-professionnel/',
#  'https://www.autoentrepreneur-pratique.fr/la-musique-un-allie-incontournable-pour-ameliorer-lexperience-client-en-point-de-vente/',
#  'https://www.autoentrepreneur-pratique.fr/5-strategies-pour-ameliorer-le-marketing-de-votre-entreprise/',
#  'https://www.autoentrepreneur-pratique.fr/pourquoi-faire-appel-a-une-societe-de-conseil-en-management-dentreprise/',
#  'https://www.autoentrepreneur-pratique.fr/comment-diminuer-limpact-carbone-de-son-entreprise/',
#  'https://www.autoentrepreneur-pratique.fr/les-etapes-a-suivre-pour-une-bonne-prospection-commerciale-btob/',
#  'https://www.autoentrepreneur-pratique.fr/les-differentes-strategies-de-reduction-des-emissions-de-carbone-pour-atteindre-la-neutralite-carbone/',
#  'https://www.autoentrepreneur-pratique.fr/5-meilleures-strategies-de-marketing-pour-les-entrepreneurs/',
#  'https://www.autoentrepreneur-pratique.fr/10-astuces-pour-developper-votre-entreprise/',
#  'https://www.autoentrepreneur-pratique.fr/comment-mesurer-le-succes-dune-entreprise/',
#  'https://www.autoentrepreneur-pratique.fr/5-conseils-pour-faire-le-meilleur-choix-dagence-seo-a-strasbourg/',
#  'https://www.autoentrepreneur-pratique.fr/comment-bien-choisir-une-agence-seo-a-strasbourg/',
#  'https://www.autoentrepreneur-pratique.fr/lemail-de-prospection-dans-le-developpement-de-lentreprise/',
#  'https://www.autoentrepreneur-pratique.fr/cloison-amovible-ou-cloison-mobile-laquelle-choisir-pour-votre-bureau/',
#  'https://www.autoentrepreneur-pratique.fr/comment-optimiser-la-facturation-dans-votre-entreprise/',
#  'https://www.autoentrepreneur-pratique.fr/a-quoi-servent-des-etablis-professionnels/',
#  'https://www.autoentrepreneur-pratique.fr/credit-agricole-val-de-france-comment-ouvrir-un-compte-bancaire-pro/',
#  'https://www.autoentrepreneur-pratique.fr/comment-les-entreprises-peuvent-elles-tirer-le-meilleur-parti-des-outils-de-marketing-numerique/',
#  'https://www.autoentrepreneur-pratique.fr/comment-mettre-en-place-un-systeme-de-gestion-de-services-efficace/',
#  'https://www.autoentrepreneur-pratique.fr/quelle-formation-est-necessaire-pour-devenir-integrateur-web/',
#  'https://www.autoentrepreneur-pratique.fr/les-bonnes-questions-a-se-poser-avant-une-reconversion-professionnelle/',
#  'https://www.autoentrepreneur-pratique.fr/les-avantages-des-services-aux-entreprises/',
#  'https://www.autoentrepreneur-pratique.fr/le-management-directif-definition/',
#  'https://www.autoentrepreneur-pratique.fr/comment-acheter-un-fonds-de-commerce/',
#  'https://www.autoentrepreneur-pratique.fr/comment-bien-choisir-sa-banque/',
#  'https://www.autoentrepreneur-pratique.fr/investir-5-000-e-que-choisir/',
#  'https://www.autoentrepreneur-pratique.fr/comment-gerer-son-patrimoine-foncier/',
#  'https://www.autoentrepreneur-pratique.fr/comment-reduire-ses-charges-dentreprise/',
#  'https://www.autoentrepreneur-pratique.fr/comment-vendre-des-actions-en-bourse/',
#  'https://www.autoentrepreneur-pratique.fr/comment-devenir-guide-touristique-via-une-plateforme-web/',
#  'https://www.autoentrepreneur-pratique.fr/comment-trouver-le-meilleur-service-pour-votre-entreprise/',
#  'https://www.autoentrepreneur-pratique.fr/les-evolutions-du-droit-du-travail-dans-les-entreprises/',
#  'https://www.autoentrepreneur-pratique.fr/ecrire-le-bon-modele-de-contrat-de-travail-cdi-pour-votre-entreprise/',
#  'https://www.autoentrepreneur-pratique.fr/quels-sont-les-defis-a-relever-pour-les-services-aux-entreprises/',
#  'https://www.autoentrepreneur-pratique.fr/la-declaration-fiscale-les-differents-impots-applicables/',
#  'https://www.autoentrepreneur-pratique.fr/comment-choisir-lassurance-adequate-pour-votre-entreprise/',
#  'https://www.autoentrepreneur-pratique.fr/limpact-du-teletravail-sur-lenvironnement/',
#  'https://www.autoentrepreneur-pratique.fr/le-role-strategique-dun-logisticien-definition-et-decryptage/',
#  'https://www.autoentrepreneur-pratique.fr/limportance-cruciale-de-la-taille-euro-palette-en-logistique/',
#  'https://www.autoentrepreneur-pratique.fr/comment-anticiper-les-dates-de-paie-a-leducation-nationale-pour-mieux-gerer-son-budget/',
#  'https://www.autoentrepreneur-pratique.fr/les-avantages-dexternaliser-son-entreprise-avec-une-solution-de-comite-dentreprise/',
#  'https://www.autoentrepreneur-pratique.fr/le-role-strategique-dun-logisticien-definition-et-decryptage/',
#  'https://www.autoentrepreneur-pratique.fr/limportance-cruciale-de-la-taille-euro-palette-en-logistique/',
#  'https://www.autoentrepreneur-pratique.fr/comment-anticiper-les-dates-de-paie-a-leducation-nationale-pour-mieux-gerer-son-budget/',
#  'https://www.autoentrepreneur-pratique.fr/les-avantages-dexternaliser-son-entreprise-avec-une-solution-de-comite-dentreprise/',
#  'https://www.autoentrepreneur-pratique.fr/pourquoi-contacter-une-agence-specialisee-dans-la-conception-de-carte-pop-up/',
#  'https://www.autoentrepreneur-pratique.fr/faire-appel-a-un-traiteur-professionnel-pour-vos-evenements-dentreprise/',
#  'https://www.autoentrepreneur-pratique.fr/smart-rh-altran-les-avantages-dune-gestion-des-ressources-humaines-plus-intelligente/',
#  'https://www.autoentrepreneur-pratique.fr/toutes-les-informations-utiles-sur-le-releve-de-compte-bancaire/',
#  'https://www.autoentrepreneur-pratique.fr/comment-creer-une-newsletter-percutante-pour-augmenter-le-trafic-sur-votre-site-web/',
#  'https://www.autoentrepreneur-pratique.fr/comment-sortir-dun-contrat-a-duree-indeterminee/',
#  'https://www.autoentrepreneur-pratique.fr/quest-ce-quune-sarl/',
#  'https://www.autoentrepreneur-pratique.fr/la-responsabilite-sociale-des-entreprises-un-engagement-citoyen/',
#  'https://www.autoentrepreneur-pratique.fr/pourquoi-ne-pas-organiser-votre-evenement-professionnel-a-saint-malo/',
#  'https://www.autoentrepreneur-pratique.fr/quels-sont-les-impacts-de-mon-expert-en-gestion-sur-la-gestion-dune-pme/',
#  'https://www.autoentrepreneur-pratique.fr/pourquoi-et-comment-obtenir-le-statut-dauto-entrepreneur/',
#  'https://www.autoentrepreneur-pratique.fr/comment-calcule-t-on-la-capacite-dautofinancement-des-entreprises/',
#  'https://www.autoentrepreneur-pratique.fr/comment-trouver-une-entreprise-de-location-de-bennes-a-paris/',
#  'https://www.autoentrepreneur-pratique.fr/quel-materiel-de-manutention-pour-quel-chantier/',
#  'https://www.autoentrepreneur-pratique.fr/les-risques-industriels-en-france-ou-en-est-on/',
#  'https://www.autoentrepreneur-pratique.fr/pourquoi-le-balayage-a-sec-est-interdit-en-cuisine/',
#  'https://www.autoentrepreneur-pratique.fr/quel-bac-pour-devenir-avocat/',
#  'https://www.autoentrepreneur-pratique.fr/comment-choisir-son-apporteur-daffaires/',
#  'https://www.autoentrepreneur-pratique.fr/la-marge-sur-cout-variable/',
#  'https://www.autoentrepreneur-pratique.fr/quelles-sont-les-valeurs-fondamentales-de-la-vie/',
#  'https://www.autoentrepreneur-pratique.fr/la-gestion-dentreprise-une-opportunite/',
#  'https://www.autoentrepreneur-pratique.fr/creation-dentreprise-pourquoi-faire-appel-a-un-juriste-expert-en-creation-dentreprise/',
#  'https://www.autoentrepreneur-pratique.fr/pestel-lanalyse-indispensable-avant-de-creer-son-entreprise/',
#  'https://www.autoentrepreneur-pratique.fr/quel-est-le-role-social-et-societal-de-lentreprise/',
#  'https://www.autoentrepreneur-pratique.fr/appels-doffres-a-linternational-ayez-recourt-a-la-traduction/',
#  'https://www.autoentrepreneur-pratique.fr/quelle-est-la-valeur-de-levolution-de-la-technologie/',
#  'https://www.autoentrepreneur-pratique.fr/accident-de-travail-3-raisons-de-faire-appel-a-un-avocat-specialise-en-dommage-corporel/',
#  'https://www.autoentrepreneur-pratique.fr/faire-appel-a-un-service-de-secretaire-independant-les-avantages/',
#  'https://www.autoentrepreneur-pratique.fr/le-marche-du-cbd-est-il-porteur-actuellement/',
#  'https://www.autoentrepreneur-pratique.fr/les-etapes-pour-creer-une-selarl-en-ligne/',
#  'https://www.autoentrepreneur-pratique.fr/la-caracterisation-dune-entreprise-a-travers-son-organisation/',
#  'https://www.autoentrepreneur-pratique.fr/comment-entretenir-son-materiel-de-recolte/',
#  'https://www.autoentrepreneur-pratique.fr/comment-acheter-des-materiaux-de-renovation-energetique-en-tant-quauto-entrepreneur-du-btp/',
#  'https://www.autoentrepreneur-pratique.fr/sas-definition/',
#  'https://www.autoentrepreneur-pratique.fr/avocat-en-droit-du-travail-les-avantages-pour-une-entreprise/',
#  'https://www.autoentrepreneur-pratique.fr/immobilisations-corporelles-definition-comptable/',
#  'https://www.autoentrepreneur-pratique.fr/reseaux-sociaux-lesquels-privilegier-pour-une-presence-en-ligne-efficace/',
#  'https://www.autoentrepreneur-pratique.fr/un-mobilier-lumineux-en-guise-de-decoration-pour-vos-evenements/',
#  'https://www.autoentrepreneur-pratique.fr/freelance-reussir-son-site-internet-en-dejouant-les-pieges/',
#  'https://www.autoentrepreneur-pratique.fr/pour-ou-contre-la-vaisselle-biodegradable/',
#  'https://www.autoentrepreneur-pratique.fr/le-business-plan-definition-et-explications/',
#  'https://www.autoentrepreneur-pratique.fr/quelles-solutions-pour-mieux-gerer-les-ijss-et-atmp/',
#  'https://www.autoentrepreneur-pratique.fr/reussir-sa-strategie-commerciale-digitale-pourquoi-faut-il-suivre-une-formation-en-social-selling/',
#  'https://www.autoentrepreneur-pratique.fr/comment-se-passe-le-cpf/',
#  'https://www.autoentrepreneur-pratique.fr/comment-sont-traitees-vos-donnees-personnelles-sur-internet/',
#  'https://www.autoentrepreneur-pratique.fr/quel-est-le-prix-dune-traduction-certifiee/',
#  'https://www.autoentrepreneur-pratique.fr/le-meilleur-moyen-dassurer-la-gestion-des-stocks-e-commerce/',
#  'https://www.autoentrepreneur-pratique.fr/comment-creer-facilement-son-entreprise/',
#  'https://www.autoentrepreneur-pratique.fr/quel-role-joue-les-miroirs-de-circulation-dans-lentreprise/',
#  'https://www.autoentrepreneur-pratique.fr/comment-ouvrir-un-compte-bancaire-en-ligne/',
#  'https://www.autoentrepreneur-pratique.fr/pourquoi-suivre-une-formation-en-marketing-digital/',
#  'https://www.autoentrepreneur-pratique.fr/le-role-strategique-dun-logisticien-definition-et-decryptage/',
#  'https://www.autoentrepreneur-pratique.fr/limportance-cruciale-de-la-taille-euro-palette-en-logistique/',
#  'https://www.autoentrepreneur-pratique.fr/comment-anticiper-les-dates-de-paie-a-leducation-nationale-pour-mieux-gerer-son-budget/',
#  'https://www.autoentrepreneur-pratique.fr/les-avantages-dexternaliser-son-entreprise-avec-une-solution-de-comite-dentreprise/',
#  'https://www.autoentrepreneur-pratique.fr/le-role-strategique-dun-logisticien-definition-et-decryptage/',
#  'https://www.autoentrepreneur-pratique.fr/limportance-cruciale-de-la-taille-euro-palette-en-logistique/',
#  'https://www.autoentrepreneur-pratique.fr/comment-anticiper-les-dates-de-paie-a-leducation-nationale-pour-mieux-gerer-son-budget/',
#  'https://www.autoentrepreneur-pratique.fr/les-avantages-dexternaliser-son-entreprise-avec-une-solution-de-comite-dentreprise/',
#  'https://www.autoentrepreneur-pratique.fr/pourquoi-contacter-une-agence-specialisee-dans-la-conception-de-carte-pop-up/',
#  'https://www.autoentrepreneur-pratique.fr/entreprise-comment-bien-choisir-un-expert-comptable/',
#  'https://www.autoentrepreneur-pratique.fr/prevoir-ses-finances-en-tant-quauto-entrepreneur/',
#  'https://www.autoentrepreneur-pratique.fr/restaurateurs-preparez-vos-terrasses-pour-lete-grace-a-nos-5-conseils/',
#  'https://www.autoentrepreneur-pratique.fr/10-conseils-pour-choisir-un-prestataire-de-traduction/',
#  'https://www.autoentrepreneur-pratique.fr/quel-est-le-role-dune-agence-de-traduction-touristique/',
#  'https://www.autoentrepreneur-pratique.fr/les-principaux-avantages-de-travailler-avec-un-traducteur-slovaque-independant/',
#  'https://www.autoentrepreneur-pratique.fr/que-prendre-en-compte-pour-bien-choisir-son-assurance-habitation/',
#  'https://www.autoentrepreneur-pratique.fr/pourquoi-contacter-une-agence-damenagement-pratique-et-esthetique-pour-les-collectivites/',
#  'https://www.autoentrepreneur-pratique.fr/comment-deposer-une-marque/',
#  'https://www.autoentrepreneur-pratique.fr/credit-mutuel-savoie-mont-blanc-comment-ouvrir-un-compte-bancaire-pro/',
#  'https://www.autoentrepreneur-pratique.fr/comment-mettre-en-place-une-societe-dassurance/',
#  'https://www.autoentrepreneur-pratique.fr/tout-savoir-sur-le-metier-de-secretaire/',
#  'https://www.autoentrepreneur-pratique.fr/optimisez-les-flux-logistiques-de-votre-entreprise-avec-des-logiciels/',
#  'https://www.autoentrepreneur-pratique.fr/quelle-est-la-forme-juridique-de-lentreprise/',
#  'https://www.autoentrepreneur-pratique.fr/accroitre-sa-notoriete-sur-google-comment-faire/',
#  'https://www.autoentrepreneur-pratique.fr/choisir-sa-franchise-en-5-questions/',
#  'https://www.autoentrepreneur-pratique.fr/comment-trouver-un-cfa/',
#  'https://www.autoentrepreneur-pratique.fr/livreur-uber-eats-les-etapes-pour-faire-ce-job/',
#  'https://www.autoentrepreneur-pratique.fr/comment-bien-utiliser-hubspot/',
#  'https://www.autoentrepreneur-pratique.fr/quel-metier-avec-un-dec/',
#  'https://www.autoentrepreneur-pratique.fr/comment-se-lancer-sur-le-web/',
#  'https://www.autoentrepreneur-pratique.fr/comment-peut-se-justifier-le-choix-dun-erp-open-source/',
#  'https://www.autoentrepreneur-pratique.fr/comment-faire-pour-creer-un-lien-internet/',
#  'https://www.autoentrepreneur-pratique.fr/le-role-strategique-dun-logisticien-definition-et-decryptage/',
#  'https://www.autoentrepreneur-pratique.fr/limportance-cruciale-de-la-taille-euro-palette-en-logistique/',
#  'https://www.autoentrepreneur-pratique.fr/comment-anticiper-les-dates-de-paie-a-leducation-nationale-pour-mieux-gerer-son-budget/',
#  'https://www.autoentrepreneur-pratique.fr/les-avantages-dexternaliser-son-entreprise-avec-une-solution-de-comite-dentreprise/',
#  'https://www.autoentrepreneur-pratique.fr/le-role-strategique-dun-logisticien-definition-et-decryptage/',
#  'https://www.autoentrepreneur-pratique.fr/limportance-cruciale-de-la-taille-euro-palette-en-logistique/',
#  'https://www.autoentrepreneur-pratique.fr/comment-anticiper-les-dates-de-paie-a-leducation-nationale-pour-mieux-gerer-son-budget/',
#  'https://www.autoentrepreneur-pratique.fr/les-avantages-dexternaliser-son-entreprise-avec-une-solution-de-comite-dentreprise/',
#  'https://www.autoentrepreneur-pratique.fr/pourquoi-contacter-une-agence-specialisee-dans-la-conception-de-carte-pop-up/']

# %% [markdown]
# ### Récupérer les infos qu'on souhaite sur chaque article

# %%
def get_article_info(r, url_article):
    # Liste de variables
    noms_variables = [
        'url',  # URL scrapée
        'canonical_url', 'slug', 'meta_title', 'meta_desc',  # Infos issues de la balise meta
        'date_published', 'date_modified',  # Infos dates
        'author',  # Parfois en meta
        'title', 'category', 'views', 'reading_time',  # Metadonnées contenues ailleurs que dans la balise meta
        'content', 'raw_content'  # Contenu de la page
    ]
    
    # Initialisation du dictionnaire
    data = {nom: np.nan for nom in noms_variables}
    
    data['url'] = url_article
    
    soup = BeautifulSoup(r.content, 'lxml')
    
    try:
        data['canonical_url'] = soup.find('link', {'rel': 'canonical'})['href']
    except:
        pass
    
    try:
        data['slug'] = data['canonical_url'].split('/')[-2] if data['canonical_url'] else np.nan
    except:
        pass

    try:
        data['meta_title'] = soup.find('meta', {'property': 'og:title'})['content']
    except:
        pass

    try:
        data['meta_desc'] = soup.find('meta', {'property': 'og:description'})['content']
    except:
        pass

    try:
        data['date_published'] = pd.to_datetime(soup.find('meta', {'property': 'article:published_time'})['content'][:-6], utc=True)
    except:
        pass

    try:
        data['date_modified'] = pd.to_datetime(soup.find('meta', {'property': 'article:modified_time'})['content'][:-6], utc=True)
    except:
        pass

    try:
        data['author'] = soup.find("meta", {'name': 'author'})['content']
    except:
        try:
            data['author'] = soup.find(class_="author").text.split('Publié par ')[-1]
        except:
            pass

    try:
        data['title'] = soup.find('h1').text
    except:
        pass

    try:
        data['category'] = [x.text for x in soup.find_all(class_="tdb-entry-category")]
    except:
        pass

    try:
        data['views'] = int(soup.find('div', class_="views").text)
    except:
        pass

    try:
        data['reading_time'] = int(soup.find('meta', {'name': 'twitter:data2'})['content'].split(' ')[0]) if soup.find('meta', {'name': 'twitter:data2'}) and 'minutes' in soup.find('meta', {'name': 'twitter:data2'})['content'] else np.nan
    except:
        pass

    try:
        data['content'] = BeautifulSoup(str(soup.find("div", class_="td-post-content")), 'lxml').get_text()
    except:
        pass

    try:
        data['raw_content'] = str(soup.find("div", class_="td-post-content"))
    except:
        pass

    # Ajout de features
    data['length'] = len(str(data['content']).split())
    
    if pd.notnull(data['date_published']):
        data['days_since_published'] = int((pd.Timestamp.now(tz='UTC') - data['date_published']).days)
    else:
        data['days_since_published'] = np.nan
    
    # Création de la série
    series = pd.Series(data)
    series.name = url_article
    
    # Ajout de features supplémentaires
    if pd.notnull(data.get('views')) and pd.notnull(data.get('days_since_published')):
        series['views_daily'] = series['views'] / (series['days_since_published']+1)
        series['views_monthly'] = series['views_daily'] * 30
    else:
        series['views_daily'] = np.nan
        series['views_monthly'] = np.nan
    
    series['website'] = top_url
    
    return series

# %% [markdown]
# ## Fonction finale

# %%
article_list = get_articles_on_page(get_all_results_pages(get_max_page_results(top_search_url)))
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]

# %% [markdown]
# ### Fonction finale

# %%
# Import des packages
from concurrent.futures import ThreadPoolExecutor, as_completed
import time

# Initialisation du compteur
start_time = time.time()

# Fonction principale qui sauvegarde le DataFrame dans un fichier CSV et le retourne
def scrape_all_articles(urls, batch_size=250, max_workers=20):
    # Initialisation d'une session réutilisable
    session = rq.Session()

    # Création d'une fonction qui traite chaque URL
    def process_url(url):
            try:
                r = session.get(url)
                return get_article_info(r, url)
            except Exception as e:
                print(f"Erreur pour {url}: {str(e)}")
                return pd.Series(name=url)

    # Utilise ThreadPoolExecutor pour paralléliser le traitement
    results = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Parcourt la liste d'URLs par lots de taille 'batch_size'
        for i in range(0, len(urls), batch_size):
            # Extrait un lot d'URLs
            batch = urls[i:i+batch_size]
            # Crée et soumet des tâches pour chaque URL du lot
            futures = [executor.submit(process_url, url) for url in batch]
            
            # Traite les résultats au fur et à mesure qu'ils sont terminés
            for future in tqdm(as_completed(futures), total=len(batch), desc=f"Batch {i//batch_size + 1} / {len(urls)//batch_size+1}"):
                # Récupère le résultat de la tâche
                result = future.result()
                # Si le résultat n'est pas None (pas d'erreur), l'ajoute aux résultats
                if result is not None:
                    results.append(result)
    
    # Création du DataFrame final
    df_final = pd.DataFrame(results)
    
    # Ajout de colonnes calculées
    df_final['website'] = top_url
    df_final['scraping_date'] = pd.Timestamp.now(tz='UTC')

    df_final.columns = ['article_url', 'article_canonical_url', 'article_slug',
       'article_meta_title', 'article_meta_desc', 'article_date_published',
       'article_date_modified', 'article_author', 'article_title',
       'article_category', 'article_views', 'article_reading_time',
       'article_content', 'article_raw_content', 'article_length',
       'days_since_published', 'article_views_daily', 'article_views_monthly',
       'website', 'scraping_date']

    # Sauvegarde en CSV
    df_final.to_csv(f'scraping_{abbr}.csv', sep='|', index=True)
    print(f"Scraping terminé. Total d'articles : {len(df_final)}")
    return df_final

df = scrape_all_articles(article_list)

end_time = time.time()
print(end_time - start_time)
# Out:
# Batch 1 / 3:   0%|          | 0/250 [00:00<?, ?it/s]
# Batch 2 / 3:   0%|          | 0/250 [00:00<?, ?it/s]
# Batch 3 / 3:   0%|          | 0/4 [00:00<?, ?it/s]
# Scraping terminé. Total d'articles : 504
# 87.50184345245361

# %%
# Création d'un rapport de profil avec pandas_profiling
profile = ProfileReport(df, title=f"{abbr.title()} Scraping Report", explorative=True)

# Génération du rapport au format HTML
profile.to_file(f"scraping_report_{abbr}.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# c:\Users\aurel\AppData\Local\Programs\Python\Python312\Lib\site-packages\ydata_profiling\model\correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'cannot reindex on an axis with duplicate labels')
#   warnings.warn(
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
