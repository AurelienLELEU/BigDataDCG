# %% [markdown]
# # Scraping DCG.media

# %% [markdown]
# %pip install bs4 pandas numpy ydata-profiling plotly tqdm ipywidgets

# %%
### SCRAPING
import requests as rq
from bs4 import BeautifulSoup

### DATABASES
import pandas as pd
import numpy as np
from ydata_profiling import ProfileReport

### VISUALISATION
#import plotly.express as px

### DIVERS
from tqdm.notebook import tqdm

### FORMAT
from datetime import datetime, timezone
import time
import json

# %% [markdown]
# ## Définition des variables

# %%
website = 'kf-finances'
abbr = 'kff'
tld = '.com'

# %%
page_number = 1
top_url = f'https://www.{website+tld}'
top_search_url = f'{top_url}/page/{page_number}/?s'

# %% [markdown]
# ## Définition des fonctions

# %% [markdown]
# ### Obtenir le nombre de pages de résultats de recherche

# %%
def get_max_page_results(top_search_url):
    r = rq.get(top_search_url)
    soup = BeautifulSoup(r.content)
    pagenumbers = soup.find_all('a', class_ = 'page-numbers')
    page_final = pagenumbers[-2].text
    return int(page_final)
get_max_page_results(top_search_url)
# Out:
# 11

# %% [markdown]
# ### Obtenir la liste des pages de résultats de recherche

# %%
def get_all_results_pages(page_final):
    urls = []
    for i in range(page_final):
        i = f'{top_url}/page/{i+1}/?s'
        urls.append(i)
    return urls
get_all_results_pages(get_max_page_results(top_search_url))
# Out:
# ['https://www.kf-finances.com/page/1/?s',
#  'https://www.kf-finances.com/page/2/?s',
#  'https://www.kf-finances.com/page/3/?s',
#  'https://www.kf-finances.com/page/4/?s',
#  'https://www.kf-finances.com/page/5/?s',
#  'https://www.kf-finances.com/page/6/?s',
#  'https://www.kf-finances.com/page/7/?s',
#  'https://www.kf-finances.com/page/8/?s',
#  'https://www.kf-finances.com/page/9/?s',
#  'https://www.kf-finances.com/page/10/?s',
#  'https://www.kf-finances.com/page/11/?s']

# %% [markdown]
# ### Obtenir tous les liens des articles sur une page de recherche

# %%
def get_articles_on_page(search_results):
    urls_articles = []
    s = rq.Session()
    for p in tqdm(search_results):
        r = s.get(p)
        soup = BeautifulSoup(r.content)
        articles = soup.find_all('h2', class_ = 'title')
        for article in articles:
            url = article.find('a', href=True)['href']
            urls_articles.append(url)
    return urls_articles

# %%
get_articles_on_page(get_all_results_pages(get_max_page_results(top_search_url)))
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
# ['https://www.kf-finances.com/gerez-votre-epargne-efficacement-sur-www-ca-centreloire-fr/',
#  'https://www.kf-finances.com/prelevement-sepa-asp-quest-ce-que-cest-et-comment-le-gerer/',
#  'https://www.kf-finances.com/les-avantages-insoupconnes-de-cmut-direct-pro-pour-les-petites-entreprises/',
#  'https://www.kf-finances.com/comprendre-le-smic-en-thailande-un-guide-pour-les-expatries-francophones/',
#  'https://www.kf-finances.com/www-ca-cmds-fr-acceder-a-mes-comptes-vade-mecum-exhaustif-pour-neophytes/',
#  'https://www.kf-finances.com/comment-utiliser-efficacement-le-service-credit-agricole-en-ligne-en-normandie-seine/',
#  'https://www.kf-finances.com/coopanet-banque-solidaire-avantages-et-services-pour-leconomie-sociale/',
#  'https://www.kf-finances.com/opodo-et-le-paiement-echelonne-une-nouvelle-facon-de-voyager/',
#  'https://www.kf-finances.com/conversion-salaire-de-1500-euros-brut-a-net-calcul-et-explications/',
#  'https://www.kf-finances.com/la-raison-sociale-dune-entreprise-signification-et-processus-en-suisse/',
#  'https://www.kf-finances.com/calculer-votre-salaire-net-a-partir-de-25000e-brut-annuel-voici-comment-faire-2/',
#  'https://www.kf-finances.com/decouvrez-les-avantages-du-service-monespacesecuritas-pour-ses-utilisateurs/',
#  'https://www.kf-finances.com/calculer-votre-salaire-net-a-partir-de-25000e-brut-annuel-voici-comment-faire/',
#  'https://www.kf-finances.com/comment-verifier-une-adresse-postale/',
#  'https://www.kf-finances.com/1850-brut-en-net-calculer-son-salaire-en-net-mensuel-cadre-et-non-cadre/',
#  'https://www.kf-finances.com/real-debrid-les-tarifs-et-services-proposes/',
#  'https://www.kf-finances.com/lcl-particuliers-secure-connexion-a-lespace/',
#  'https://www.kf-finances.com/cmut-direct-connexion-espace-client-credit-mutuel/',
#  'https://www.kf-finances.com/ou-trouver-le-code-nan-cesu/',
#  'https://www.kf-finances.com/comment-simplifier-louverture-dun-compte-professionnel-en-ligne-pour-votre-entreprise/',
#  'https://www.kf-finances.com/comprendre-le-bareme-de-pension-alimentaire-le-dechiffrer-pour-mieux-lappliquer/',
#  'https://www.kf-finances.com/comment-optimiser-votre-experience-de-connexion-a-la-societe-generale-astuces-et-conseils-pratiques/',
#  'https://www.kf-finances.com/comprendre-www-lefil-pour-une-gestion-bancaire-optimale/',
#  'https://www.kf-finances.com/comment-joindre-efficacement-harmonie-mutuelle-astuces-et-conseils/',
#  'https://www.kf-finances.com/epsens-un-atout-indispensable-pour-les-investisseurs-avises/',
#  'https://www.kf-finances.com/compte-carpa-et-delais-de-reglement-astuces-pour-une-gestion-irreprochable/',
#  'https://www.kf-finances.com/comparateur-assurance-voiture-devis-gratuits-avec-mon-gustave/',
#  'https://www.kf-finances.com/comment-avoir-une-carte-bancaire-sans-banque/',
#  'https://www.kf-finances.com/les-pieges-a-eviter-lors-du-remplissage-du-cerfa-2044-en-2024/',
#  'https://www.kf-finances.com/pret-bateau-la-solution-ideale-pour-votre-projet/',
#  'https://www.kf-finances.com/linvestisseur-heureux-conseils-pour-une-finance-sereine/',
#  'https://www.kf-finances.com/annuler-prelevement-automatique-credit-agricole-etapes-simples-et-rapides/',
#  'https://www.kf-finances.com/quel-objet-se-loue-le-mieux/',
#  'https://www.kf-finances.com/qui-se-cache-derriere-fortuneo/',
#  'https://www.kf-finances.com/quel-montant-maximum-paypal/',
#  'https://www.kf-finances.com/quand-faut-il-acheter-du-bitcoin/',
#  'https://www.kf-finances.com/quelle-est-la-base-de-remboursement-de-la-securite-sociale-pour-les-lunettes/',
#  'https://www.kf-finances.com/comment-faire-pour-acheter-des-dollars/',
#  'https://www.kf-finances.com/comment-activer-un-tracker/',
#  'https://www.kf-finances.com/comment-choisir-les-mots-parfaits-pour-un-discours-de-depart-a-la-retraite-inoubliable/',
#  'https://www.kf-finances.com/calculer-precisement-son-salaire-de-professeur-une-simulation-exhaustive/',
#  'https://www.kf-finances.com/zoom-sur-le-meilleur-comparatif-dassurances-voitures-en-2024/',
#  'https://www.kf-finances.com/comprendre-le-solde-debiteur-en-comptabilite-tout-ce-que-vous-devez-savoir/',
#  'https://www.kf-finances.com/epargne-salariale-la-poste-comprendre-les-avantages-et-options/',
#  'https://www.kf-finances.com/methode-de-linvestisseur-heureux-strategies-pour-une-rentabilite-optimale/',
#  'https://www.kf-finances.com/quest-ce-que-la-loa-bateau/',
#  'https://www.kf-finances.com/credit-a-la-consommation-un-meilleur-allie-pour-faire-un-achat-exceptionnel-2/',
#  'https://www.kf-finances.com/carre-jaune-signification-et-utilisation-dans-differents-contextes-2/',
#  'https://www.kf-finances.com/carre-jaune-signification-et-utilisation-dans-differents-contextes/',
#  'https://www.kf-finances.com/quel-est-lessentiel-a-savoir-sur-le-devis-assurance-habitation-proposee-par-la-maaf/',
#  'https://www.kf-finances.com/ou-trouver-le-code-nan-cesu/',
#  'https://www.kf-finances.com/pourquoi-utiliser-un-comparateur-de-banques/',
#  'https://www.kf-finances.com/est-il-interessant-dacheter-des-dollars/',
#  'https://www.kf-finances.com/quel-objet-peut-prendre-de-la-valeur/',
#  'https://www.kf-finances.com/comment-ouvrir-un-compte-bancaire-sans-domicile-fixe/',
#  'https://www.kf-finances.com/gerez-votre-epargne-efficacement-sur-www-ca-centreloire-fr/',
#  'https://www.kf-finances.com/prelevement-sepa-asp-quest-ce-que-cest-et-comment-le-gerer/',
#  'https://www.kf-finances.com/les-avantages-insoupconnes-de-cmut-direct-pro-pour-les-petites-entreprises/',
#  'https://www.kf-finances.com/comprendre-le-smic-en-thailande-un-guide-pour-les-expatries-francophones/',
#  'https://www.kf-finances.com/www-ca-cmds-fr-acceder-a-mes-comptes-vade-mecum-exhaustif-pour-neophytes/',
#  'https://www.kf-finances.com/est-ce-que-laah-est-un-revenu/',
#  'https://www.kf-finances.com/quel-objet-peut-prendre-de-la-valeur/',
#  'https://www.kf-finances.com/entre-attente-et-realite-la-date-des-salaires-des-professeurs/',
#  'https://www.kf-finances.com/comparaison-historique-de-la-valeur-du-point-convention-66-tendances-et-perspectives/',
#  'https://www.kf-finances.com/solution-ged-pour-les-ressources-humaines-un-outil-impressionnant/',
#  'https://www.kf-finances.com/taux-de-change-du-franc-suisse-comprendre-et-optimiser-vos-transactions/',
#  'https://www.kf-finances.com/comprendre-et-optimiser-votre-connexion-credit-mutuel-pour-une-experience-bancaire-en-ligne-securisee/',
#  'https://www.kf-finances.com/nirio-le-compte-projets-une-solution-depargne-pour-vos-envies-et-projets-personnels/',
#  'https://www.kf-finances.com/souscription-au-gfp-plan-sante-les-etapes-indispensables/',
#  'https://www.kf-finances.com/quels-impacts-dun-releve-dinformation-assurance-sur-votre-prime-dassurance-auto/',
#  'https://www.kf-finances.com/acheter-des-actions-lvmh-est-ce-une-strategie-rentable/',
#  'https://www.kf-finances.com/les-meilleures-assurances-habitation-pour-les-etudiants-comparez-les-options-matmut-gmf-maif-et-carrefour/',
#  'https://www.kf-finances.com/la-loi-pinel-une-aubaine-pour-les-investisseurs-en-corse/',
#  'https://www.kf-finances.com/comment-investir-sur-etoro/',
#  'https://www.kf-finances.com/reconnaitre-une-piece-de-monnaie-rare/',
#  'https://www.kf-finances.com/comment-declarer-un-temps-partiel-a-la-caf/',
#  'https://www.kf-finances.com/quest-ce-quune-preuve-de-virement/',
#  'https://www.kf-finances.com/quel-budget-nourriture-pour-une-personne-seule/',
#  'https://www.kf-finances.com/comment-ouvrir-un-compte-bancaire-sans-domicile-fixe/',
#  'https://www.kf-finances.com/quelle-crypto-va-exploser/',
#  'https://www.kf-finances.com/comment-acheter-de-lether/',
#  'https://www.kf-finances.com/est-il-interessant-dacheter-des-dollars/',
#  'https://www.kf-finances.com/comment-calculer-la-valeur-ajoutee-ses-seconde/',
#  'https://www.kf-finances.com/pourquoi-les-entreprises-doivent-souscrire-a-une-couverture-sante/',
#  'https://www.kf-finances.com/quest-ce-que-cest-raccoon-stealer/',
#  'https://www.kf-finances.com/quel-format-multimedia-choisir/',
#  'https://www.kf-finances.com/comptabilisation-des-pourboires-astuces-et-normes-comptables/',
#  'https://www.kf-finances.com/resilier-votre-assurance-auto-groupama-en-quelques-clics-mode-demploi-7/',
#  'https://www.kf-finances.com/resilier-votre-assurance-auto-groupama-en-quelques-clics-mode-demploi-6/',
#  'https://www.kf-finances.com/assurance-auto-maaf-comment-changer-facilement-son-adresse-de-residence/',
#  'https://www.kf-finances.com/comment-utiliser-filbanque-pour-acceder-a-mes-comptes-cic-en-toute-securite/',
#  'https://www.kf-finances.com/comment-vendre-des-items-rocket-league-et-obtenir-le-meilleur-prix/',
#  'https://www.kf-finances.com/quelle-scpi-logistique-choisir/',
#  'https://www.kf-finances.com/comment-consulter-mes-comptes-bnp-paribas/',
#  'https://www.kf-finances.com/quelle-banque-pour-cofinoga/',
#  'https://www.kf-finances.com/credit-agricole-aquitaine-comment-ouvrir-un-compte-bancaire-pro/',
#  'https://www.kf-finances.com/comment-ouvrir-un-compte-bancaire-en-ligne-en-suisse/',
#  'https://www.kf-finances.com/comment-deposer-de-largent-liquide-dans-une-banque-en-ligne/',
#  'https://www.kf-finances.com/comment-obtenir-un-pret-caf-pour-une-voiture/',
#  'https://www.kf-finances.com/comment-utiliser-le-guichet-automatique/',
#  'https://www.kf-finances.com/comprendre-le-fonctionnement-du-service-securise-bnp-1-pour-vos-transactions-bancaires/',
#  'https://www.kf-finances.com/tout-ce-quil-faut-savoir-sur-le-fonctionnement-dun-perco/',
#  'https://www.kf-finances.com/optimiser-lutilisation-du-cheque-portefeuille-pour-vos-transactions-courantes/',
#  'https://www.kf-finances.com/maximiser-vos-profits-avec-honeyminer-une-exploration-detaillee-du-minage-de-crypto-monnaies/',
#  'https://www.kf-finances.com/comprendre-labonnement-des-charges-en-comptabilite-astuces-et-methodes/',
#  'https://www.kf-finances.com/trouver-carte-bancaire-perdue-meilleures-apps-pour-localiser-rapidement/',
#  'https://www.kf-finances.com/comment-obtenir-un-logement-sans-emploi/',
#  'https://www.kf-finances.com/comment-optimiser-la-gestion-de-votre-compte-hsbc-en-ligne/',
#  'https://www.kf-finances.com/compte-bancaire-pour-mineur-avec-carte-de-paiement-quelles-sont-les-options-securisees/',
#  'https://www.kf-finances.com/comment-optimiser-la-gestion-de-mon-compte-en-un-resume-efficace/',
#  'https://www.kf-finances.com/ou-trouver-le-code-nan-cesu/',
#  'https://www.kf-finances.com/pourquoi-utiliser-un-comparateur-de-banques/',
#  'https://www.kf-finances.com/est-il-interessant-dacheter-des-dollars/',
#  'https://www.kf-finances.com/quel-objet-peut-prendre-de-la-valeur/',
#  'https://www.kf-finances.com/comment-ouvrir-un-compte-bancaire-sans-domicile-fixe/',
#  'https://www.kf-finances.com/gerez-votre-epargne-efficacement-sur-www-ca-centreloire-fr/',
#  'https://www.kf-finances.com/prelevement-sepa-asp-quest-ce-que-cest-et-comment-le-gerer/',
#  'https://www.kf-finances.com/les-avantages-insoupconnes-de-cmut-direct-pro-pour-les-petites-entreprises/',
#  'https://www.kf-finances.com/comprendre-le-smic-en-thailande-un-guide-pour-les-expatries-francophones/',
#  'https://www.kf-finances.com/www-ca-cmds-fr-acceder-a-mes-comptes-vade-mecum-exhaustif-pour-neophytes/',
#  'https://www.kf-finances.com/loptimisation-fiscale-conseils-pour-les-entrepreneurs/',
#  'https://www.kf-finances.com/gagner-de-largent-par-la-musique-decouvrez-soonvibes/',
#  'https://www.kf-finances.com/blueprintforsafety-org-la-reference-pour-la-securite-au-travail/',
#  'https://www.kf-finances.com/analyser-levaluation-dune-entreprise-cotee-en-bourse-les-cles-de-comprehension/',
#  'https://www.kf-finances.com/la-resiliation-direct-assurance-en-cas-de-non-paiement/',
#  'https://www.kf-finances.com/comment-acheter-de-lether-2/',
#  'https://www.kf-finances.com/quelle-est-la-difference-entre-la-carsat-et-assurance-retraite/',
#  'https://www.kf-finances.com/quand-sarrete-laah/',
#  'https://www.kf-finances.com/comment-envoyer-un-mail-a-lassurance-retraite/',
#  'https://www.kf-finances.com/comment-se-servir-dun-pea/',
#  'https://www.kf-finances.com/comment-declarer-deux-residences-principales/',
#  'https://www.kf-finances.com/comment-obtenir-un-rib-sans-carte-bancaire/',
#  'https://www.kf-finances.com/demander-un-devis-pour-assurer-une-voiture-que-devez-vous-retenir/',
#  'https://www.kf-finances.com/conseil-patrimonial-lart-doptimiser-son-patrimoine-et-preparer-lavenir/',
#  'https://www.kf-finances.com/suivi-en-temps-reel-levolution-de-la-paire-euro-dollar/',
#  'https://www.kf-finances.com/la-place-des-cryptos-dans-la-finance-mondiale/',
#  'https://www.kf-finances.com/forums-dassurance-auto-comment-participer-efficacement-a-la-communaute/',
#  'https://www.kf-finances.com/comment-savoir-ou-investir-en-bourse-2/',
#  'https://www.kf-finances.com/mon-compte-alsolia-connexion-et-gestion-facile/',
#  'https://www.kf-finances.com/optimisez-votre-projet-immobilier-avec-le-simulateur-de-capacite-demprunt/',
#  'https://www.kf-finances.com/tout-ce-quil-faut-savoir-sur-les-virements-sepa-instantanes-pour-professionnels/',
#  'https://www.kf-finances.com/investir-en-ehpad-les-avantages-a-long-terme/',
#  'https://www.kf-finances.com/guide-complet-sur-les-deductions-fiscales-accessibles-aux-particuliers/',
#  'https://www.kf-finances.com/delai-de-paiement-solde-de-tout-compte-details-et-obligations-legales/',
#  'https://www.kf-finances.com/quelle-est-la-region-la-moins-chere-de-france/',
#  'https://www.kf-finances.com/ing-direct-aide-a-la-connexion/',
#  'https://www.kf-finances.com/quelle-somme-declarer-au-pole-emploi/',
#  'https://www.kf-finances.com/comment-maximiser-les-avantages-du-credit-immobilier-pour-securiser-votre-investissement/',
#  'https://www.kf-finances.com/lld-profitez-dun-vehicule-neuf-sans-les-couts-dachat/',
#  'https://www.kf-finances.com/comment-optimiser-votre-solution-de-recouvrement-de-creances-avec-lautomatisation/',
#  'https://www.kf-finances.com/comment-devenir-maitre-de-vos-finances-conseils-pratiques-pour-des-decisions-eclairees/',
#  'https://www.kf-finances.com/comment-investir-grace-a-une-assurance-vie/',
#  'https://www.kf-finances.com/1-million-de-won-en-euro-conversion-et-valeur/',
#  'https://www.kf-finances.com/1-million-de-won-en-euro-comment-convertir-les-devises/',
#  'https://www.kf-finances.com/banque-en-ligne-quelles-possibilites-pour-un-credit/',
#  'https://www.kf-finances.com/duree-durant-laquelle-un-huissier-peut-reclamer-une-dette-en-france/',
#  'https://www.kf-finances.com/naviguer-sur-acm-mon-compte-astuces-et-conseils/',
#  'https://www.kf-finances.com/comment-trouver-un-bon-expert-comptable-a-paris/',
#  'https://www.kf-finances.com/le-credit-en-ligne-une-methode-efficace/',
#  'https://www.kf-finances.com/comment-gerer-le-risque-de-credit-pour-proteger-vos-investissements/',
#  'https://www.kf-finances.com/pourquoi-cloturer-un-pel-sans-projet-immobilier-peut-etre-avantageux/',
#  'https://www.kf-finances.com/quel-est-le-role-dun-expert-comptable/',
#  'https://www.kf-finances.com/saisir-lefficacite-du-blocage-pce-en-cas-de-saisie-bancaire/',
#  'https://www.kf-finances.com/comment-un-conseiller-en-investissement-peut-transformer-votre-strategie-financiere/',
#  'https://www.kf-finances.com/comment-choisir-la-meilleure-assurance-auto-pour-votre-voiture-neuve/',
#  'https://www.kf-finances.com/2-800-brut-en-net-comprenez-votre-salaire-apres-impots/',
#  'https://www.kf-finances.com/e-carte-bleue-nomade-securisez-vos-achats-en-ligne-avantages-et-usage/',
#  'https://www.kf-finances.com/les-dimensions-des-lingots-dor-et-leur-impact-sur-la-valeur-du-metal-precieux/',
#  'https://www.kf-finances.com/qui-est-la-banque-en-ligne-du-credit-agricole/',
#  'https://www.kf-finances.com/quel-apport-pour-etre-marchand-de-bien/',
#  'https://www.kf-finances.com/ou-trouver-le-code-nan-cesu/',
#  'https://www.kf-finances.com/pourquoi-utiliser-un-comparateur-de-banques/',
#  'https://www.kf-finances.com/est-il-interessant-dacheter-des-dollars/',
#  'https://www.kf-finances.com/quel-objet-peut-prendre-de-la-valeur/',
#  'https://www.kf-finances.com/comment-ouvrir-un-compte-bancaire-sans-domicile-fixe/',
#  'https://www.kf-finances.com/gerez-votre-epargne-efficacement-sur-www-ca-centreloire-fr/',
#  'https://www.kf-finances.com/prelevement-sepa-asp-quest-ce-que-cest-et-comment-le-gerer/',
#  'https://www.kf-finances.com/les-avantages-insoupconnes-de-cmut-direct-pro-pour-les-petites-entreprises/',
#  'https://www.kf-finances.com/comprendre-le-smic-en-thailande-un-guide-pour-les-expatries-francophones/',
#  'https://www.kf-finances.com/www-ca-cmds-fr-acceder-a-mes-comptes-vade-mecum-exhaustif-pour-neophytes/',
#  'https://www.kf-finances.com/le-prix-du-cuivre-au-kilo-en-2024-tendances-mondiales-et-impacts-economiques/',
#  'https://www.kf-finances.com/comment-optimiser-la-gestion-de-votre-compte-caisse-depargne-en-ligne/',
#  'https://www.kf-finances.com/comprendre-les-frais-generaux-en-comptabilite-astuces-et-conseils-pratiques/',
#  'https://www.kf-finances.com/kwerk-acteur-majeur-du-bureau-flexible-a-paris/',
#  'https://www.kf-finances.com/decouvrez-les-avantages-du-compte-courant-societe-generale/',
#  'https://www.kf-finances.com/pourquoi-est-ce-le-moment-de-renegocier-son-pret-immobilier-pour-la-fin-dannee-2024/',
#  'https://www.kf-finances.com/paris-en-legere-hausse-la-bourse-attend-les-chiffres-de-linflation-americaine/',
#  'https://www.kf-finances.com/optimiser-votre-rentabilite-profitez-des-conseils-dun-expert-comptable-immobilier/',
#  'https://www.kf-finances.com/quel-plan-depargne-choisir-pour-sa-retraite/',
#  'https://www.kf-finances.com/comment-choisir-ses-etf-le-guide/',
#  'https://www.kf-finances.com/quel-montant-pour-debuter-en-bourse/',
#  'https://www.kf-finances.com/astuces-pratiques-pour-optimiser-votre-negociation-de-pret-immobilier/',
#  'https://www.kf-finances.com/les-astuces-pour-maitriser-le-formulaire-2044-et-maximiser-vos-revenus-fonciers/',
#  'https://www.kf-finances.com/comprendre-le-concept-daversion-au-risque/',
#  'https://www.kf-finances.com/lingot-dor-250-g-une-barre-compacte-dans-son-etat-pur/',
#  'https://www.kf-finances.com/comment-choisir-sa-mutuelle-sante-pour-etre-bien-couvert/',
#  'https://www.kf-finances.com/choisir-le-bon-expert-comptable-a-levallois-perret-criteres-et-conseils/',
#  'https://www.kf-finances.com/optimiser-lefficacite-de-votre-commerce-grace-a-des-systemes-pos-modernes/',
#  'https://www.kf-finances.com/comment-alleger-ses-mensualites-en-consolidant-ses-dettes/',
#  'https://www.kf-finances.com/comprendre-limportance-de-se-rapprocher-dun-conseil-en-gestion-du-patrimoine/',
#  'https://www.kf-finances.com/comprendre-lassurance-moto-125cc-fonctionnement-et-conseils/',
#  'https://www.kf-finances.com/assurance-vie-un-outil-de-transmission-patrimoniale-efficace/',
#  'https://www.kf-finances.com/quel-est-lobjectif-premier-de-la-comptabilite/',
#  'https://www.kf-finances.com/que-savoir-sur-les-neo-banques-et-neo-assurances/',
#  'https://www.kf-finances.com/quelle-est-la-meilleure-assurance-vie-en-2020/',
#  'https://www.kf-finances.com/les-acteurs-innovants-du-marche-immobilier-en-ligne/',
#  'https://www.kf-finances.com/dividendes-comment-batir-un-portefeuille-de-placements-pour-votre-retraite/',
#  'https://www.kf-finances.com/assurance-emprunteur-pourquoi-demander-plusieurs-devis/',
#  'https://www.kf-finances.com/le-deficit-foncier-en-lmnp-une-opportunite-pour-les-investisseurs/',
#  'https://www.kf-finances.com/comment-trouver-la-meilleure-scpi/',
#  'https://www.kf-finances.com/10-astuces-pour-ameliorer-votre-situation-financiere/',
#  'https://www.kf-finances.com/comprendre-la-reforme-de-la-retraite-pour-les-carrieres-longues-enjeux-et-perspectives-2/',
#  'https://www.kf-finances.com/convertir-efficacement-vos-dollars-australiens-en-euros-astuces-et-conseils/',
#  'https://www.kf-finances.com/comprendre-le-mecanisme-de-fixation-du-taux-dinteret-du-livret-a/',
#  'https://www.kf-finances.com/comprendre-le-plafond-du-livret-a-astuces-et-conseils-pour-optimiser-vos-economies/',
#  'https://www.kf-finances.com/comprendre-la-reforme-de-la-retraite-pour-les-carrieres-longues-enjeux-et-perspectives/',
#  'https://www.kf-finances.com/comment-choisir-la-meilleure-couverture-sante-en-tant-quindependant/',
#  'https://www.kf-finances.com/quelle-est-la-meilleure-crypto-monnaie/',
#  'https://www.kf-finances.com/les-bases-de-lepargne-en-scpi-pour-optimiser-votre-fiscalite/',
#  'https://www.kf-finances.com/assurance-auto-moto-la-banque-postale-notre-avis-sur-les-contrats-tous-risques/',
#  'https://www.kf-finances.com/les-mentions-obligatoires-sur-une-facture-en-2022/',
#  'https://www.kf-finances.com/analyse-detaillee-le-grand-comparatif-des-assurances-auto-en-2022/',
#  'https://www.kf-finances.com/comment-choisir-un-cabinet-comptable-en-ligne-pour-independant-les-avantages-a-ne-pas-negliger/',
#  'https://www.kf-finances.com/les-differences-entre-caution-bancaire-et-retenue-de-garantie-sur-un-chantier-btp/',
#  'https://www.kf-finances.com/quel-est-le-trading-le-plus-rentable/',
#  'https://www.kf-finances.com/pret-pour-senior-une-maniere-de-financer-ses-projets-personnels-a-tout-age/',
#  'https://www.kf-finances.com/maximisez-votre-investissement-en-comparant-lassurance-de-pret-immobilier/',
#  'https://www.kf-finances.com/comment-le-regroupement-de-credits-peut-liberer-du-cash/',
#  'https://www.kf-finances.com/construire-et-optimiser-son-patrimoine-grace-a-linvestissement-locatif/',
#  'https://www.kf-finances.com/methodes-de-revenus-de-google-comprendre-les-sources-de-profit/',
#  'https://www.kf-finances.com/ou-trouver-le-code-nan-cesu/',
#  'https://www.kf-finances.com/pourquoi-utiliser-un-comparateur-de-banques/',
#  'https://www.kf-finances.com/est-il-interessant-dacheter-des-dollars/',
#  'https://www.kf-finances.com/quel-objet-peut-prendre-de-la-valeur/',
#  'https://www.kf-finances.com/comment-ouvrir-un-compte-bancaire-sans-domicile-fixe/',
#  'https://www.kf-finances.com/gerez-votre-epargne-efficacement-sur-www-ca-centreloire-fr/',
#  'https://www.kf-finances.com/prelevement-sepa-asp-quest-ce-que-cest-et-comment-le-gerer/',
#  'https://www.kf-finances.com/les-avantages-insoupconnes-de-cmut-direct-pro-pour-les-petites-entreprises/',
#  'https://www.kf-finances.com/comprendre-le-smic-en-thailande-un-guide-pour-les-expatries-francophones/',
#  'https://www.kf-finances.com/www-ca-cmds-fr-acceder-a-mes-comptes-vade-mecum-exhaustif-pour-neophytes/',
#  'https://www.kf-finances.com/les-avantages-de-faire-appel-a-un-consultant-en-banque-de-finance/',
#  'https://www.kf-finances.com/travailler-avec-un-expert-comptable-une-strategie-gagnante-pour-les-entreprises/',
#  'https://www.kf-finances.com/devenir-riche-sans-effort-mythes-et-strategies-realistes-expliques/',
#  'https://www.kf-finances.com/recours-subrogatoire-en-assurance-maitrisez-les-demarches-et-impacts/',
#  'https://www.kf-finances.com/bref-apercu-du-rachat-de-credit-pour-fonctionnaire/',
#  'https://www.kf-finances.com/quel-est-le-montant-moyen-dune-retraite-complementaire/',
#  'https://www.kf-finances.com/pourquoi-sas-et-pas-sarl/',
#  'https://www.kf-finances.com/comprendre-et-utiliser-lindicateur-macd-dans-lanalyse-technique/',
#  'https://www.kf-finances.com/gestion-du-flux-financier-en-supply-chain-optimisez-votre-tresorerie/',
#  'https://www.kf-finances.com/assurance-accident-de-la-vie-est-elle-indispensable-pour-vous/',
#  'https://www.kf-finances.com/les-avantages-de-souscrire-une-assurance-vie-au-luxembourg/',
#  'https://www.kf-finances.com/comprendre-le-plafond-de-lassurance-vie-enjeux-et-strategies/',
#  'https://www.kf-finances.com/les-meilleures-assurances-vie-du-moment-comment-choisir/',
#  'https://www.kf-finances.com/pourquoi-devriez-vous-suivre-des-blogs-sur-la-thematique-de-la-cryptomonnaie/',
#  'https://www.kf-finances.com/les-criteres-a-prendre-en-compte-pour-choisir-une-assurance-auto-en-ligne/',
#  'https://www.kf-finances.com/comment-optimiser-la-rentabilite-de-votre-investissement-locatif/',
#  'https://www.kf-finances.com/les-aspects-fiscaux-de-linvestissement-en-scpi-a-connaitre/',
#  'https://www.kf-finances.com/comment-obtenir-un-pret-pour-un-projet-professionnel/',
#  'https://www.kf-finances.com/comment-fonctionne-lapport-cession-le-guide/',
#  'https://www.kf-finances.com/decouvrir-les-outils-numeriques-qui-boostent-lexpansion-des-compagnies-dassurance/',
#  'https://www.kf-finances.com/audit-comptable-efficace-5-etapes-cles-pour-reussir-votre-analyse-financiere/',
#  'https://www.kf-finances.com/tout-savoir-sur-les-cartes-de-paiements-pour-les-mineurs/',
#  'https://www.kf-finances.com/les-meilleures-assurances-vie-du-moment-comment-choisir-4/',
#  'https://www.kf-finances.com/les-meilleures-assurances-vie-du-moment-comment-choisir-3/',
#  'https://www.kf-finances.com/les-meilleures-assurances-vie-du-moment-comment-choisir-2/',
#  'https://www.kf-finances.com/chomage-technique-comprendre-conditions-et-indemnisation-efficacement/',
#  'https://www.kf-finances.com/astuce-pour-denicher-lassurance-auto-la-moins-chere/',
#  'https://www.kf-finances.com/gestion-de-patrimoine-comment-apprendre-a-investir-intelligemment/',
#  'https://www.kf-finances.com/quels-sont-les-differents-types-de-placements-financiers/',
#  'https://www.kf-finances.com/les-meilleures-strategies-dinvestissement-immobilier-pour-les-debutants/',
#  'https://www.kf-finances.com/obtenir-apl-des-le-premier-mois-astuces-efficaces-pour-maximiser-vos-aides/',
#  'https://www.kf-finances.com/les-differentes-significations-du-carre-jaune-decryptage-et-interpretation/',
#  'https://www.kf-finances.com/saisie-bancaire-inattendue-comprendre-et-reagir-efficacement/',
#  'https://www.kf-finances.com/investissement-sur-internet-des-opportunites-a-ne-pas-manquer/',
#  'https://www.kf-finances.com/calcul-du-taux-horaire-avantages-et-inconvenients-des-modeles-populaires/',
#  'https://www.kf-finances.com/pourquoi-contacter-un-courtier-en-credit-immobilier-a-pontarlier/',
#  'https://www.kf-finances.com/comment-bien-choisir-son-bureau-a-paris/',
#  'https://www.kf-finances.com/cest-quoi-la-comptabilisation/',
#  'https://www.kf-finances.com/prevision-du-prix-du-bitcoin-en-2025-les-estimations-de-la-presse/',
#  'https://www.kf-finances.com/creer-un-deuxieme-compte-bancaire-est-ce-possible-en-france/',
#  'https://www.kf-finances.com/credit-a-la-consommation-un-meilleur-allie-pour-faire-un-achat-exceptionnel/',
#  'https://www.kf-finances.com/financer-son-permis-de-conduire-options-et-astuces-pour-economiser/',
#  'https://www.kf-finances.com/assurance-habitation-matmut-resilier-en-toute-serenite-grace-a-nos-conseils/',
#  'https://www.kf-finances.com/roulez-bien-assure-avec-la-societe-generale/',
#  'https://www.kf-finances.com/pourquoi-assurer-son-pret-travaux/',
#  'https://www.kf-finances.com/metaverse-quelles-sont-les-entreprises-qui-y-investissent-le-plus/',
#  'https://www.kf-finances.com/quels-sont-les-logiciels-utilises-par-les-banques/',
#  'https://www.kf-finances.com/le-role-dun-courtier-en-assurance/',
#  'https://www.kf-finances.com/la-mutuelle-pour-chien-les-points-importants-a-connaitre/',
#  'https://www.kf-finances.com/comment-financer-la-construction-de-son-batiment-industriel/',
#  'https://www.kf-finances.com/ou-trouver-le-code-nan-cesu/',
#  'https://www.kf-finances.com/pourquoi-utiliser-un-comparateur-de-banques/',
#  'https://www.kf-finances.com/est-il-interessant-dacheter-des-dollars/',
#  'https://www.kf-finances.com/quel-objet-peut-prendre-de-la-valeur/',
#  'https://www.kf-finances.com/comment-ouvrir-un-compte-bancaire-sans-domicile-fixe/',
#  'https://www.kf-finances.com/gerez-votre-epargne-efficacement-sur-www-ca-centreloire-fr/',
#  'https://www.kf-finances.com/prelevement-sepa-asp-quest-ce-que-cest-et-comment-le-gerer/',
#  'https://www.kf-finances.com/les-avantages-insoupconnes-de-cmut-direct-pro-pour-les-petites-entreprises/',
#  'https://www.kf-finances.com/comprendre-le-smic-en-thailande-un-guide-pour-les-expatries-francophones/',
#  'https://www.kf-finances.com/www-ca-cmds-fr-acceder-a-mes-comptes-vade-mecum-exhaustif-pour-neophytes/',
#  'https://www.kf-finances.com/quentend-on-par-portefeuille-de-dividendes-performant/',
#  'https://www.kf-finances.com/les-cles-pour-reussir-vos-investissements-immobiliers/',
#  'https://www.kf-finances.com/top-5-des-meilleurs-modeles-de-kia-en-loa/',
#  'https://www.kf-finances.com/refection-de-toiture-quelles-sont-les-aides-de-letat/',
#  'https://www.kf-finances.com/quelle-crypto-monnaie-miner-en-2021/',
#  'https://www.kf-finances.com/quel-est-le-role-dun-conseiller-financier/',
#  'https://www.kf-finances.com/quest-ce-que-la-mauvaise-gestion/',
#  'https://www.kf-finances.com/comment-sont-calcules-les-prelevements-sociaux/',
#  'https://www.kf-finances.com/est-ce-que-lauto-entrepreneur-cotise-pour-la-retraite/',
#  'https://www.kf-finances.com/meilleure-plateforme-en-crypto-guide-pour-bien-commencer-dans-la-crypto-en-5-etapes-faciles/',
#  'https://www.kf-finances.com/choix-financiers-dentreprise-toutes-les-informations-sur-les-alternatives-existantes/',
#  'https://www.kf-finances.com/comment-savoir-que-votre-maison-est-protegee/',
#  'https://www.kf-finances.com/la-bonne-methode-pour-joindre-un-service-clients/',
#  'https://www.kf-finances.com/comprendre-la-vente-et-le-pret-viager/',
#  'https://www.kf-finances.com/suivre-les-blogs-dedies-pour-comprendre-le-role-dun-courtier-en-ligne/',
#  'https://www.kf-finances.com/ce-quil-faut-retenir-de-lassurance-habitation/',
#  'https://www.kf-finances.com/gestion-de-tresorerie-dune-entreprise-quelques-points-a-retenir/',
#  'https://www.kf-finances.com/quel-est-linteret-de-rembourser-un-pret-par-anticipation/',
#  'https://www.kf-finances.com/investissement-immobilier-dentreprise-les-pieges-a-eviter-absolument/',
#  'https://www.kf-finances.com/transformation-finance-la-digitalisation-a-lordre-du-jour/',
#  'https://www.kf-finances.com/tout-ce-quil-faut-absolument-savoir-sur-le-pea/',
#  'https://www.kf-finances.com/investir-dans-les-cryptomonnaies-avantages-et-risques-des-diverses-options/',
#  'https://www.kf-finances.com/la-cle-du-succes-dune-entreprise-limportance-de-la-planification-financiere/',
#  'https://www.kf-finances.com/etablissement-des-fiches-de-paies-pourquoi-confier-la-tache-a-un-expert-comptable/',
#  'https://www.kf-finances.com/les-secrets-de-lanalyse-technique-pour-anticiper-les-mouvements-des-cryptomonnaies/',
#  'https://www.kf-finances.com/les-meilleures-assurances-bancaires-pour-securiser-vos-biens-et-vos-finances/',
#  'https://www.kf-finances.com/les-multiples-options-de-regimes-de-retraite-existants-quel-choix-pour-votre-avenir/',
#  'https://www.kf-finances.com/que-retenir-du-pea-avant-dy-souscrire/',
#  'https://www.kf-finances.com/les-cles-dune-reussite-dans-votre-projet-dachat-immobilier/',
#  'https://www.kf-finances.com/les-meilleures-options-de-financement-pour-les-etudes-superieures/',
#  'https://www.kf-finances.com/les-pieges-a-eviter-lors-du-trading-de-crypto-monnaies/',
#  'https://www.kf-finances.com/quels-sont-les-avantages-de-la-blockchain-litecoin/',
#  'https://www.kf-finances.com/les-cles-pour-decrypter-les-etats-financiers-avant-dinvestir-en-bourse/',
#  'https://www.kf-finances.com/pourquoi-je-nai-pas-recu-la-prime-de-noel/',
#  'https://www.kf-finances.com/optimisez-votre-preparation-a-la-retraite-financiere-avec-laide-de-votre-banque/',
#  'https://www.kf-finances.com/optimisez-la-gestion-de-votre-entreprise-grace-a-un-logiciel-fiable-et-simple/',
#  'https://www.kf-finances.com/selectionner-la-meilleure-assurance-retraite-criteres-essentiels-a-considerer/',
#  'https://www.kf-finances.com/les-pieges-a-eviter-lors-de-lacquisition-dun-bien-immobilier/',
#  'https://www.kf-finances.com/financement-par-emprunt-les-aspects-positifs-et-negatifs-a-connaitre/',
#  'https://www.kf-finances.com/externalisation-des-services-financiers-avantages-et-inconvenients-a-connaitre/',
#  'https://www.kf-finances.com/decouvrez-les-dernieres-avancees-technologiques-des-cryptomonnaies/',
#  'https://www.kf-finances.com/les-conditions-du-pret-a-taux-zero-renforce/',
#  'https://www.kf-finances.com/les-meilleurs-strategies-de-trading-pour-maximiser-vos-gains/',
#  'https://www.kf-finances.com/financement-des-tpe-pme-explorez-les-diverses-solutions-disponibles/',
#  'https://www.kf-finances.com/comment-choisir-le-sol-ideal-pour-votre-espace-exterieur/',
#  'https://www.kf-finances.com/les-atouts-et-limites-des-investissements-dans-les-matieres-premieres-tout-ce-que-vous-devez-savoir/',
#  'https://www.kf-finances.com/choisir-une-banque-ecologique-cest-possible/',
#  'https://www.kf-finances.com/estimer-la-valeur-dun-bien-immobilier-avant-dacheter-les-cles-pour-une-evaluation-precise/',
#  'https://www.kf-finances.com/les-pieges-a-eviter-lors-de-linvestissement-en-crypto-monnaies/',
#  'https://www.kf-finances.com/changer-dassurance-emprunteur-comment-proceder/',
#  'https://www.kf-finances.com/ou-trouver-le-code-nan-cesu/',
#  'https://www.kf-finances.com/pourquoi-utiliser-un-comparateur-de-banques/',
#  'https://www.kf-finances.com/est-il-interessant-dacheter-des-dollars/',
#  'https://www.kf-finances.com/quel-objet-peut-prendre-de-la-valeur/',
#  'https://www.kf-finances.com/comment-ouvrir-un-compte-bancaire-sans-domicile-fixe/',
#  'https://www.kf-finances.com/gerez-votre-epargne-efficacement-sur-www-ca-centreloire-fr/',
#  'https://www.kf-finances.com/prelevement-sepa-asp-quest-ce-que-cest-et-comment-le-gerer/',
#  'https://www.kf-finances.com/les-avantages-insoupconnes-de-cmut-direct-pro-pour-les-petites-entreprises/',
#  'https://www.kf-finances.com/comprendre-le-smic-en-thailande-un-guide-pour-les-expatries-francophones/',
#  'https://www.kf-finances.com/www-ca-cmds-fr-acceder-a-mes-comptes-vade-mecum-exhaustif-pour-neophytes/',
#  'https://www.kf-finances.com/les-avantages-et-les-inconvenients-du-trading-de-crypto-monnaies-ce-que-vous-devez-savoir/',
#  'https://www.kf-finances.com/resilier-votre-assurance-auto-groupama-en-quelques-clics-mode-demploi-5/',
#  'https://www.kf-finances.com/forums-dassurance-auto-comment-participer-efficacement-a-la-communaute-2/',
#  'https://www.kf-finances.com/resilier-votre-assurance-auto-groupama-en-quelques-clics-mode-demploi-4/',
#  'https://www.kf-finances.com/resilier-votre-assurance-auto-groupama-en-quelques-clics-mode-demploi-3/',
#  'https://www.kf-finances.com/resilier-votre-assurance-auto-groupama-en-quelques-clics-mode-demploi-2/',
#  'https://www.kf-finances.com/resilier-votre-assurance-auto-groupama-en-quelques-clics-mode-demploi/',
#  'https://www.kf-finances.com/deux-raisons-de-realiser-une-simulation-de-votre-pension-de-retraite/',
#  'https://www.kf-finances.com/assurance-auto-professionnelle-les-astuces-pour-reduire-votre-prime-dassurance/',
#  'https://www.kf-finances.com/decouvrez-les-particularites-des-regimes-de-retraite-en-france/',
#  'https://www.kf-finances.com/lexpert-comptable-en-ligne-des-solutions-pratiques-pour-les-entreprises/',
#  'https://www.kf-finances.com/les-essentiels-pour-la-gestion-comptable-de-votre-entreprise/',
#  'https://www.kf-finances.com/comment-comprendre-la-bourse/',
#  'https://www.kf-finances.com/epargner-grace-a-linvestissement-en-metaux-precieux-la-solution-primagold-com/',
#  'https://www.kf-finances.com/maitriser-ses-finances-personnelles-les-meilleures-strategies-a-adopter/',
#  'https://www.kf-finances.com/maitrisez-les-fondamentaux-de-metatrader-4-pour-mieux-investir-sur-les-marches-financiers/',
#  'https://www.kf-finances.com/ico-decryptage-des-avantages-et-inconvenients-dune-revolution-numerique/',
#  'https://www.kf-finances.com/les-secrets-pour-vendre-rapidement-votre-bien-immobilier-a-rosas/',
#  'https://www.kf-finances.com/quelles-sont-les-differentes-etapes-pour-rediger-une-annonce-immobiliere-a-rosas/',
#  'https://www.kf-finances.com/investir-en-bourse-strategies-securisees-et-rentables-a-adopter/',
#  'https://www.kf-finances.com/strategies-efficaces-pour-ameliorer-la-gestion-des-finances-de-votre-entreprise/',
#  'https://www.kf-finances.com/les-meilleurs-choix-pour-les-investisseurs-debutants-sur-le-marche-boursier/',
#  'https://www.kf-finances.com/comment-un-avocat-en-fiscalite-internationale-peut-il-optimiser-vos-affaires-transfrontalieres/',
#  'https://www.kf-finances.com/decouvrez-les-points-forts-et-les-points-faibles-des-transactions-en-cryptomonnaie/',
#  'https://www.kf-finances.com/interets-composes-les-facteurs-dinfluence-et-guide-de-calcul/',
#  'https://www.kf-finances.com/limportance-de-la-diversification-en-bourse-pour-optimiser-vos-investissements/',
#  'https://www.kf-finances.com/comment-investir-en-bourse-en-2022/',
#  'https://www.kf-finances.com/impact-des-taux-dinteret-sur-les-dynamiques-du-marche-immobilier/',
#  'https://www.kf-finances.com/comment-choisir-un-terminal-de-paiement-pour-sa-boutique/',
#  'https://www.kf-finances.com/les-etablissements-de-paiement-des-services-innovants/',
#  'https://www.kf-finances.com/comment-fonctionne-le-credit-express-pour-repondre-aux-besoins-financiers-urgents/',
#  'https://www.kf-finances.com/la-force-relative-en-bourse-et-analyse-technique-un-indicateur-cle-pour-les-investisseurs/',
#  'https://www.kf-finances.com/les-terminaux-de-paiement-un-apercu-complet-sur-leur-utilisation-et-leurs-avantages/',
#  'https://www.kf-finances.com/les-cas-dutilisation-de-la-defi-explorez-les-possibilites-de-cette-revolution-financiere/',
#  'https://www.kf-finances.com/pourquoi-passer-pour-un-courtier-pour-un-pret-professionnel/',
#  'https://www.kf-finances.com/quelles-sont-les-demarches-pour-un-statut-de-quasi-resident/',
#  'https://www.kf-finances.com/fortuneo-avis-que-vaut-cette-banque-en-ligne/',
#  'https://www.kf-finances.com/puis-je-cumuler-rsa-et-salaire/',
#  'https://www.kf-finances.com/comment-compte-un-mi-temps-therapeutique-pour-la-retraite/',
#  'https://www.kf-finances.com/les-meilleures-strategies-dinvestissement-pour-preparer-sa-retraite/',
#  'https://www.kf-finances.com/mutuelle-et-assurance-sante-quelle-difference/',
#  'https://www.kf-finances.com/cv-pour-le-poste-dun-manager/',
#  'https://www.kf-finances.com/souscrire-a-une-assurance-vie-pour-quelles-raisons/',
#  'https://www.kf-finances.com/gerer-ses-emotions-et-rester-calme-pendant-les-periodes-de-volatilite-en-bourse-les-cles-du-succes/',
#  'https://www.kf-finances.com/le-courtage-en-ligne-une-nouvelle-ere-pour-les-investisseurs/',
#  'https://www.kf-finances.com/les-pieges-a-eviter-lors-du-financement-de-votre-projet/',
#  'https://www.kf-finances.com/les-cryptomonnaies-un-bouleversement-economique-mondial/',
#  'https://www.kf-finances.com/investir-en-bourse-guide-complet-pour-les-debutants/',
#  'https://www.kf-finances.com/pourquoi-opter-pour-un-logiciel-de-recouvrement/',
#  'https://www.kf-finances.com/faut-il-utiliser-le-credit-pour-investir-dans-des-parts-de-scpi/',
#  'https://www.kf-finances.com/ou-trouver-le-code-nan-cesu/',
#  'https://www.kf-finances.com/pourquoi-utiliser-un-comparateur-de-banques/',
#  'https://www.kf-finances.com/est-il-interessant-dacheter-des-dollars/',
#  'https://www.kf-finances.com/quel-objet-peut-prendre-de-la-valeur/',
#  'https://www.kf-finances.com/comment-ouvrir-un-compte-bancaire-sans-domicile-fixe/',
#  'https://www.kf-finances.com/gerez-votre-epargne-efficacement-sur-www-ca-centreloire-fr/',
#  'https://www.kf-finances.com/prelevement-sepa-asp-quest-ce-que-cest-et-comment-le-gerer/',
#  'https://www.kf-finances.com/les-avantages-insoupconnes-de-cmut-direct-pro-pour-les-petites-entreprises/',
#  'https://www.kf-finances.com/comprendre-le-smic-en-thailande-un-guide-pour-les-expatries-francophones/',
#  'https://www.kf-finances.com/www-ca-cmds-fr-acceder-a-mes-comptes-vade-mecum-exhaustif-pour-neophytes/',
#  'https://www.kf-finances.com/comment-obtenir-une-notification-de-pension-de-retraite/',
#  'https://www.kf-finances.com/assurance-moto-comment-negocier-son-contrat-pour-obtenir-le-meilleur-tarif/',
#  'https://www.kf-finances.com/quel-est-le-meilleur-investissement-a-long-terme/',
#  'https://www.kf-finances.com/les-tendances-actuelles-dans-les-formations-en-logiciel-comptable/',
#  'https://www.kf-finances.com/les-avantages-dinvestir-son-argent-plutot-que-de-le-garder-sur-son-compte-en-banque/',
#  'https://www.kf-finances.com/les-avantages-et-les-inconvenients-du-credit-renouvelable-accessio-cofidis/',
#  'https://www.kf-finances.com/comment-proteger-votre-patrimoine-avec-lassurance/',
#  'https://www.kf-finances.com/la-reprogrammation-ethanol-quels-sont-les-reels-avantages/',
#  'https://www.kf-finances.com/les-imperatifs-juridiques-a-connaitre-pour-les-proprietaires-louant-leur-bien-immobilier/',
#  'https://www.kf-finances.com/payer-en-bitcoins-sans-compte-la-solution-simplifiee/',
#  'https://www.kf-finances.com/pourquoi-mt4-ne-fonctionne-pas-les-reponses/',
#  'https://www.kf-finances.com/garantir-la-securite-de-votre-etudiant-pourquoi-vous-devriez-choisir-groupama-assurance-etudiant/',
#  'https://www.kf-finances.com/exploiter-le-mining-des-crypto-monnaies-avec-honeyminer-une-introduction-pour-les-debutants/',
#  'https://www.kf-finances.com/comprendre-le-cout-des-assurances-jeune-conducteur-en-2018-et-obtenir-le-meilleur-tarif/',
#  'https://www.kf-finances.com/quel-est-limpact-reel-de-la-crise-sanitaire-sur-le-marche-des-bureaux/',
#  'https://www.kf-finances.com/le-pret-sci-que-faut-il-savoir-a-propos/',
#  'https://www.kf-finances.com/innovation-en-matiere-de-remuneration-les-tendances-actuelles-pour-recompenser-les-dirigeants-dentreprise/',
#  'https://www.kf-finances.com/decouvrez-la-banque-la-plus-riche-de-france-et-ce-quelle-a-a-offrir/',
#  'https://www.kf-finances.com/5-arnaques-du-moment-sur-internet/',
#  'https://www.kf-finances.com/montre-en-bois-les-inconvenients/',
#  'https://www.kf-finances.com/regroupement-de-credits-quels-avantages/',
#  'https://www.kf-finances.com/quelle-est-la-banque-numero-1-en-france/',
#  'https://www.kf-finances.com/pret-projet-pourquoi-un-tel-engouement/',
#  'https://www.kf-finances.com/optimisation-fiscale-lessentiel-a-savoir/',
#  'https://www.kf-finances.com/comment-gerer-son-credit-autorise/',
#  'https://www.kf-finances.com/comment-miner-du-bitcoin-cash/',
#  'https://www.kf-finances.com/regroupement-de-credit-une-solution-pour-eviter-le-surendettement/',
#  'https://www.kf-finances.com/comment-consulter-mon-compte-cic/',
#  'https://www.kf-finances.com/comprendre-le-salaire-brut-et-le-salaire-net-calculer-son-salaire-mensuel-en-net-cadre-et-non-cadre/',
#  'https://www.kf-finances.com/les-avantages-de-loptimisation-fiscale-pour-votre-sasu-tout-ce-quil-faut-savoir/',
#  'https://www.kf-finances.com/les-recours-possibles-face-a-une-plainte-classee-sans-suite/',
#  'https://www.kf-finances.com/comment-reussir-votre-investissement-immobilier/',
#  'https://www.kf-finances.com/comment-investir-dans-la-crypto-monnaie-les-meilleures-strategies-pour-les-debutants/',
#  'https://www.kf-finances.com/les-banques-francaises-a-risque-etat-des-lieux/',
#  'https://www.kf-finances.com/proteger-vos-bitcoins-des-cyberattaques-les-meilleures-pratiques-pour-securiser-vos-cryptomonnaies/',
#  'https://www.kf-finances.com/comment-savoir-si-plainte-classee-sans-suite/',
#  'https://www.kf-finances.com/comment-investir-dans-le-marche-boursier-pour-un-meilleur-rendement-financier/',
#  'https://www.kf-finances.com/comprendre-le-marche-des-crypto-monnaies-une-introduction-pour-les-debutants/',
#  'https://www.kf-finances.com/comment-assurer-votre-avenir-financier-grace-a-lassurance/',
#  'https://www.kf-finances.com/comment-investir-dans-limmobilier-pour-ameliorer-votre-portefeuille-financier/',
#  'https://www.kf-finances.com/5-conseils-pour-economiser-de-largent/',
#  'https://www.kf-finances.com/comment-bien-choisir-une-offre-de-rachat-de-credit/',
#  'https://www.kf-finances.com/10-conseils-pour-demarrer-un-trading-a-faible-capital/',
#  'https://www.kf-finances.com/pourquoi-prendre-un-courtier-en-assurance-digital-dans-la-ville-de-charleroi-en-belgique/',
#  'https://www.kf-finances.com/les-5-meilleures-pratiques-en-matiere-de-gestion-des-finances/',
#  'https://www.kf-finances.com/comprendre-les-tenants-et-aboutissants-dune-promesse-synallagmatique/',
#  'https://www.kf-finances.com/comment-gerer-la-tresorerie-dune-entreprise/',
#  'https://www.kf-finances.com/la-nouvelle-ere-des-fusions-et-acquisitions/',
#  'https://www.kf-finances.com/les-solutions-de-financement-alternatives-pour-les-petites-entreprises/',
#  'https://www.kf-finances.com/quelle-est-lassurance-habitation-la-moins-chere-sans-franchise/',
#  'https://www.kf-finances.com/ou-trouver-le-code-nan-cesu/',
#  'https://www.kf-finances.com/pourquoi-utiliser-un-comparateur-de-banques/',
#  'https://www.kf-finances.com/est-il-interessant-dacheter-des-dollars/',
#  'https://www.kf-finances.com/quel-objet-peut-prendre-de-la-valeur/',
#  'https://www.kf-finances.com/comment-ouvrir-un-compte-bancaire-sans-domicile-fixe/',
#  'https://www.kf-finances.com/gerez-votre-epargne-efficacement-sur-www-ca-centreloire-fr/',
#  'https://www.kf-finances.com/prelevement-sepa-asp-quest-ce-que-cest-et-comment-le-gerer/',
#  'https://www.kf-finances.com/les-avantages-insoupconnes-de-cmut-direct-pro-pour-les-petites-entreprises/',
#  'https://www.kf-finances.com/comprendre-le-smic-en-thailande-un-guide-pour-les-expatries-francophones/',
#  'https://www.kf-finances.com/www-ca-cmds-fr-acceder-a-mes-comptes-vade-mecum-exhaustif-pour-neophytes/',
#  'https://www.kf-finances.com/comment-teledeclarer-sci/',
#  'https://www.kf-finances.com/comprendre-le-concept-de-credit/',
#  'https://www.kf-finances.com/comment-choisir-la-meilleure-banque-pour-vos-besoins-financiers/',
#  'https://www.kf-finances.com/les-meilleures-pratiques-pour-investir-dans-les-crypto-monnaies/',
#  'https://www.kf-finances.com/quelle-banque-choisir-pour-une-assurance-vie/',
#  'https://www.kf-finances.com/comment-ouvrir-un-livret-a-dans-une-autre-banque/',
#  'https://www.kf-finances.com/quels-sont-les-avantages-et-les-risques-de-linvestissement-en-bourse/',
#  'https://www.kf-finances.com/gerer-son-budget-comment-utiliser-le-credit-a-la-consommation-de-maniere-responsable/',
#  'https://www.kf-finances.com/comment-reussir-une-levee-de-fonds-pour-une-start-up/',
#  'https://www.kf-finances.com/comment-trader-sur-metatrader-4-les-bases/',
#  'https://www.kf-finances.com/pourquoi-les-seniors-devraient-investir-dans-des-placements-financiers/',
#  'https://www.kf-finances.com/assurance-credit-pourquoi-choisir-loption-50/',
#  'https://www.kf-finances.com/comment-evaluer-le-rendement-dun-investissement-en-bourse/',
#  'https://www.kf-finances.com/les-meilleurs-conseils-pour-trouver-un-bon-courtier-en-bourse/',
#  'https://www.kf-finances.com/comment-ameliorer-la-gestion-des-finances-de-votre-entreprise/',
#  'https://www.kf-finances.com/quand-investir-dans-une-crypto-monnaie/',
#  'https://www.kf-finances.com/la-valeur-dune-monnaie-virtuelle-comment-est-elle-determinee/',
#  'https://www.kf-finances.com/les-outils-financiers-pour-une-retraite-sereine/',
#  'https://www.kf-finances.com/5-raisons-dinvestir-en-floride-des-maintenant/',
#  'https://www.kf-finances.com/comment-maximiser-votre-retraite-en-investissant-intelligemment/',
#  'https://www.kf-finances.com/comprendre-les-deductions-fiscales-liees-aux-assurances/',
#  'https://www.kf-finances.com/pourquoi-vous-aider-dun-logiciel-de-facturation-pour-votre-entreprise/',
#  'https://www.kf-finances.com/quel-site-utiliser-pour-trouver-les-meilleurs-taux-de-credit/',
#  'https://www.kf-finances.com/ce-quil-faut-savoir-sur-la-selarl/',
#  'https://www.kf-finances.com/quest-ce-quun-compte-titres-ordinaire/',
#  'https://www.kf-finances.com/gaz-les-meilleurs-tarifs-en-2020-pour-economiser-sur-votre-facture/',
#  'https://www.kf-finances.com/le-processus-dactivation-de-la-carte-bancaire-la-poste/',
#  'https://www.kf-finances.com/la-decouverte-de-lor-en-ouganda-influence-t-elle-la-crypto/',
#  'https://www.kf-finances.com/assurance-credit-100-ou-50-quelle-difference/',
#  'https://www.kf-finances.com/le-recouvrement-comment-ca-marche/',
#  'https://www.kf-finances.com/pourquoi-utiliser-un-comparateur-de-banques/',
#  'https://www.kf-finances.com/pourquoi-avoir-choisi-leconomie/',
#  'https://www.kf-finances.com/le-cours-de-laction-de-tesla-motors-en-hausse-apres-lannonce-dun-nouveau-partenariat/',
#  'https://www.kf-finances.com/les-seniors-et-les-placements-financiers-ce-quil-faut-savoir/',
#  'https://www.kf-finances.com/assurance-de-pret-et-hypotheque-quelles-differences/',
#  'https://www.kf-finances.com/les-astuces-pour-reduire-ses-impots-sur-les-investissements/',
#  'https://www.kf-finances.com/apprendre-a-estimer-la-performance-dun-investissement-avec-la-cagr/',
#  'https://www.kf-finances.com/quand-utiliser-les-prelevements-sociaux-sur-pea/',
#  'https://www.kf-finances.com/la-fiscalite-des-sorties-en-capital-a-letranger/',
#  'https://www.kf-finances.com/ce-quil-faut-savoir-sur-lassurance-habitation-en-colocation/',
#  'https://www.kf-finances.com/pourquoi-choisir-une-assurance-au-kilometre-plutot-quune-assurance-classique/',
#  'https://www.kf-finances.com/comment-obtenir-le-pret-bancaire-le-plus-rentable/',
#  'https://www.kf-finances.com/les-points-forts-en-faveur-des-banques-en-ligne/',
#  'https://www.kf-finances.com/pourquoi-passer-par-un-courtier-en-assurance/',
#  'https://www.kf-finances.com/quel-type-de-contrat-pour-un-retraite/',
#  'https://www.kf-finances.com/les-cles-pour-reussir-en-tant-que-gerant-dune-sarl/',
#  'https://www.kf-finances.com/comment-investir-avec-precaution-et-obtenir-une-rentabilite-maximale-en-matiere-de-finance/',
#  'https://www.kf-finances.com/quest-ce-quun-transfert-immediat/',
#  'https://www.kf-finances.com/comment-configurer-metatrader-pour-le-trading/',
#  'https://www.kf-finances.com/quels-sont-les-meilleurs-moyens-dobtenir-des-actualites-crypto/',
#  'https://www.kf-finances.com/ou-trouver-le-code-nan-cesu/',
#  'https://www.kf-finances.com/pourquoi-utiliser-un-comparateur-de-banques/',
#  'https://www.kf-finances.com/est-il-interessant-dacheter-des-dollars/',
#  'https://www.kf-finances.com/quel-objet-peut-prendre-de-la-valeur/',
#  'https://www.kf-finances.com/comment-ouvrir-un-compte-bancaire-sans-domicile-fixe/',
#  'https://www.kf-finances.com/gerez-votre-epargne-efficacement-sur-www-ca-centreloire-fr/',
#  'https://www.kf-finances.com/prelevement-sepa-asp-quest-ce-que-cest-et-comment-le-gerer/',
#  'https://www.kf-finances.com/les-avantages-insoupconnes-de-cmut-direct-pro-pour-les-petites-entreprises/',
#  'https://www.kf-finances.com/comprendre-le-smic-en-thailande-un-guide-pour-les-expatries-francophones/',
#  'https://www.kf-finances.com/www-ca-cmds-fr-acceder-a-mes-comptes-vade-mecum-exhaustif-pour-neophytes/',
#  'https://www.kf-finances.com/comment-faire-de-la-communication-sans-budget/',
#  'https://www.kf-finances.com/quelles-administrations-prevenir-en-cas-de-pacs/',
#  'https://www.kf-finances.com/utiliser-le-play-to-earn-p2e-pour-ameliorer-votre-jeu/',
#  'https://www.kf-finances.com/quel-vin-acheter-pour-investir-les-vins-les-plus-rentables-en-2020/',
#  'https://www.kf-finances.com/metatrader-5-mac-conseils-pour-les-debutants/',
#  'https://www.kf-finances.com/la-retraite-spirituelle-un-moment-privilegie-pour-mediter-et-se-ressourcer/',
#  'https://www.kf-finances.com/quels-sont-les-avantages-du-pret-viager-hypothecaire/',
#  'https://www.kf-finances.com/aide-au-chauffage-pour-les-retraites-2022-comment-beneficier-des-avantages-disponibles/',
#  'https://www.kf-finances.com/comment-le-compte-joint-en-cas-de-deces-peut-il-aider-les-beneficiaires/',
#  'https://www.kf-finances.com/comment-choisir-la-bonne-banque-pour-votre-epargne/',
#  'https://www.kf-finances.com/les-raisons-dappeler-sa-banque-par-telephone/',
#  'https://www.kf-finances.com/les-meilleures-astuces-pour-contacter-facilement-un-service-client/',
#  'https://www.kf-finances.com/ou-cacher-un-traceur-gps/',
#  'https://www.kf-finances.com/comment-devenir-resident-fiscal-a-dubai/',
#  'https://www.kf-finances.com/comment-deleguer-le-recouvrement-de-ses-creances/',
#  'https://www.kf-finances.com/puis-je-faire-un-cheque-de-4000-euros/',
#  'https://www.kf-finances.com/qui-est-le-plus-fort-le-dollar-ou-leuro/',
#  'https://www.kf-finances.com/jusqua-quel-age-doit-on-prendre-une-assurance-scolaire/',
#  'https://www.kf-finances.com/quelle-banque-choisir-pour-un-jeune-de-17-ans/',
#  'https://www.kf-finances.com/qui-a-cree-le-bitcoin-prime/',
#  'https://www.kf-finances.com/shiba-inu-pourquoi-cette-crypto-monnaie-vaut-elle-la-peine-detre-achetee/',
#  'https://www.kf-finances.com/logitelnet-comment-acceder-a-mon-compte-societe-generale/',
#  'https://www.kf-finances.com/ou-trouver-numero-de-police-dassurance-scolaire-mae/',
#  'https://www.kf-finances.com/le-vechain-pourrait-bien-etre-la-prochaine-grande-crypto-monnaie/',
#  'https://www.kf-finances.com/qui-peut-constituer-une-sarl-de-famille/',
#  'https://www.kf-finances.com/orthodontie-adulte-garder-le-sourire-grace-a-votre-mutuelle/',
#  'https://www.kf-finances.com/trading-ne-soyez-pas-trop-gourmand-et-contentez-vous-de-petits-gains-reguliers/',
#  'https://www.kf-finances.com/opcvm-quelle-fiscalite/',
#  'https://www.kf-finances.com/comment-utiliser-les-trackers/',
#  'https://www.kf-finances.com/quel-etf-sp500-choisir/',
#  'https://www.kf-finances.com/comment-trouver-une-mutuelle-sante-pas-chere/',
#  'https://www.kf-finances.com/pourquoi-prendre-un-conseiller-en-gestion-de-patrimoine/',
#  'https://www.kf-finances.com/faut-il-toujours-investir-dans-limmobilier/',
#  'https://www.kf-finances.com/comment-monter-un-projet-de-creation-dentreprise/',
#  'https://www.kf-finances.com/un-courtier-recherche-le-meilleur-taux-pour-votre-credit/',
#  'https://www.kf-finances.com/comment-arreter-une-assurance-vie/',
#  'https://www.kf-finances.com/conseils-pour-bien-trader-en-bourse/',
#  'https://www.kf-finances.com/comment-acheter-du-bitcoin-en-france/',
#  'https://www.kf-finances.com/pourquoi-faire-assurer-son-entreprise/',
#  'https://www.kf-finances.com/3-bonnes-raisons-de-miser-sur-une-plateforme-de-trading-automatique/',
#  'https://www.kf-finances.com/quelle-est-la-difference-entre-crowdlending-et-crowdfunding/',
#  'https://www.kf-finances.com/4-conseils-pour-preparer-vos-finances-a-la-retraite/',
#  'https://www.kf-finances.com/quels-sont-les-frais-associes-a-un-achat-en-scpi/',
#  'https://www.kf-finances.com/investissement-dans-lor-a-quoi-faut-il-faire-attention/',
#  'https://www.kf-finances.com/que-dois-je-savoir-avant-dinvestir/',
#  'https://www.kf-finances.com/renovation-de-maison-pourquoi-contacter-une-entreprise-specialisee/',
#  'https://www.kf-finances.com/pourquoi-visiter-un-blog-sur-les-crypto-monnaies/',
#  'https://www.kf-finances.com/comment-payer-sur-le-darknet-bitcoin/',
#  'https://www.kf-finances.com/quels-sont-les-investissements-que-vous-pouvez-faire-en-2022/',
#  'https://www.kf-finances.com/pourquoi-suivre-des-cours-pour-apprendre-a-gerer-ses-finances-personnelles/',
#  'https://www.kf-finances.com/ou-trouver-le-code-nan-cesu/',
#  'https://www.kf-finances.com/pourquoi-utiliser-un-comparateur-de-banques/',
#  'https://www.kf-finances.com/est-il-interessant-dacheter-des-dollars/',
#  'https://www.kf-finances.com/quel-objet-peut-prendre-de-la-valeur/',
#  'https://www.kf-finances.com/comment-ouvrir-un-compte-bancaire-sans-domicile-fixe/',
#  'https://www.kf-finances.com/gerez-votre-epargne-efficacement-sur-www-ca-centreloire-fr/',
#  'https://www.kf-finances.com/prelevement-sepa-asp-quest-ce-que-cest-et-comment-le-gerer/',
#  'https://www.kf-finances.com/les-avantages-insoupconnes-de-cmut-direct-pro-pour-les-petites-entreprises/',
#  'https://www.kf-finances.com/comprendre-le-smic-en-thailande-un-guide-pour-les-expatries-francophones/',
#  'https://www.kf-finances.com/www-ca-cmds-fr-acceder-a-mes-comptes-vade-mecum-exhaustif-pour-neophytes/',
#  'https://www.kf-finances.com/pourquoi-recourir-a-une-entreprise-dinvestissement-locatif-rentable-cle-en-main/',
#  'https://www.kf-finances.com/quels-sont-les-meilleurs-investissements-a-faire-en-2022/',
#  'https://www.kf-finances.com/quels-avantages-de-recourir-a-un-courtier-specialiste-des-credits-immobiliers/',
#  'https://www.kf-finances.com/ou-acheter-des-cryptomonnaies-en-2022/',
#  'https://www.kf-finances.com/qui-peut-utiliser-la-carte-de-gestion-financiere-pour-ado/',
#  'https://www.kf-finances.com/5-differences-entre-un-preteur-prive-et-un-preteur-traditionnel/',
#  'https://www.kf-finances.com/comment-trouver-un-directeur-financier-pour-votre-startup/',
#  'https://www.kf-finances.com/trading-et-immobilier-pourquoi-sentourer-dun-courtier/',
#  'https://www.kf-finances.com/entreprises-du-batiment-pourquoi-faire-appel-a-un-courtier-en-assurance/',
#  'https://www.kf-finances.com/mieux-comprendre-le-rachat-de-credit-pour-mieux-en-profiter/',
#  'https://www.kf-finances.com/les-marches-financiers-des-opportunites-de-gagner-de-largent/',
#  'https://www.kf-finances.com/quel-est-le-montant-dune-retraite-moyenne/',
#  'https://www.kf-finances.com/qui-paye-le-chomage-des-fonctionnaires/',
#  'https://www.kf-finances.com/quelle-methode-permet-de-suivre-levolution-dun-projet/',
#  'https://www.kf-finances.com/quel-malus-suite-a-un-accrochage/',
#  'https://www.kf-finances.com/quel-est-le-montant-minimum-dun-pret-a-la-consommation/',
#  'https://www.kf-finances.com/pourquoi-faire-un-contrat-de-prevoyance/',
#  'https://www.kf-finances.com/comment-se-porte-les-marches-financiers/',
#  'https://www.kf-finances.com/comment-savoir-ou-investir-en-bourse/',
#  'https://www.kf-finances.com/comment-investir-sur-les-indices-boursiers/',
#  'https://www.kf-finances.com/comment-fonctionne-le-minage/',
#  'https://www.kf-finances.com/comment-calculer-revalorisation-retraite/',
#  'https://www.kf-finances.com/comment-devenir-mineur-de-crypto-monnaie/',
#  'https://www.kf-finances.com/comment-calculer-la-marge-dun-chantier/',
#  'https://www.kf-finances.com/comment-ca-marche-disnat/',
#  'https://www.kf-finances.com/comment-acheter-des-actions-soi-meme/',
#  'https://www.kf-finances.com/comment-contacter-mon-urssaf-par-mail/',
#  'https://www.kf-finances.com/ou-trouver-le-code-nan-cesu/',
#  'https://www.kf-finances.com/pourquoi-utiliser-un-comparateur-de-banques/',
#  'https://www.kf-finances.com/est-il-interessant-dacheter-des-dollars/',
#  'https://www.kf-finances.com/quel-objet-peut-prendre-de-la-valeur/',
#  'https://www.kf-finances.com/comment-ouvrir-un-compte-bancaire-sans-domicile-fixe/',
#  'https://www.kf-finances.com/gerez-votre-epargne-efficacement-sur-www-ca-centreloire-fr/',
#  'https://www.kf-finances.com/prelevement-sepa-asp-quest-ce-que-cest-et-comment-le-gerer/',
#  'https://www.kf-finances.com/les-avantages-insoupconnes-de-cmut-direct-pro-pour-les-petites-entreprises/',
#  'https://www.kf-finances.com/comprendre-le-smic-en-thailande-un-guide-pour-les-expatries-francophones/',
#  'https://www.kf-finances.com/www-ca-cmds-fr-acceder-a-mes-comptes-vade-mecum-exhaustif-pour-neophytes/']

# %% [markdown]
# ### Récupérer les infos qu'on souhaite sur chaque article

# %%
def get_article_info(r, url_article):
    # Liste de variables
    noms_variables = [
        'url',  # URL scrapée
        'canonical_url', 'slug', 'meta_title', 'meta_desc',  # Infos issues de la balise meta
        'date_published', 'date_modified',  # Infos dates
        'author',  # Parfois en meta
        'title', 'category', 'views', 'reading_time',  # Metadonnées contenues ailleurs que dans la balise meta
        'content', 'raw_content'  # Contenu de la page
    ]
    
    # Initialisation du dictionnaire
    data = {nom: np.nan for nom in noms_variables}
    
    data['url'] = url_article
    
    soup = BeautifulSoup(r.content, 'lxml')
    
    try:
        data['canonical_url'] = soup.find('link', {'rel': 'canonical'})['href']
    except:
        pass
    
    try:
        data['slug'] = data['canonical_url'].split('/')[-2] if data['canonical_url'] else np.nan
    except:
        pass

    try:
        data['meta_title'] = soup.find('meta', {'property': 'og:title'})['content']
    except:
        pass

    try:
        data['meta_desc'] = soup.find('meta', {'property': 'og:description'})['content']
    except:
        pass

    try:
        data['date_published'] = pd.to_datetime(soup.find('meta', {'property': 'article:published_time'})['content'][:-6], utc=True)
    except:
        pass

    try:
        data['date_modified'] = pd.to_datetime(soup.find('meta', {'property': 'article:modified_time'})['content'][:-6], utc=True)
    except:
        pass

    try:
        data['author'] = soup.find("meta", {'name': 'author'})['content']
    except:
        try:
            data['author'] = soup.find(class_="author").text.split('Publié par ')[-1]
        except:
            pass

    try:
        data['title'] = soup.find('h1').text
    except:
        pass

    try:
        data['category'] = soup.find('div', class_="post-category").text
    except:
        pass

    try:
        data['views'] = int(soup.find('div', class_="views").text)
    except:
        pass

    try:
        data['reading_time'] = int(soup.find('meta', {'name': 'twitter:data2'})['content'].split(' ')[0]) if soup.find('meta', {'name': 'twitter:data2'}) and 'minutes' in soup.find('meta', {'name': 'twitter:data2'})['content'] else np.nan
    except:
        pass

    try:
        data['content'] = BeautifulSoup(str(soup.find("div", class_="td-post-content")), 'lxml').get_text()
    except:
        pass

    try:
        data['raw_content'] = str(soup.find("div", class_="td-post-content"))
    except:
        pass

    # Ajout de features
    data['length'] = len(str(data['content']).split())
    
    if pd.notnull(data['date_published']):
        data['days_since_published'] = int((pd.Timestamp.now(tz='UTC') - data['date_published']).days)
    else:
        data['days_since_published'] = np.nan
    
    # Création de la série
    series = pd.Series(data)
    series.name = url_article
    
    # Ajout de features supplémentaires
    if pd.notnull(data.get('views')) and pd.notnull(data.get('days_since_published')):
        series['views_daily'] = series['views'] / (series['days_since_published']+1)
        series['views_monthly'] = series['views_daily'] * 30
    else:
        series['views_daily'] = np.nan
        series['views_monthly'] = np.nan
    
    series['website'] = top_url
    
    return series

# %% [markdown]
# ## Fonction finale

# %%
article_list = get_articles_on_page(get_all_results_pages(get_max_page_results(top_search_url)))
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]

# %% [markdown]
# ### Fonction finale

# %%
# Import des packages
from concurrent.futures import ThreadPoolExecutor, as_completed
import time

# Initialisation du compteur
start_time = time.time()

# Fonction principale qui sauvegarde le DataFrame dans un fichier CSV et le retourne
def scrape_all_articles(urls, batch_size=250, max_workers=20):
    # Initialisation d'une session réutilisable
    session = rq.Session()

    # Création d'une fonction qui traite chaque URL
    def process_url(url):
            try:
                r = session.get(url)
                return get_article_info(r, url)
            except Exception as e:
                print(f"Erreur pour {url}: {str(e)}")
                return pd.Series(name=url)

    # Utilise ThreadPoolExecutor pour paralléliser le traitement
    results = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Parcourt la liste d'URLs par lots de taille 'batch_size'
        for i in range(0, len(urls), batch_size):
            # Extrait un lot d'URLs
            batch = urls[i:i+batch_size]
            # Crée et soumet des tâches pour chaque URL du lot
            futures = [executor.submit(process_url, url) for url in batch]
            
            # Traite les résultats au fur et à mesure qu'ils sont terminés
            for future in tqdm(as_completed(futures), total=len(batch), desc=f"Batch {i//batch_size + 1} / {len(urls)//batch_size+1}"):
                # Récupère le résultat de la tâche
                result = future.result()
                # Si le résultat n'est pas None (pas d'erreur), l'ajoute aux résultats
                if result is not None:
                    results.append(result)
    
    # Création du DataFrame final
    df_final = pd.DataFrame(results)
    
    # Ajout de colonnes calculées
    df_final['website'] = top_url
    df_final['scraping_date'] = pd.Timestamp.now(tz='UTC')

    df_final.columns = ['article_url', 'article_canonical_url', 'article_slug',
       'article_meta_title', 'article_meta_desc', 'article_date_published',
       'article_date_modified', 'article_author', 'article_title',
       'article_category', 'article_views', 'article_reading_time',
       'article_content', 'article_raw_content', 'article_length',
       'days_since_published', 'article_views_daily', 'article_views_monthly',
       'website', 'scraping_date']

    # Sauvegarde en CSV
    df_final.to_csv(f'scraping_{abbr}.csv', sep='|', index=True)
    print(f"Scraping terminé. Total d'articles : {len(df_final)}")
    return df_final

df = scrape_all_articles(article_list)

end_time = time.time()
print(end_time - start_time)
# Out:
# Batch 1 / 3:   0%|          | 0/250 [00:00<?, ?it/s]
# Batch 2 / 3:   0%|          | 0/250 [00:00<?, ?it/s]
# Batch 3 / 3:   0%|          | 0/137 [00:00<?, ?it/s]
# Scraping terminé. Total d'articles : 637
# 103.54789352416992

# %%
# Création d'un rapport de profil avec pandas_profiling
profile = ProfileReport(df, title=f"{abbr.title()} Scraping Report", explorative=True)

# Génération du rapport au format HTML
profile.to_file(f"scraping_report_{abbr}.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# c:\Users\aurel\anaconda3\Lib\site-packages\ydata_profiling\model\correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'cannot reindex on an axis with duplicate labels')
#   warnings.warn(
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
