# %% [markdown]
# # Scraping DCG.media

# %% [markdown]
# %pip install bs4 pandas numpy ydata-profiling plotly tqdm ipywidgets

# %%
### SCRAPING
import requests as rq
from bs4 import BeautifulSoup

### DATABASES
import pandas as pd
import numpy as np
from ydata_profiling import ProfileReport

### VISUALISATION
#import plotly.express as px

### DIVERS
from tqdm.notebook import tqdm

### FORMAT
from datetime import datetime, timezone
import time
import json

# %% [markdown]
# ## Définition des variables

# %%
website = 'spotemploi'
abbr = 'spe'
tld = '.com'

# %%
page_number = 1
top_url = f'https://www.{website+tld}'
top_search_url = f'{top_url}/page/{page_number}/?s'

# %% [markdown]
# ## Définition des fonctions

# %% [markdown]
# ### Obtenir le nombre de pages de résultats de recherche

# %%
def get_max_page_results(top_search_url):
    r = rq.get(top_search_url)
    soup = BeautifulSoup(r.content)
    page_final = soup.find('a', class_ = 'last').text
    return int(page_final)
get_max_page_results(top_search_url)
# Out:
# 10

# %% [markdown]
# ### Obtenir la liste des pages de résultats de recherche

# %%
def get_all_results_pages(page_final):
    urls = []
    for i in range(page_final):
        i = f'{top_url}/page/{i+1}/?s'
        urls.append(i)
    return urls
get_all_results_pages(get_max_page_results(top_search_url))
# Out:
# ['https://www.spotemploi.com/page/1/?s',
#  'https://www.spotemploi.com/page/2/?s',
#  'https://www.spotemploi.com/page/3/?s',
#  'https://www.spotemploi.com/page/4/?s',
#  'https://www.spotemploi.com/page/5/?s',
#  'https://www.spotemploi.com/page/6/?s',
#  'https://www.spotemploi.com/page/7/?s',
#  'https://www.spotemploi.com/page/8/?s',
#  'https://www.spotemploi.com/page/9/?s',
#  'https://www.spotemploi.com/page/10/?s']

# %% [markdown]
# ### Obtenir tous les liens des articles sur une page de recherche

# %%
def get_articles_on_page(search_results):
    urls_articles = []
    s = rq.Session()
    for p in tqdm(search_results):
        r = s.get(p)
        soup = BeautifulSoup(r.content)
        articles = soup.find_all('h2', class_ = 'entry-title')
        for article in articles:
            url = article.find('a', href=True)['href']
            urls_articles.append(url)
    return urls_articles

# %%
get_articles_on_page(get_all_results_pages(get_max_page_results(top_search_url)))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# ['https://www.spotemploi.com/pourquoi-la-formation-est-la-cle-dune-prevention-efficace-des-risques-professionnels/',
#  'https://www.spotemploi.com/ent-tours-se-connecter-en-ligne/',
#  'https://www.spotemploi.com/mycampus-connexion-a-mycampus-eduservices/',
#  'https://www.spotemploi.com/les-cles-pour-reussir-son-test-psychotechnique-sncf/',
#  'https://www.spotemploi.com/cet-apres-midi-ou-cette-apres-midi-une-guide-sur-lorthographe-correcte/',
#  'https://www.spotemploi.com/bts-decouvrez-lage-de-chaque-membre-de-ce-groupe-de-k-pop-sensationnel/',
#  'https://www.spotemploi.com/bts-decouvrez-lage-de-chaque-membre-de-ce-groupe-de-k-pop-sensationnel-2/',
#  'https://www.spotemploi.com/leo-uga-decouvrez-les-programmes-et-ressources-de-luniversite-de-georgie/',
#  'https://www.spotemploi.com/optimiser-lutilisation-de-la-messagerie-academique-nancy-metz/',
#  'https://www.spotemploi.com/ent-u-bordeaux-portail-universitaire/',
#  'https://www.spotemploi.com/optimisez-votre-experience-dapprentissage-avec-mycampus-eduservices/',
#  'https://www.spotemploi.com/limpact-de-myschool-escp-sur-lexperience-etudiant/',
#  'https://www.spotemploi.com/creer-un-dossier-sur-pix-le-guide-exhaustif/',
#  'https://www.spotemploi.com/metier-par-w-levolution-technologique-dans-le-domaine-du-wagonnage/',
#  'https://www.spotemploi.com/decouvrir-les-opportunites-de-metis-afpa-fr-pour-une-requalification-professionnelle-reussie/',
#  'https://www.spotemploi.com/luniversite-dangers-ent-revolution-numerique-au-sein-du-campus/',
#  'https://www.spotemploi.com/comment-lauthentification-a-poitiers-transforme-lacces-aux-ressources-educatives/',
#  'https://www.spotemploi.com/escp-blackboard-guide-pour-les-etudiants-et-enseignants/',
#  'https://www.spotemploi.com/mycampus-eduservices-guide-pour-naviguer-facilement-sur-la-plateforme/',
#  'https://www.spotemploi.com/prime-informatique-enseignant-2025-nouveautes-et-modalites-de-versement/',
#  'https://www.spotemploi.com/limportance-cruciale-de-la-palette-euro-pour-une-chaine-dapprovisionnement-efficiente/',
#  'https://www.spotemploi.com/akeonet-comment-acceder-a-vos-outils-professionnels-facilement/',
#  'https://www.spotemploi.com/comprendre-le-role-du-pai-dans-leducation-nationale-enjeux-et-perspectives/',
#  'https://www.spotemploi.com/quel-est-le-metier-le-plus-epanouissant/',
#  'https://www.spotemploi.com/univo-revolutionne-le-monde-des-plateformes-de-e-learning/',
#  'https://www.spotemploi.com/comment-rediger-une-lettre-de-motivation-pour-une-demande-de-formation/',
#  'https://www.spotemploi.com/les-avantages-de-choisir-ornicar-pour-son-permis-de-conduire/',
#  'https://www.spotemploi.com/les-stylos-4-couleurs-puff-un-outil-essentiel-pour-les-etudiants-et-les-professionnels/',
#  'https://www.spotemploi.com/formation-permis-poids-lourd-tout-savoir-sur-le-financement-via-le-cpf/',
#  'https://www.spotemploi.com/comment-se-reconvertir-dans-la-data-science/',
#  'https://www.spotemploi.com/devenir-kinesitherapeute-etapes-et-conseils-pour-une-reconversion-reussie/',
#  'https://www.spotemploi.com/rediger-un-chapo-efficace-techniques-et-pieges-a-eviter-en-ecriture/',
#  'https://www.spotemploi.com/zoom-sur-le-salaire-dun-instituteur-primaire-chiffres-et-perspectives-devolution/',
#  'https://www.spotemploi.com/methode-nerac-expliquee-avantages-et-fonctionnement-pour-votre-strategie/',
#  'https://www.spotemploi.com/droit-aux-vacances-en-bts-alternance-ce-quil-faut-savoir/',
#  'https://www.spotemploi.com/methode-nerac-expliquee-avantages-et-processus-pour-optimiser-votre-strategie/',
#  'https://www.spotemploi.com/enneagramme-type-2-quest-ce-que-cest/',
#  'https://www.spotemploi.com/seuil-dimposition-a-partir-de-combien-de-revenus-doit-on-payer-des-impots/',
#  'https://www.spotemploi.com/optimiser-vos-travaux-grace-au-tableau-de-conversion-litre-en-metre-cube/',
#  'https://www.spotemploi.com/a-quel-age-on-passe-le-bac-informations-officielles/',
#  'https://www.spotemploi.com/changer-de-conseiller-pole-emploi-demarches-et-conseils/',
#  'https://www.spotemploi.com/reflexologie-et-sante-limportance-dune-formation-solide/',
#  'https://www.spotemploi.com/exploration-des-meilleures-agences-dinterim-a-evreux-votre-chemin-vers-lemploi/',
#  'https://www.spotemploi.com/les-avantages-dune-formation-en-alternance-en-hotellerie-et-tourisme/',
#  'https://www.spotemploi.com/integrer-le-developpement-durable-dans-son-cursus-en-ecole-de-commerce/',
#  'https://www.spotemploi.com/qui-peut-beneficier-dune-formation-par-pole-emploi/',
#  'https://www.spotemploi.com/comment-sinscrire-a-pole-emploi-sans-attestation-employeur/',
#  'https://www.spotemploi.com/devenir-digital-nomad/',
#  'https://www.spotemploi.com/comment-devenir-un-conducteur-livreur-sur-vehicules-utilitaires-legers-niv-3-niveau-cap/',
#  'https://www.spotemploi.com/permis-de-conduire-en-ligne-les-avantages/',
#  'https://www.spotemploi.com/comment-amenager-son-temps-de-travail/',
#  'https://www.spotemploi.com/comprendre-lexperience-employe/',
#  'https://www.spotemploi.com/le-conge-paternite-explique-vos-droits/',
#  'https://www.spotemploi.com/quest-ce-que-le-cpf-de-transition-professionnelle/',
#  'https://www.spotemploi.com/cet-apres-midi-ou-cette-apres-midi-une-guide-sur-lorthographe-correcte/',
#  'https://www.spotemploi.com/comment-sinscrire-a-pole-emploi-sans-attestation-employeur/',
#  'https://www.spotemploi.com/mycampus-connexion-a-mycampus-eduservices/',
#  'https://www.spotemploi.com/quel-est-le-travail-dans-une-agence-dinterim/',
#  'https://www.spotemploi.com/formation-interne-ou-externe-quel-choix-pour-les-entreprises/',
#  'https://www.spotemploi.com/cpf-et-permis-poids-lourd-quelles-sont-les-conditions/',
#  'https://www.spotemploi.com/permis-poids-lourd-et-cpf-un-duo-gagnant-pour-une-reconversion-professionnelle-reussie/',
#  'https://www.spotemploi.com/comment-obtenir-son-permis-poids-lourd-sans-se-ruiner-grace-au-cpf/',
#  'https://www.spotemploi.com/comment-obtenir-laide-financiere-de-la-caf-pour-le-permis-c-guide-complet/',
#  'https://www.spotemploi.com/reussir-le-test-psychotechnique-sncf-astuces-et-processus-detaille/',
#  'https://www.spotemploi.com/rediger-une-fiche-de-jurisprudence-efficacement-astuces-et-methodologie/',
#  'https://www.spotemploi.com/importance-de-larret-appieto-du-20-novembre-1963-en-droit-civil/',
#  'https://www.spotemploi.com/analyse-approfondie-de-la-formation-de-yomi-denzel-ce-que-vous-devez-savoir/',
#  'https://www.spotemploi.com/integrer-efficacement-vos-loisirs-dans-un-cv-conseils-et-astuces-pour-se-demarquer/',
#  'https://www.spotemploi.com/enseignement-et-fiche-de-paie-guide-complet-pour-les-enseignants/',
#  'https://www.spotemploi.com/quelle-est-la-duree-des-etudes-de-kinesitherapie-en-espagne/',
#  'https://www.spotemploi.com/explorez-lunivers-di-prof-strasbourg-astuces-et-conseils/',
#  'https://www.spotemploi.com/taux-de-change-du-franc-suisse-comprendre-son-impact-et-son-importance/',
#  'https://www.spotemploi.com/comment-obtenir-un-cdi-dans-la-fonction-publique-hospitaliere-etapes-et-conseils/',
#  'https://www.spotemploi.com/formation-continue-comment-se-reorienter-vers-le-teletravail/',
#  'https://www.spotemploi.com/les-questions-difficiles-de-lentretien-dembauche/',
#  'https://www.spotemploi.com/devenir-avocat-etapes-cles-formation-et-conseils-pour-reussir/',
#  'https://www.spotemploi.com/credit-cpf-delai-de-versement-et-consultation-du-solde-en-ligne/',
#  'https://www.spotemploi.com/les-competences-incontournables-pour-exceller-comme-nettoyeur-decran-de-cinema/',
#  'https://www.spotemploi.com/le-parcours-dexcellence-avec-interim-triangle-valenciennes-un-apercu-detaille/',
#  'https://www.spotemploi.com/ouvrir-une-franchise-rentable-quelles-opportunites-choisir/',
#  'https://www.spotemploi.com/comment-envoyer-un-document-via-pronote-guide-complet/',
#  'https://www.spotemploi.com/oravendis-un-taux-de-reussite-qui-fait-la-difference/',
#  'https://www.spotemploi.com/creer-son-chemin-vers-le-succes-une-approche-unique-de-lexemple-de-projet-professionnel-personnalise/',
#  'https://www.spotemploi.com/comment-optimiser-votre-cv-de-designer-pour-seduire-pole-emploi-astuces-et-conseils/',
#  'https://www.spotemploi.com/comment-devenir-un-plaquiste-platrier-dexception/',
#  'https://www.spotemploi.com/redaction-des-clauses-dun-jeu-concours-en-boutique-erreurs-a-eviter/',
#  'https://www.spotemploi.com/les-metiers-de-la-banque-comment-se-former-pour-reussir-dans-ce-secteur-en-pleine-mutation/',
#  'https://www.spotemploi.com/est-ce-que-la-caf-peut-financer-une-formation/',
#  'https://www.spotemploi.com/quest-ce-quun-ambassadeur-dentreprise/',
#  'https://www.spotemploi.com/comment-se-former-a-un-bts-gpme/',
#  'https://www.spotemploi.com/quel-bts-dans-le-commerce/',
#  'https://www.spotemploi.com/un-hebergement-unique-pour-les-etudiants-erasmus-a-budapest/',
#  'https://www.spotemploi.com/se-former-en-anglais-le-point-sur-les-differentes-options-disponibles/',
#  'https://www.spotemploi.com/financer-son-permis-poids-lourd-grace-a-son-cpf-les-etapes-a-suivre/',
#  'https://www.spotemploi.com/tout-savoir-sur-le-cpf-et-son-utilisation-pour-financer-le-permis-poids-lourd/',
#  'https://www.spotemploi.com/les-elements-incontournables-dun-cv-reussi-pour-larmee/',
#  'https://www.spotemploi.com/bac-std2a-comprendre-son-importance-et-ses-debouches-pour-les-etudiants-en-design-et-arts-appliques/',
#  'https://www.spotemploi.com/devenir-cpe-en-france-parcours-formation-et-conseils-pratiques/',
#  'https://www.spotemploi.com/pourquoi-se-reconvertir-dans-les-metiers-de-la-coiffure/',
#  'https://www.spotemploi.com/pedagogie-montessori-top-livres-pour-maitriser-la-methode-educative/',
#  'https://www.spotemploi.com/formation-coach-intuitif-demarrer-votre-carriere-et-reussir/',
#  'https://www.spotemploi.com/direct-securite-formation-centre-n1-pour-lobtention-dun-cqp-aps/',
#  'https://www.spotemploi.com/les-secteurs-qui-recrutent-en-interim-en-2024/',
#  'https://www.spotemploi.com/maximisez-votre-temps-avec-la-boite-academique-de-lyon/',
#  'https://www.spotemploi.com/comprendre-la-remuneration-dun-bts-en-alternance-grille-de-salaires-et-facteurs-variables/',
#  'https://www.spotemploi.com/pivoter-avec-succes-strategies-pour-une-reconversion-professionnelle-efficace/',
#  'https://www.spotemploi.com/comment-optimiser-sa-formation-pour-acceder-aux-meilleures-opportunites-demploi-a-annecy/',
#  'https://www.spotemploi.com/comment-amenager-son-temps-de-travail/',
#  'https://www.spotemploi.com/comprendre-lexperience-employe/',
#  'https://www.spotemploi.com/le-conge-paternite-explique-vos-droits/',
#  'https://www.spotemploi.com/quest-ce-que-le-cpf-de-transition-professionnelle/',
#  'https://www.spotemploi.com/cet-apres-midi-ou-cette-apres-midi-une-guide-sur-lorthographe-correcte/',
#  'https://www.spotemploi.com/comment-sinscrire-a-pole-emploi-sans-attestation-employeur/',
#  'https://www.spotemploi.com/mycampus-connexion-a-mycampus-eduservices/',
#  'https://www.spotemploi.com/decouvrez-les-fonctionnalites-avancees-de-mycampus-par-eduservices/',
#  'https://www.spotemploi.com/optimiser-son-utilisation-du-webmail-academie-de-normandie-guide-pratique/',
#  'https://www.spotemploi.com/les-formations-indispensables-pour-reussir-la-creation-de-son-entreprise/',
#  'https://www.spotemploi.com/atteindre-le-sommet-managerial-comment-conjuguer-formation-et-reconnaissance-pour-reussir/',
#  'https://www.spotemploi.com/le-role-crucial-de-lalternance-dans-la-formation-dauxiliaire-de-puericulture/',
#  'https://www.spotemploi.com/diplomatie-et-discretion-comment-refuser-une-offre-sans-bruler-les-ponts/',
#  'https://www.spotemploi.com/quels-sont-les-qualites-et-les-defauts-dun-entrepreneur/',
#  'https://www.spotemploi.com/les-atouts-de-la-formation-continue-pour-dynamiser-sa-trajectoire-professionnelle/',
#  'https://www.spotemploi.com/maitriser-le-preterit-en-allemand-astuces-et-conseils-pour-y-parvenir/',
#  'https://www.spotemploi.com/comment-reagir-face-a-une-injustice-au-travail/',
#  'https://www.spotemploi.com/devenir-psychologue-a-40-ans-conseils-pour-une-reconversion/',
#  'https://www.spotemploi.com/les-avantages-dune-assurance-professionnelle-sur-mesure-pour-les-pme/',
#  'https://www.spotemploi.com/comment-pourrais-je-vous-aider-astuces-et-methodes-pour-ameliorer-votre-service-client/',
#  'https://www.spotemploi.com/parcours-academique-detaille-comment-se-preparer-a-une-carriere-en-droit/',
#  'https://www.spotemploi.com/comment-trouver-un-teletravail-serieux/',
#  'https://www.spotemploi.com/les-avantages-de-suivre-une-formation-en-electromecanique/',
#  'https://www.spotemploi.com/le-cout-moyen-dun-bilan-de-competences-en-france/',
#  'https://www.spotemploi.com/cpf-financer-sa-formation-de-permis-poids-lourd-cest-possible/',
#  'https://www.spotemploi.com/les-meilleurs-podcasts-pour-pratiquer-et-ameliorer-son-arabe/',
#  'https://www.spotemploi.com/tout-savoir-sur-le-cpf-pour-financer-votre-permis-de-conduire-poids-lourd/',
#  'https://www.spotemploi.com/opter-pour-un-bts-services-et-prestations-des-secteurs-sanitaire-et-social-un-parcours-prometteur-pour-une-carriere-reussie/',
#  'https://www.spotemploi.com/comment-innover-en-entreprise/',
#  'https://www.spotemploi.com/pourquoi-apprendre-langlais/',
#  'https://www.spotemploi.com/comment-trouver-un-emploi-darchitecte/',
#  'https://www.spotemploi.com/conseils-et-exemples-pour-rediger-une-synthese-de-stage-en-troisieme/',
#  'https://www.spotemploi.com/limportance-de-la-motivation-dans-lapprentissage-de-larabe/',
#  'https://www.spotemploi.com/plateforme-lms-la-bonne-solution-pour-votre-formation-en-entreprise/',
#  'https://www.spotemploi.com/cinq-competences-cles-pour-reussir-dans-le-secteur-de-la-vente/',
#  'https://www.spotemploi.com/comment-imbriquer-les-connecteurs-logiques-espagnols-dans-une-dissertation/',
#  'https://www.spotemploi.com/cpf-tout-savoir-sur-la-conversion-de-son-dif/',
#  'https://www.spotemploi.com/les-outils-numeriques-indispensables-pour-optimiser-lapprentissage-en-formation/',
#  'https://www.spotemploi.com/le-cv-quelle-importance-en-2023/',
#  'https://www.spotemploi.com/pedagogie-reggio-expliquee-principes-et-impact-sur-lapprentissage/',
#  'https://www.spotemploi.com/tableau-des-declinaisons-allemandes-erreurs-frequentes-a-eviter/',
#  'https://www.spotemploi.com/quels-sont-les-secteurs-porteurs-en-reconversion-professionnelle/',
#  'https://www.spotemploi.com/quelles-sont-les-formations-adaptees-aux-besoins-des-entreprises/',
#  'https://www.spotemploi.com/les-etapes-incontournables-pour-acceder-a-lent-auvergne-et-enrichir-votre-apprentissage/',
#  'https://www.spotemploi.com/comment-trouver-rapidement-un-emploi-dans-le-domaine-de-la-plomberie-et-du-chauffage/',
#  'https://www.spotemploi.com/rediger-un-sommaire-de-rapport-de-stage-efficace-astuces-et-conseils-seo/',
#  'https://www.spotemploi.com/ameliorer-vos-competences-en-design-les-meilleures-formations-de-graphisme-en-france/',
#  'https://www.spotemploi.com/les-problemes-courants-en-entreprise/',
#  'https://www.spotemploi.com/comment-se-faire-financer-une-formation-par-la-region/',
#  'https://www.spotemploi.com/quest-ce-quun-gerant-egalitaire/',
#  'https://www.spotemploi.com/cpf-et-pole-emploi-comment-evaluer-la-valeur-de-votre-temps-de-formation/',
#  'https://www.spotemploi.com/comment-rediger-et-bien-structurer-un-compte-rendu-dun-seminaire-dentreprise/',
#  'https://www.spotemploi.com/top-applications-pour-apprendre-une-langue-avis-et-comparatif-2023/',
#  'https://www.spotemploi.com/les-coulisses-de-la-mise-sous-pli-techniques-et-astuces/',
#  'https://www.spotemploi.com/classement-des-prepas-les-facteurs-determinants-pour-reussir/',
#  'https://www.spotemploi.com/quelles-opportunites-de-carriere-en-kinesiologie-en-2025/',
#  'https://www.spotemploi.com/comment-mettre-en-place-le-teletravail-dans-son-entreprise/',
#  'https://www.spotemploi.com/comment-amenager-son-temps-de-travail/',
#  'https://www.spotemploi.com/comprendre-lexperience-employe/',
#  'https://www.spotemploi.com/le-conge-paternite-explique-vos-droits/',
#  'https://www.spotemploi.com/quest-ce-que-le-cpf-de-transition-professionnelle/',
#  'https://www.spotemploi.com/cet-apres-midi-ou-cette-apres-midi-une-guide-sur-lorthographe-correcte/',
#  'https://www.spotemploi.com/comment-sinscrire-a-pole-emploi-sans-attestation-employeur/',
#  'https://www.spotemploi.com/quels-sont-les-modules-proposes-avec-la-formation-iobsp/',
#  'https://www.spotemploi.com/une-formation-de-mode-traditionnelle-ou-a-distance/',
#  'https://www.spotemploi.com/pourquoi-faut-il-consulter-les-sites-relatifs-aux-metiers/',
#  'https://www.spotemploi.com/boostez-votre-developpement-personnel-et-gerez-votre-stress-grace-a-la-formation/',
#  'https://www.spotemploi.com/consulter-des-blogs-dedies-aux-entreprises-pour-beneficier-de-conseils-dexperts/',
#  'https://www.spotemploi.com/quelles-sont-les-differentes-formations-dans-le-secteur-de-la-finance/',
#  'https://www.spotemploi.com/pourquoi-se-faire-former-en-immobilier/',
#  'https://www.spotemploi.com/les-formations-incontournables-pour-reussir-dans-le-monde-des-affaires/',
#  'https://www.spotemploi.com/formation-en-entreprise-comment-booster-la-productivite-de-vos-equipes-grace-a-la-formation-professionnelle-continue/',
#  'https://www.spotemploi.com/qui-peut-beneficier-dun-temps-partiel/',
#  'https://www.spotemploi.com/comment-apprendre-en-ligne-de-maniere-efficace/',
#  'https://www.spotemploi.com/dcg-guide-pour-choisir-letablissement-ideal-et-reussir-votre-parcours/',
#  'https://www.spotemploi.com/tout-ce-quil-faut-savoir-sur-la-synthese-de-stage-en-troisieme/',
#  'https://www.spotemploi.com/entreprise-optez-pour-des-cartes-de-visite-originales/',
#  'https://www.spotemploi.com/comment-devenir-consultant-financier/',
#  'https://www.spotemploi.com/bien-choisir-son-statut-juridique-en-profession-liberale/',
#  'https://www.spotemploi.com/quel-3e-pilier-est-le-plus-avantageux/',
#  'https://www.spotemploi.com/comment-amenager-son-temps-de-travail/',
#  'https://www.spotemploi.com/comprendre-lexperience-employe/',
#  'https://www.spotemploi.com/le-conge-paternite-explique-vos-droits/',
#  'https://www.spotemploi.com/quest-ce-que-le-cpf-de-transition-professionnelle/',
#  'https://www.spotemploi.com/cet-apres-midi-ou-cette-apres-midi-une-guide-sur-lorthographe-correcte/',
#  'https://www.spotemploi.com/comment-sinscrire-a-pole-emploi-sans-attestation-employeur/',
#  'https://www.spotemploi.com/mycampus-connexion-a-mycampus-eduservices/',
#  'https://www.spotemploi.com/sitemap/',
#  'https://www.spotemploi.com/un-sejour-en-angleterre-pour-apprendre-la-langue-de-shakespeare/',
#  'https://www.spotemploi.com/bts-management-commercial-operationnel-ce-quil-faut-savoir/',
#  'https://www.spotemploi.com/pourquoi-se-rapprocher-dun-centre-de-formation/',
#  'https://www.spotemploi.com/quelles-sont-les-cles-de-la-reussite/',
#  'https://www.spotemploi.com/quest-ce-que-le-cpf-de-transition-professionnelle/',
#  'https://www.spotemploi.com/contact/',
#  'https://www.spotemploi.com/mentions-legales/',
#  'https://www.spotemploi.com/le-conge-paternite-explique-vos-droits/',
#  'https://www.spotemploi.com/comprendre-lexperience-employe/',
#  'https://www.spotemploi.com/comment-amenager-son-temps-de-travail/',
#  'https://www.spotemploi.com/',
#  'https://www.spotemploi.com/comment-amenager-son-temps-de-travail/',
#  'https://www.spotemploi.com/comprendre-lexperience-employe/',
#  'https://www.spotemploi.com/le-conge-paternite-explique-vos-droits/',
#  'https://www.spotemploi.com/quest-ce-que-le-cpf-de-transition-professionnelle/',
#  'https://www.spotemploi.com/cet-apres-midi-ou-cette-apres-midi-une-guide-sur-lorthographe-correcte/',
#  'https://www.spotemploi.com/comment-sinscrire-a-pole-emploi-sans-attestation-employeur/',
#  'https://www.spotemploi.com/mycampus-connexion-a-mycampus-eduservices/']

# %% [markdown]
# ### Récupérer les infos qu'on souhaite sur chaque article

# %%
def get_article_info(r, url_article):
    # Liste de variables
    noms_variables = [
        'url',  # URL scrapée
        'canonical_url', 'slug', 'meta_title', 'meta_desc',  # Infos issues de la balise meta
        'date_published', 'date_modified',  # Infos dates
        'author',  # Parfois en meta
        'title', 'category', 'views', 'reading_time',  # Metadonnées contenues ailleurs que dans la balise meta
        'content', 'raw_content'  # Contenu de la page
    ]
    
    # Initialisation du dictionnaire
    data = {nom: np.nan for nom in noms_variables}
    
    data['url'] = url_article
    
    soup = BeautifulSoup(r.content, 'lxml')
    
    try:
        data['canonical_url'] = soup.find('link', {'rel': 'canonical'})['href']
    except:
        pass
    
    try:
        data['slug'] = data['canonical_url'].split('/')[-2] if data['canonical_url'] else np.nan
    except:
        pass

    try:
        data['meta_title'] = soup.find('meta', {'property': 'og:title'})['content']
    except:
        pass

    try:
        data['meta_desc'] = soup.find('meta', {'property': 'og:description'})['content']
    except:
        pass

    try:
        data['date_published'] = pd.to_datetime(soup.find('meta', {'property': 'article:published_time'})['content'][:-6], utc=True)
    except:
        pass

    try:
        data['date_modified'] = pd.to_datetime(soup.find('meta', {'property': 'article:modified_time'})['content'][:-6], utc=True)
    except:
        pass

    try:
        data['author'] = soup.find("meta", {'name': 'author'})['content']
    except:
        try:
            data['author'] = soup.find(class_="author").text.split('Publié par ')[-1]
        except:
            pass

    try:
        data['title'] = soup.find('h1').text
    except:
        pass

    try:
        data['category'] = [x.text for x in soup.find_all(class_="tdb-entry-category")]
    except:
        pass

    try:
        data['views'] = int(soup.find('span', class_=lambda x: x and x.startswith('td-nr-views-')).text)
    except:
        pass

    try:
        data['reading_time'] = int(soup.find('meta', {'name': 'twitter:data2'})['content'].split(' ')[0]) if soup.find('meta', {'name': 'twitter:data2'}) and 'minutes' in soup.find('meta', {'name': 'twitter:data2'})['content'] else np.nan
    except:
        pass

    try:
        data['content'] = BeautifulSoup(str(soup.find("div", class_="td-post-content")), 'lxml').get_text()
    except:
        pass

    try:
        data['raw_content'] = str(soup.find("div", class_="td-post-content"))
    except:
        pass

    # Ajout de features
    data['length'] = len(str(data['content']).split())
    
    if pd.notnull(data['date_published']):
        data['days_since_published'] = int((pd.Timestamp.now(tz='UTC') - data['date_published']).days)
    else:
        data['days_since_published'] = np.nan
    
    # Création de la série
    series = pd.Series(data)
    series.name = url_article
    
    # Ajout de features supplémentaires
    if pd.notnull(data.get('views')) and pd.notnull(data.get('days_since_published')):
        series['views_daily'] = series['views'] / series['days_since_published']
        series['views_monthly'] = series['views_daily'] * 30
    else:
        series['views_daily'] = np.nan
        series['views_monthly'] = np.nan
    
    series['website'] = top_url
    
    return series

# %% [markdown]
# ## Fonction finale

# %%
article_list = get_articles_on_page(get_all_results_pages(get_max_page_results(top_search_url)))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# ### Fonction finale

# %%
# Import des packages
from concurrent.futures import ThreadPoolExecutor, as_completed
import time

# Initialisation du compteur
start_time = time.time()

# Fonction principale qui sauvegarde le DataFrame dans un fichier CSV et le retourne
def scrape_all_articles(urls, batch_size=250, max_workers=20):
    # Initialisation d'une session réutilisable
    session = rq.Session()

    # Création d'une fonction qui traite chaque URL
    def process_url(url):
            try:
                r = session.get(url)
                return get_article_info(r, url)
            except Exception as e:
                print(f"Erreur pour {url}: {str(e)}")
                return pd.Series(name=url)

    # Utilise ThreadPoolExecutor pour paralléliser le traitement
    results = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Parcourt la liste d'URLs par lots de taille 'batch_size'
        for i in range(0, len(urls), batch_size):
            # Extrait un lot d'URLs
            batch = urls[i:i+batch_size]
            # Crée et soumet des tâches pour chaque URL du lot
            futures = [executor.submit(process_url, url) for url in batch]
            
            # Traite les résultats au fur et à mesure qu'ils sont terminés
            for future in tqdm(as_completed(futures), total=len(batch), desc=f"Batch {i//batch_size + 1} / {len(urls)//batch_size+1}"):
                # Récupère le résultat de la tâche
                result = future.result()
                # Si le résultat n'est pas None (pas d'erreur), l'ajoute aux résultats
                if result is not None:
                    results.append(result)
    
    # Création du DataFrame final
    df_final = pd.DataFrame(results)
    
    # Ajout de colonnes calculées
    df_final['website'] = top_url
    df_final['scraping_date'] = pd.Timestamp.now(tz='UTC')

    df_final.columns = ['article_url', 'article_canonical_url', 'article_slug',
       'article_meta_title', 'article_meta_desc', 'article_date_published',
       'article_date_modified', 'article_author', 'article_title',
       'article_category', 'article_views', 'article_reading_time',
       'article_content', 'article_raw_content', 'article_length',
       'days_since_published', 'article_views_daily', 'article_views_monthly',
       'website', 'scraping_date']

    # Sauvegarde en CSV
    df_final.to_csv(f'scraping_{abbr}.csv', sep='|', index=True)
    print(f"Scraping terminé. Total d'articles : {len(df_final)}")
    return df_final

df = scrape_all_articles(article_list)

end_time = time.time()
print(end_time - start_time)
# Out:
# Batch 1 / 3:   0%|          | 0/250 [00:00<?, ?it/s]
# Batch 2 / 3:   0%|          | 0/250 [00:00<?, ?it/s]
# Batch 3 / 3:   0%|          | 0/32 [00:00<?, ?it/s]
# Scraping terminé. Total d'articles : 532
# 67.06396150588989

# %%
# Création d'un rapport de profil avec pandas_profiling
profile = ProfileReport(df, title=f"{abbr.title()} Scraping Report", explorative=True)

# Génération du rapport au format HTML
profile.to_file(f"scraping_report_{abbr}.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# c:\Users\aurel\anaconda3\Lib\site-packages\ydata_profiling\model\correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'cannot reindex on an axis with duplicate labels')
#   warnings.warn(
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
